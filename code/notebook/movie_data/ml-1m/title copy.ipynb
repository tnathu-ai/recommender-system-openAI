# %%
import numpy as np
import openai
import pandas as pd
import os
import sys
import time

# Add the path to the constants file to the system path
sys.path.append('../../../')
from constants import *
from evaluation_utils import *
from path_utils import *
from ChatCompletion_OpenAI_API import *

# OpenAI API Key
openai.api_key = OPENAI_API_KEY

SYSTEM_CONTENT = MOVIELENS_CONTENT_SYSTEM
# Constants for column names
USER_COLUMN_NAME = 'UserID'
TITLE_COLUMN_NAME = 'Title'
ITEM_ID_COLUMN = 'MovieID'
RATING_COLUMN_NAME = 'Rating'

TEST_OBSERVATION_PER_USER = 1
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# source code folder path
rec_sys_dir = get_rec_sys_directory()
print(f"Rec-sys directory: {rec_sys_dir}")

# data folder path
DATA_DIR = os.path.join(rec_sys_dir, '../data')
print(f"Data directory: {DATA_DIR}")

# data path
data_path = os.path.join(DATA_DIR, 'ml-1m/merged_data.dat')
print(f'Data path: {data_path}')

# output
ZERO_SHOT_SAVE_PATH = os.path.join(DATA_DIR, 'ml-1m/output/title_zero_shot.dat')
print(f'ZERO_SHOT_SAVE_PATH path: {ZERO_SHOT_SAVE_PATH}')

ZERO_SHOT_RERUN_PATH = os.path.join(DATA_DIR, 'ml-1m/output/rerun_title_zero_shot.dat')
print(f'ZERO_SHOT_RERUN_PATH path: {ZERO_SHOT_RERUN_PATH}')

# few shot save path
FEW_SHOT_1_OBS_SAVE_PATH = os.path.join(DATA_DIR, 'ml-1m/output/title_1_test_predictions_few_shot.csv')
print(f'Few shot save path: {FEW_SHOT_1_OBS_SAVE_PATH}')


# few shot save path
FEW_SHOT_1_OBS_RERUN_PATH = os.path.join(DATA_DIR, 'ml-1m/output/rerun_title_1_test_predictions_few_shot.csv')
print(f'Few shot rerun path: {FEW_SHOT_1_OBS_SAVE_PATH}')
# Out:
# Rec-sys directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/code/notebook
# Data directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/code/notebook/../data
# Data path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/code/notebook/../data/ml-1m/merged_data.dat
# ZERO_SHOT_SAVE_PATH path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/code/notebook/../data/ml-1m/output/title_zero_shot.dat
# ZERO_SHOT_RERUN_PATH path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/code/notebook/../data/ml-1m/output/rerun_title_zero_shot.dat
# Few shot save path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/code/notebook/../data/ml-1m/output/title_1_test_predictions_few_shot.csv
# Few shot rerun path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/code/notebook/../data/ml-1m/output/title_1_test_predictions_few_shot.csv

# %% [markdown]
# # Data Overview

# %%
# Read the data
data = pd.read_csv(data_path)

# get statistic and first few data of NUM_SAMPLES rows
data.info()
data.head(NUM_EXAMPLES)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 10 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   UserID      1000209 non-null  int64
#  1   MovieID     1000209 non-null  int64
#  2   Rating      1000209 non-null  int64
#  3   Timestamp   1000209 non-null  int64
#  4   Gender      1000209 non-null  object
#  5   Age         1000209 non-null  int64
#  6   Occupation  1000209 non-null  int64
#  7   Zip-code    1000209 non-null  object
#  8   Title       1000209 non-null  object
#  9   Genres      1000209 non-null  object
# dtypes: int64(6), object(4)
# memory usage: 76.3+ MB
#    UserID  MovieID  Rating  Timestamp Gender  Age  Occupation Zip-code  \
# 0       1     1193       5  978300760      F    1          10    48067
# 1       2     1193       5  978298413      M   56          16    70072
# 2      12     1193       4  978220179      M   25          12    32793
# 3      15     1193       4  978199279      M   25           7    22903
# 4      17     1193       5  978158471      M   50           1    95350
#
#                                     Title Genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4  One Flew Over the Cuckoo's Nest (1975)  Drama

# %% [markdown]
# # Zero-shot (OpenAI API)

# %%
# %%time

predict_ratings_zero_shot_and_save(data,
                                       columns_for_prediction=[TITLE_COLUMN_NAME],
                                       user_column_name=USER_COLUMN_NAME,
                                       title_column_name=TITLE_COLUMN_NAME,
                                       asin_column_name=ITEM_ID_COLUMN,
                                       rating_column_name=RATING_COLUMN_NAME,
                                       pause_every_n_users=PAUSE_EVERY_N_USERS,
                                       sleep_time=SLEEP_TIME,
                                       save_path=ZERO_SHOT_SAVE_PATH,
                                       system_content=SYSTEM_CONTENT)
# Out:
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Pleasantville (1998)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: GoodFellas (1990)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Boat, The (Das Boot) (1981)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Being John Malkovich (1999)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Sixth Sense, The (1999)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Toys (1992)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Fantasia (1940)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Amadeus (1984)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Brothers McMullen, The (1995)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Carrie (1976)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Processed 10 users. Pausing for 60 seconds...
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Election (1999)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Howards End (1992)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Man for All Seasons, A (1966)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Dances with Wolves (1990)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Clear and Present Danger (1994)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Iron Eagle (1986)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: And Now for Something Completely Different (1971)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Ghost Dog: The Way of the Samurai (1999)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Queen Margot (La Reine Margot) (1994)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Processed 20 users. Pausing for 60 seconds...
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Man Who Would Be King, The (1975)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Hand That Rocks the Cradle, The (1992)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Henry V (1989)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Platoon (1986)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: One Flew Over the Cuckoo's Nest (1975)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Nikita (La Femme Nikita) (1990)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Dangerous Liaisons (1988)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Evita (1996)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: But I'm a Cheerleader (1999)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Bringing Out the Dead (1999)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Processed 30 users. Pausing for 60 seconds...
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Some Like It Hot (1959)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Holiday Inn (1942)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Vertigo (1958)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Police Academy (1984)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Starship Troopers (1997)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: What's Eating Gilbert Grape (1993)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Nightmare on Elm Street, A (1984)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Man Who Knew Too Much, The (1956)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Misery (1990)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Mighty Aphrodite (1995)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Processed 40 users. Pausing for 60 seconds...
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Addams Family, The (1991)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Mission: Impossible 2 (2000)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Pretty Woman (1990)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Ulee's Gold (1997)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Beach Party (1963)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Manon of the Spring (Manon des sources) (1986)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Donnie Brasco (1997)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Bio-Dome (1996)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Beetlejuice (1988)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Clan of the Cave Bear, The (1986)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Processed 50 users. Pausing for 60 seconds...
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Usual Suspects, The (1995)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Miracle on 34th Street (1947)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Pitch Black (2000)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Prizzi's Honor (1985)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********
#
#
#
# System Fingerprint: fp_cbe4fa03fe
#
# API call response: "4"
# Extracted rating: 4.0
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this product Title: Raging Bull (1980)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
# **********

# %%
# Read the data
zeroshot_saved_data = pd.read_csv(ZERO_SHOT_SAVE_PATH)

# Display the original data types
print("Original Data Types:")
print(zeroshot_saved_data.dtypes)
print("\n")

# Attempt to convert ratings to float and add a flag for conversion failure
zeroshot_saved_data['is_rating_float'] = pd.to_numeric(zeroshot_saved_data['predicted_rating'], errors='coerce').notna()

# Filter rows where ratings are not float
non_float_ratings = zeroshot_saved_data[zeroshot_saved_data['is_rating_float'] == False]

# total number of rows with non-float ratings
print(f"Total number of rows with non-float ratings: {len(non_float_ratings)}")

# rerun indices for non-float ratings
rerun_indices = non_float_ratings.index.tolist()
print(f"Rerun indices: {rerun_indices}")

# Display rows with non-float ratings
print("Rows with non-float ratings:")
non_float_ratings.head(3)

# %%
# %%time

data = pd.read_csv(ZERO_SHOT_SAVE_PATH)

# Rerun predictions for failed cases and save the updated data
rerun_save_path = os.path.join(DATA_DIR, 'movie-ml-latest-small/output/rerun_title_large_predictions_zero_shot.csv')
columns_for_prediction = ['title']
updated_data = rerun_failed_zero_shot_predictions(data, ZERO_SHOT_SAVE_PATH, rerun_save_path, columns_for_prediction, PAUSE_EVERY_N_USERS, SLEEP_TIME)

# Remove rows with non-float ratings and save the cleaned data
cleaned_data = updated_data[pd.to_numeric(updated_data['predicted_rating'], errors='coerce').notna()]
cleaned_data.to_csv(ZERO_SHOT_SAVE_PATH, index=False)

# Evaluate the model predictions
evaluate_model_predictions_rmse_mae(ZERO_SHOT_SAVE_PATH, NUM_EXAMPLES, 'actual_rating', 'predicted_rating')

# %% [markdown]
# # Few-shot (OpenAI API)
#
#
# + For each user, we'll use 4 of their ratings as training data to predict ratings for the rest of their products. Finally, we'll evaluate the predictions against the actual ratings to calculate the overall RMSE and MAE.
#
# + The rating_history_str now includes both the title and the review text for each of the training data rows

# %% [markdown]
# # 1 observation per reviewer - Few-shot OpenAI

# %%
# %%time

predict_ratings_few_shot_and_save(data,
                                      columns_for_training=[TITLE_COLUMN_NAME],
                                       columns_for_prediction=[TITLE_COLUMN_NAME],
                                       title_column_name=TITLE_COLUMN_NAME, 
                                       user_column_name=USER_COLUMN_NAME,
                                       asin_column_name=ITEM_ID_COLUMN,
                                       rating_column_name=RATING_COLUMN_NAME,
                                       obs_per_user=1,
                                       pause_every_n_users=PAUSE_EVERY_N_USERS,
                                       sleep_time=SLEEP_TIME,
                                       save_path=FEW_SHOT_1_OBS_SAVE_PATH,
                                       system_content=SYSTEM_CONTENT)

# %%
# Read the data
fewshot_saved_data = pd.read_csv(FEW_SHOT_1_OBS_SAVE_PATH)

# Display the original data types
print("Original Data Types:")
print(fewshot_saved_data.dtypes)
print("\n")

# Attempt to convert ratings to float and add a flag for conversion failure
fewshot_saved_data['is_rating_float'] = pd.to_numeric(fewshot_saved_data['predicted_rating'], errors='coerce').notna()

# Filter rows where ratings are not float
non_float_ratings = fewshot_saved_data[fewshot_saved_data['is_rating_float'] == False]

# total number of rows with non-float ratings
print(f"Total number of rows with non-float ratings: {len(non_float_ratings)}")

# rerun indices for non-float ratings
rerun_indices = non_float_ratings.index.tolist()
print(f"Rerun indices: {rerun_indices}")

# Display rows with non-float ratings
print("Rows with non-float ratings:")
non_float_ratings.head(3)

# %%
# %%time 

rerun_failed_few_shot_predictions(data, 
                                  columns_for_training=[TITLE_COLUMN_NAME],
                                  columns_for_prediction=[TITLE_COLUMN_NAME],
                                  user_column_name=USER_COLUMN_NAME,
                                  title_column_name=TITLE_COLUMN_NAME,
                                  asin_column_name=ITEM_ID_COLUMN,
                                  rating_column_name=RATING_COLUMN_NAME,
                                  obs_per_user=1,
                                  pause_every_n_users=PAUSE_EVERY_N_USERS,
                                  sleep_time=SLEEP_TIME,
                                  save_path=FEW_SHOT_1_OBS_SAVE_PATH, 
                                  new_path=FEW_SHOT_1_OBS_RERUN_PATH,
                                  rerun_indices=rerun_indices,
                                  system_content=SYSTEM_CONTENT)

# %%
# Read the data
fewshot_saved_data = pd.read_csv(FEW_SHOT_1_OBS_RERUN_PATH)

# Display the original data types
print("Original Data Types:")
print(fewshot_saved_data.dtypes)
print("\n")

# Attempt to convert ratings to float and add a flag for conversion failure
fewshot_saved_data['is_rating_float'] = pd.to_numeric(fewshot_saved_data['predicted_rating'], errors='coerce').notna()

# Filter rows where ratings are not float
non_float_ratings = fewshot_saved_data[fewshot_saved_data['is_rating_float'] == False]

# total number of rows with non-float ratings
print(f"Total number of rows with non-float ratings: {len(non_float_ratings)}")

# rerun indices for non-float ratings
rerun_indices = non_float_ratings.index.tolist()
print(f"Rerun indices: {rerun_indices}")

# Display rows with non-float ratings
print("Rows with non-float ratings:")
non_float_ratings.head(3)

# %%
evaluate_model_predictions_rmse_mae(
    data_path=FEW_SHOT_1_OBS_RERUN_PATH,
    num_examples=NUM_EXAMPLES,
    actual_ratings_column='actual_rating',
    predicted_ratings_column='predicted_rating'
)

# %% [markdown]
# # Limitations:
#
# The model might not fully understand the nuanced relationships between products based on titles alone. Additional context or features might be needed for more accurate predictions.
# This approach might be computationally expensive and slower than traditional matrix factorization or deep learning-based recommendation models, especially for a large number of users.
#
# # References
#
# + https://platform.openai.com/docs/api-reference/authentication
