# %%
import numpy as np
import openai
import pandas as pd
import os
import sys
import time
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import openai
# Add the path to the constants file to the system path
sys.path.append('../../')
from constants import *
from evaluation_utils import *
from path_utils import *
from ChatCompletion_OpenAI_API import *
from CF_utils import *

# OpenAI API Key
openai.api_key = OPENAI_API_KEY

# %%
# source code folder path
rec_sys_dir = get_rec_sys_directory()
print(f"Rec-sys directory: {rec_sys_dir}")

# data folder path
DATA_DIR = os.path.join(rec_sys_dir, 'data')
print(f"Data directory: {DATA_DIR}")

# data path
data_path = os.path.join(DATA_DIR, 'movie-ml-latest-small/merged_data.csv')
print(f'Data path: {data_path}')


# few shot save path
CF_FEW_SHOT_1_OBS_SAVE_PATH = os.path.join(DATA_DIR, 'movie-ml-latest-small/CF_large_1_test_predictions_few_shot.csv')
print(f'Few shot save path: {CF_FEW_SHOT_1_OBS_SAVE_PATH}')
# Out:
# Rec-sys directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys
# Data directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data
# Data path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/movie-ml-latest-small/merged_data.csv
# Few shot save path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/movie-ml-latest-small/CF_large_1_test_predictions_few_shot.csv

# %%
# Read the data
data = pd.read_csv(data_path)

# get statistic and first few data of NUM_SAMPLES rows
data.info()
data.head(NUM_EXAMPLES)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3405 entries, 0 to 3404
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  3405 non-null   int64
#  1   imdbId   3405 non-null   int64
#  2   tmdbId   3405 non-null   float64
#  3   title    3405 non-null   object
#  4   genres   3405 non-null   object
#  5   userId   3405 non-null   int64
#  6   rating   3405 non-null   float64
#  7   tag      3405 non-null   object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 212.9+ KB
#    movieId  imdbId  tmdbId             title  \
# 0        1  114709   862.0  Toy Story (1995)
# 1        1  114709   862.0  Toy Story (1995)
# 2        1  114709   862.0  Toy Story (1995)
# 3        2  113497  8844.0    Jumanji (1995)
# 4        2  113497  8844.0    Jumanji (1995)
#
#                                         genres  userId  rating  \
# 0  Adventure|Animation|Children|Comedy|Fantasy     336     4.0
# 1  Adventure|Animation|Children|Comedy|Fantasy     474     4.0
# 2  Adventure|Animation|Children|Comedy|Fantasy     567     3.5
# 3                   Adventure|Children|Fantasy      62     4.0
# 4                   Adventure|Children|Fantasy      62     4.0
#
#                 tag
# 0             pixar
# 1             pixar
# 2               fun
# 3           fantasy
# 4  magic board game

# %%
import numpy as np
import openai
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error
import re
import time
from constants import *
from evaluation_utils import *
from utils import *
from CF_utils import *
from tenacity import retry, wait_random_exponential, stop_after_attempt
import tiktoken
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
import openai
from openai.error import APIError, APIConnectionError, RateLimitError


@retry_decorator
def predict_rating_combined_ChatCompletion(combined_text, 
                                           model=GPT_MODEL_NAME, 
                                           temperature=TEMPERATURE, 
                                           approach="zero-shot", 
                                           rating_history=None, 
                                           similar_users_ratings=None, 
                                           seed=RANDOM_STATE, 
                                           system_content=AMAZON_CONTENT_SYSTEM):
    # Validation
    if approach == "few-shot" and rating_history is None:
        raise ValueError("Rating history is required for the few-shot approach.")
    if approach == "CF" and similar_users_ratings is None:
        raise ValueError("Similar users' ratings are required for the collaborative filtering approach.")
    if not system_content:
        raise ValueError("System content is required.")

    # Check and reduce length of combined_text
    combined_text = check_and_reduce_length(combined_text, MAX_TOKENS_CHAT_GPT // 3, TOKENIZER)
    prompt = f"How will user rate this {combined_text}? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text."

    # Construct the prompt based on the approach
    if approach == "few-shot":
        rating_history = check_and_reduce_length(rating_history, MAX_TOKENS_CHAT_GPT // 3, TOKENIZER)
        prompt += f"\n\nHere is user rating history:\n{rating_history}"

    elif approach == "CF":
        similar_users_ratings = check_and_reduce_length(similar_users_ratings, MAX_TOKENS_CHAT_GPT // 3, TOKENIZER)
        prompt += f"\n\nHere are the rating history from users who are similar to this user:\n{similar_users_ratings}"

    # Adding end of the prompt
    prompt += "\n\nBased on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)"

    print(f"Constructed Prompt for {approach} approach:\n")
    print(f'The prompt:\n**********\n{prompt}\n**********\n')

    try:
        # Create the API call
        response = openai.ChatCompletion.create(
            model=model,
            temperature=temperature,
            max_tokens=MAX_TOKENS_CHAT_GPT,
            seed=seed,
            messages=[
                {"role": "system", "content": system_content},
                {"role": "user", "content": prompt}
            ]
        )
        # Extract the system fingerprint and print it
        system_fingerprint = response.get('system_fingerprint')
        print(f"\n\nSystem Fingerprint: {system_fingerprint}")
        # Extract and return the rating
        rating_text = response.choices[0].message['content'].strip()
        print(f'\nAPI call response: "{rating_text}"')
        extracted_rating = extract_numeric_rating(rating_text)
        print(f'Extracted rating: {extracted_rating}')
        return extracted_rating  # Ensure this is a float
    
    except APIError as api_err:
        print(f"API Error occurred: {api_err}")
        return None, str(api_err)
    except RateLimitError as rate_err:
        print(f"Rate Limit Error occurred: {rate_err}")
        return None, str(rate_err)
    except Exception as e:
        print(f"Unexpected Error: {e}")
        return None, str(e)



def predict_ratings_with_collaborative_filtering_and_save(data, interaction_matrix, user_mapper, item_mapper, user_inv_mapper, 
                                                          model_knn, columns_for_training, columns_for_prediction,
                                                          title_column_name='title', 
                                                          user_column_name='reviewerID',
                                                          asin_column_name='asin',
                                                          obs_per_user=None, 
                                                          pause_every_n_users=5, 
                                                          sleep_time=5,
                                                          save_path='collaborative_filtering_predictions.csv'):
    all_similar_users_ratings = get_all_similar_users_ratings(data, user_mapper, user_inv_mapper, model_knn, interaction_matrix, title_column_name)
    results = []

    for idx, user_id in enumerate(data[user_column_name].unique()):
        user_data = data[data[user_column_name] == user_id].sample(frac=1, random_state=42).reset_index(drop=True)
        print(f"\n-------------------\nUser {user_id} ({idx + 1}/{len(data[user_column_name].unique())}):")
        if len(user_data) < 5:
            print(f"Insufficient data points for user {user_id}, skipping...")
            continue

        for test_idx, test_row in user_data.iterrows():
            train_data = user_data[user_data[asin_column_name] != test_row[asin_column_name]]
            n_train_items = min(4, len(train_data))
            if n_train_items == 0:
                print(f"No training data for user {user_id}, item {test_row[asin_column_name]}, skipping...")
                continue

            similar_users_ratings_str = format_similar_users_ratings(all_similar_users_ratings.get(user_id))
            if not similar_users_ratings_str:
                print(f"No similar users' ratings found for user {user_id}, skipping prediction.")
                continue

            prediction_data = {col: test_row[col] for col in columns_for_prediction if col != 'rating'}
            combined_text = generate_combined_text_for_prediction(columns_for_prediction, *prediction_data.values())

            try:
                predicted_rating, error_message = predict_rating_combined_ChatCompletion(
                    combined_text,
                    rating_history=similar_users_ratings_str,
                    approach="CF"
                )
                if predicted_rating is None:
                    print(f"\nPrediction error: {error_message}, skipping...")
                    continue
            except Exception as e:
                print(f"\nError during prediction: {e}, skipping...")
                continue

            item_id = test_row[asin_column_name]
            actual_rating = test_row['rating']
            title = test_row[title_column_name]

            results.append([user_id, item_id, title, actual_rating, predicted_rating])

            print(f"Predicted Rating - {predicted_rating} stars for '{title}' (Item ID: {item_id})")

            if obs_per_user and len(results) >= obs_per_user:
                break

        if (idx + 1) % pause_every_n_users == 0:
            print(f"\nProcessed {idx + 1} users, pausing for {sleep_time} seconds...")
            time.sleep(sleep_time)

    # Save results to CSV
    results_df = pd.DataFrame(results, columns=['user_id', 'item_id', 'title', 'actual_rating', 'predicted_rating'])
    results_df.to_csv(save_path, index=False)

    print("Predictions completed and saved.")

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
from utils import *
from constants import *
from tenacity import retry, stop_after_attempt, wait_random_exponential
import random


# Create Interaction Matrix
def create_interaction_matrix(df, user_col, item_col, rating_col, threshold=1):
    interactions = df.groupby([user_col, item_col])[rating_col].sum().unstack().reset_index().fillna(0).set_index(user_col)
    interactions = interactions.applymap(lambda x: 1 if x >= threshold else 0)
    user_mapper = dict(zip(np.unique(df[user_col]), list(range(df[user_col].nunique()))))
    item_mapper = dict(zip(np.unique(df[item_col]), list(range(df[item_col].nunique()))))
    user_inv_mapper = dict(zip(list(range(df[user_col].nunique())), np.unique(df[user_col])))
    item_inv_mapper = dict(zip(list(range(df[item_col].nunique())), np.unique(df[item_col])))
    return csr_matrix(interactions.values), user_mapper, item_mapper, user_inv_mapper, item_inv_mapper



def fit_knn_model(interaction_matrix, n_neighbors=4):
    """
    Fit the k-Nearest Neighbors model.

    Args:
        interaction_matrix (csr_matrix): User-item interaction matrix.
        n_neighbors (int): Number of neighbors to consider.

    Returns:
        NearestNeighbors: Trained kNN model.
    """
    model_knn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=n_neighbors, n_jobs=-1)
    model_knn.fit(interaction_matrix)
    return model_knn

def recommend_items(user_id, interaction_matrix, user_mapper, item_inv_mapper, model_knn, n_recommendations=4):
    """
    Recommend items for a given user based on kNN model.

    Args:
        user_id (str): User ID for whom to make recommendations.
        interaction_matrix (csr_matrix): User-item interaction matrix.
        user_mapper (dict): Dictionary mapping user ID to user index.
        item_inv_mapper (dict): Dictionary mapping item index to item ID.
        model_knn (NearestNeighbors): Trained kNN model.
        n_recommendations (int): Number of recommendations to make.

    Returns:
        list: List of recommended item IDs.
    """
    user_idx = user_mapper[user_id]
    distances, indices = model_knn.kneighbors(interaction_matrix[user_idx], n_neighbors=n_recommendations+1)
    
    raw_recommends = sorted(list(zip(indices.squeeze().tolist(), distances.squeeze().tolist())), key=lambda x: x[1])[:0:-1]
    recommendations = [item_inv_mapper[idx] for idx, dist in raw_recommends if idx != user_idx]

    return recommendations



# source RMIT courses
def pearson_correlation(interaction_matrix):
    """
    Compute the Pearson Correlation Coefficient matrix for the user-item interaction matrix.

    Args:
    interaction_matrix (numpy.ndarray): A 2D array where rows represent users and columns represent items.
                                        The values in the matrix are the ratings given by users to items.

    Returns:
    numpy.ndarray: A 2D array representing the Pearson Correlation Coefficients between each pair of users.
    """

    # Get the number of users
    n_users = interaction_matrix.shape[0]

    # Initialize the Pearson Correlation matrix with zeros
    pearson_corr_matrix = np.zeros((n_users, n_users))

    # Small constant to avoid division by zero
    EPSILON = 1e-9

    # Iterate over each pair of users
    for i in range(n_users):
        for j in range(n_users):
            # Get the rating vectors for the current pair of users
            user_i_vec = interaction_matrix[i, :]
            user_j_vec = interaction_matrix[j, :]

            # Create masks for ratings greater than 0 (indicating rated items)
            mask_i = user_i_vec > 0
            mask_j = user_j_vec > 0

            # Find indices of corrated items (items rated by both users)
            corrated_index = np.intersect1d(np.where(mask_i), np.where(mask_j))

            # Skip if no items are corrated
            if len(corrated_index) == 0:
                continue

            # Compute the mean rating for each user over corrated items
            mean_user_i = np.mean(user_i_vec[corrated_index])
            mean_user_j = np.mean(user_j_vec[corrated_index])

            # Compute the deviations from the mean for each user
            user_i_sub_mean = user_i_vec[corrated_index] - mean_user_i
            user_j_sub_mean = user_j_vec[corrated_index] - mean_user_j

            # Calculate the components for Pearson correlation
            r_ui_sub_r_i_sq = np.square(user_i_sub_mean)
            r_uj_sub_r_j_sq = np.square(user_j_sub_mean)

            r_ui_sum_sqrt = np.sqrt(np.sum(r_ui_sub_r_i_sq))
            r_uj_sum_sqrt = np.sqrt(np.sum(r_uj_sub_r_j_sq))

            # Calculate Pearson correlation and handle division by zero
            sim = np.sum(user_i_sub_mean * user_j_sub_mean) / (r_ui_sum_sqrt * r_uj_sum_sqrt + EPSILON)

            # Store the similarity in the matrix
            pearson_corr_matrix[i, j] = sim

    return pearson_corr_matrix




def cosine_similarity_manual(interaction_matrix):
    """
    Compute the Cosine Similarity matrix for the user-item interaction matrix.

    Args:
    interaction_matrix (numpy.ndarray): A 2D array where rows represent users and columns represent items.
                                        The values in the matrix are the ratings given by users to items.

    Returns:
    numpy.ndarray: A 2D array representing the Cosine Similarities between each pair of users.
    """

    # Get the number of users
    n_users = interaction_matrix.shape[0]

    # Initialize the Cosine Similarity matrix with zeros
    cosine_sim_matrix = np.zeros((n_users, n_users))

    # Iterate over each pair of users
    for i in range(n_users):
        for j in range(n_users):
            # Get the rating vectors for the current pair of users
            user_i_vec = interaction_matrix[i, :]
            user_j_vec = interaction_matrix[j, :]

            # Compute the dot product between the two vectors
            dot_product = np.dot(user_i_vec, user_j_vec)

            # Compute the magnitude (norm) of each vector
            norm_i = np.linalg.norm(user_i_vec)
            norm_j = np.linalg.norm(user_j_vec)

            # Calculate cosine similarity (handling division by zero)
            if norm_i == 0 or norm_j == 0:
                # If a vector has magnitude 0, the similarity is set to 0
                similarity = 0
            else:
                similarity = dot_product / (norm_i * norm_j)

            # Store the similarity in the matrix
            cosine_sim_matrix[i, j] = similarity

    return cosine_sim_matrix

# Function to get all similar users' ratings
def get_all_similar_users_ratings(data, user_mapper, user_inv_mapper, model_knn, interaction_matrix, title_column_name='title', user_column_name='userId'):
    all_similar_users_ratings = {}
    for user_id in data[user_column_name].unique():
        similar_users_ratings = []
        user_idx = user_mapper.get(user_id)
        if user_idx is None:
            continue
        distances, indices = model_knn.kneighbors(interaction_matrix[user_idx], n_neighbors=20)
        for idx in indices.flatten():
            if idx == user_idx:
                continue
            similar_user_id = user_inv_mapper[idx]
            similar_user_data = data[data[user_column_name] == similar_user_id]
            sampled_ratings = similar_user_data.sample(n=min(5, len(similar_user_data)), random_state=42)
            for _, row in sampled_ratings.iterrows():
                similar_users_ratings.append(f"{row[title_column_name]} ({row['rating']} stars)")
        all_similar_users_ratings[user_id] = similar_users_ratings
    return all_similar_users_ratings

# Fallback strategy
def fallback_prediction_strategy(item_id, data):
    return data[data['movieId'] == item_id]['rating'].mean()

# Function to format similar users' ratings
def format_similar_users_ratings(similar_users_ratings):
    if not isinstance(similar_users_ratings, dict):
        return ''
    formatted_ratings = []
    for user_id, ratings in similar_users_ratings.items():
        formatted_ratings.append(f"\n\n{user_id}:")
        for rating in ratings:
            formatted_ratings.append(f"+ {rating}")
    return '\n'.join(formatted_ratings)


# Function to check data sparsity
def check_data_sparsity(df, user_col, item_col):
    total_ratings = len(df)
    num_users = df[user_col].nunique()
    num_items = df[item_col].nunique()
    sparsity = 1 - (total_ratings / (num_users * num_items))
    print(f"Total Ratings: {total_ratings}, Number of Users: {num_users}, Number of Items: {num_items}, Sparsity: {sparsity}")



def predict_ratings_with_collaborative_filtering_and_save(data, interaction_matrix, user_mapper, item_mapper, user_inv_mapper, 
                                                          model_knn, columns_for_training, columns_for_prediction,
                                                          title_column_name='title', 
                                                          user_column_name='userId',
                                                          asin_column_name='asin',
                                                          obs_per_user=None, 
                                                          pause_every_n_users=5, 
                                                          sleep_time=5,
                                                          save_path='collaborative_filtering_predictions.csv'):
    all_similar_users_ratings = get_all_similar_users_ratings(data, user_mapper, user_inv_mapper, model_knn, interaction_matrix, title_column_name, user_column_name=user_column_name)
    results = []

    for idx, user_id in enumerate(data[user_column_name].unique()):
        user_data = data[data[user_column_name] == user_id].sample(frac=1, random_state=42).reset_index(drop=True)
        print(f"\n-------------------\nUser {user_id} ({idx + 1}/{len(data[user_column_name].unique())}):")

        for test_idx, test_row in user_data.iterrows():
            similar_users_ratings_str = format_similar_users_ratings(all_similar_users_ratings.get(user_id))

            prediction_data = {col: test_row[col] for col in columns_for_prediction if col != 'rating'}
            combined_text = generate_combined_text_for_prediction(columns_for_prediction, *prediction_data.values())

            predicted_rating = None
            if similar_users_ratings_str:
                try:
                    predicted_rating, error_message = predict_rating_combined_ChatCompletion(
                        combined_text,
                        rating_history=similar_users_ratings_str,
                        approach="CF"
                    )
                except Exception as e:
                    print(f"\nError during prediction: {e}")
            
            # Fallback strategy
            if predicted_rating is None:
                print(f"Fallback prediction for user {user_id} on item {test_row[asin_column_name]}")
                predicted_rating = fallback_prediction_strategy(test_row[asin_column_name], data)

            item_id = test_row[asin_column_name]
            actual_rating = test_row['rating']
            title = test_row[title_column_name]
            results.append([user_id, item_id, title, actual_rating, predicted_rating])

        if (idx + 1) % pause_every_n_users == 0:
            print(f"\nProcessed {idx + 1} users, pausing for {sleep_time} seconds...")
            time.sleep(sleep_time)

    results_df = pd.DataFrame(results, columns=['user_id', 'item_id', 'title', 'actual_rating', 'predicted_rating'])
    results_df.to_csv(save_path, index=False)
    print("Predictions completed and saved.")

# %%
check_data_sparsity(data, 'userId', 'movieId')
# Out:
# Total Ratings: 3405, Number of Users: 25, Number of Items: 1451, Sparsity: 0.9061337008959338

# %% [markdown]
# # Collaborative filtering model to predict ratings - User based CF

# %%
user_col = 'userId'   # Column name for users
item_col = 'movieId'         # Column name for items
rating_col = 'rating'     # Column name for ratings

# Create User-Item Interaction Matrix
interaction_matrix, user_mapper, item_mapper, user_inv_mapper, item_inv_mapper = create_interaction_matrix(data, user_col, item_col, rating_col)

# Fit the kNN Model
model_knn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=5, n_jobs=-1)
model_knn.fit(interaction_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1)

# %%
# Function to get top N popular items as a fallback
def get_top_n_popular_items(data, n=10):
    popular_items = data.groupby('movieId')['rating'].count().sort_values(ascending=False).head(n).index.tolist()
    return popular_items


# Fallback strategy
top_n_popular_items = get_top_n_popular_items(data)
top_n_popular_items
# Out:
# [296, 2959, 924, 293, 1732, 7361, 4878, 79132, 135536, 72998]

# %%
# %%time 

predict_ratings_with_collaborative_filtering_and_save(
    data=data,
    interaction_matrix=interaction_matrix,
    user_mapper=user_mapper,
    item_mapper=item_mapper,
    user_inv_mapper=user_inv_mapper,
    model_knn=model_knn,
    columns_for_training=['title'],
    columns_for_prediction=['title'],
    title_column_name='title',  
    user_column_name='userId',
    asin_column_name='movieId',    
    obs_per_user=1,             # Number of observations per user for testing
    save_path=CF_FEW_SHOT_1_OBS_SAVE_PATH
)
# Out:
# -------------------
# User 336 (1/25):
# Fallback prediction for user 336 on item 37729
# Fallback prediction for user 336 on item 552
# Fallback prediction for user 336 on item 34162
# Fallback prediction for user 336 on item 1
# Fallback prediction for user 336 on item 38798
# Fallback prediction for user 336 on item 1246
# Fallback prediction for user 336 on item 33660
# Fallback prediction for user 336 on item 32587
# Fallback prediction for user 336 on item 36529
#
# -------------------
# User 474 (2/25):
# Fallback prediction for user 474 on item 3723
# Fallback prediction for user 474 on item 4809
# Fallback prediction for user 474 on item 1204
# Fallback prediction for user 474 on item 830
# Fallback prediction for user 474 on item 904
# Fallback prediction for user 474 on item 3451
# Fallback prediction for user 474 on item 1975
# Fallback prediction for user 474 on item 237
# Fallback prediction for user 474 on item 5669
# Fallback prediction for user 474 on item 153
# Fallback prediction for user 474 on item 2085
# Fallback prediction for user 474 on item 1995
# Fallback prediction for user 474 on item 3504
# Fallback prediction for user 474 on item 7618
# Fallback prediction for user 474 on item 8622
# Fallback prediction for user 474 on item 6341
# Fallback prediction for user 474 on item 3816
# Fallback prediction for user 474 on item 7121
# Fallback prediction for user 474 on item 2517
# Fallback prediction for user 474 on item 30793
# Fallback prediction for user 474 on item 6178
# Fallback prediction for user 474 on item 3844
# Fallback prediction for user 474 on item 1006
# Fallback prediction for user 474 on item 247
# Fallback prediction for user 474 on item 454
# Fallback prediction for user 474 on item 3536
# Fallback prediction for user 474 on item 3039
# Fallback prediction for user 474 on item 6101
# Fallback prediction for user 474 on item 6454
# Fallback prediction for user 474 on item 6333
# Fallback prediction for user 474 on item 938
# Fallback prediction for user 474 on item 2745
# Fallback prediction for user 474 on item 2206
# Fallback prediction for user 474 on item 1230
# Fallback prediction for user 474 on item 262
# Fallback prediction for user 474 on item 2966
# Fallback prediction for user 474 on item 1104
# Fallback prediction for user 474 on item 1081
# Fallback prediction for user 474 on item 7493
# Fallback prediction for user 474 on item 43
# Fallback prediction for user 474 on item 3420
# Fallback prediction for user 474 on item 1407
# Fallback prediction for user 474 on item 4476
# Fallback prediction for user 474 on item 3384
# Fallback prediction for user 474 on item 920
# Fallback prediction for user 474 on item 6232
# Fallback prediction for user 474 on item 150
# Fallback prediction for user 474 on item 3030
# Fallback prediction for user 474 on item 4160
# Fallback prediction for user 474 on item 27834
# Fallback prediction for user 474 on item 909
# Fallback prediction for user 474 on item 6031
# Fallback prediction for user 474 on item 941
# Fallback prediction for user 474 on item 3552
# Fallback prediction for user 474 on item 260
# Fallback prediction for user 474 on item 1674
# Fallback prediction for user 474 on item 5792
# Fallback prediction for user 474 on item 1732
# Fallback prediction for user 474 on item 3546
# Fallback prediction for user 474 on item 4333
# Fallback prediction for user 474 on item 1537
# Fallback prediction for user 474 on item 111
# Fallback prediction for user 474 on item 6466
# Fallback prediction for user 474 on item 2059
# Fallback prediction for user 474 on item 3859
# Fallback prediction for user 474 on item 1247
# Fallback prediction for user 474 on item 3101
# Fallback prediction for user 474 on item 3910
# Fallback prediction for user 474 on item 2312
# Fallback prediction for user 474 on item 931
# Fallback prediction for user 474 on item 4105
# Fallback prediction for user 474 on item 1354
# Fallback prediction for user 474 on item 1217
# Fallback prediction for user 474 on item 5114
# Fallback prediction for user 474 on item 1303
# Fallback prediction for user 474 on item 1177
# Fallback prediction for user 474 on item 1234
# Fallback prediction for user 474 on item 7132
# Fallback prediction for user 474 on item 6650
# Fallback prediction for user 474 on item 5816
# Fallback prediction for user 474 on item 39292
# Fallback prediction for user 474 on item 1022
# Fallback prediction for user 474 on item 2006
# Fallback prediction for user 474 on item 1244
# Fallback prediction for user 474 on item 110
# Fallback prediction for user 474 on item 2194
# Fallback prediction for user 474 on item 929
# Fallback prediction for user 474 on item 6333
# Fallback prediction for user 474 on item 7382
# Fallback prediction for user 474 on item 7835
# Fallback prediction for user 474 on item 2550
# Fallback prediction for user 474 on item 5064
# Fallback prediction for user 474 on item 6016
# Fallback prediction for user 474 on item 1683
# Fallback prediction for user 474 on item 5505
# Fallback prediction for user 474 on item 8938
# Fallback prediction for user 474 on item 342
# Fallback prediction for user 474 on item 27790
# Fallback prediction for user 474 on item 235
# Fallback prediction for user 474 on item 6201
# Fallback prediction for user 474 on item 2394
# Fallback prediction for user 474 on item 377
# Fallback prediction for user 474 on item 2011
# Fallback prediction for user 474 on item 6984
# Fallback prediction for user 474 on item 1225
# Fallback prediction for user 474 on item 5878
# Fallback prediction for user 474 on item 5505
# Fallback prediction for user 474 on item 2801
# Fallback prediction for user 474 on item 47
# Fallback prediction for user 474 on item 4210
# Fallback prediction for user 474 on item 6852
# Fallback prediction for user 474 on item 596
# Fallback prediction for user 474 on item 7069
# Fallback prediction for user 474 on item 1209
# Fallback prediction for user 474 on item 919
# Fallback prediction for user 474 on item 956
# Fallback prediction for user 474 on item 1500
# Fallback prediction for user 474 on item 736
# Fallback prediction for user 474 on item 39292
# Fallback prediction for user 474 on item 1299
# Fallback prediction for user 474 on item 4641
# Fallback prediction for user 474 on item 2660
# Fallback prediction for user 474 on item 5527
# Fallback prediction for user 474 on item 6269
# Fallback prediction for user 474 on item 7079
# Fallback prediction for user 474 on item 898
# Fallback prediction for user 474 on item 32582
# Fallback prediction for user 474 on item 2494
# Fallback prediction for user 474 on item 7059
# Fallback prediction for user 474 on item 6874
# Fallback prediction for user 474 on item 27878
# Fallback prediction for user 474 on item 1960
# Fallback prediction for user 474 on item 2329
# Fallback prediction for user 474 on item 943
# Fallback prediction for user 474 on item 1032
# Fallback prediction for user 474 on item 230
# Fallback prediction for user 474 on item 6944
# Fallback prediction for user 474 on item 1090
# Fallback prediction for user 474 on item 5034
# Fallback prediction for user 474 on item 1231
# Fallback prediction for user 474 on item 3468
# Fallback prediction for user 474 on item 590
# Fallback prediction for user 474 on item 1219
# Fallback prediction for user 474 on item 45
# Fallback prediction for user 474 on item 950
# Fallback prediction for user 474 on item 6776
# Fallback prediction for user 474 on item 1381
# Fallback prediction for user 474 on item 5747
# Fallback prediction for user 474 on item 6327
# Fallback prediction for user 474 on item 6235
# Fallback prediction for user 474 on item 3811
# Fallback prediction for user 474 on item 3306
# Fallback prediction for user 474 on item 1213
# Fallback prediction for user 474 on item 2064
# Fallback prediction for user 474 on item 3211
# Fallback prediction for user 474 on item 5954
# Fallback prediction for user 474 on item 2422
# Fallback prediction for user 474 on item 1028
# Fallback prediction for user 474 on item 1252
# Fallback prediction for user 474 on item 2078
# Fallback prediction for user 474 on item 3897
# Fallback prediction for user 474 on item 4878
# Fallback prediction for user 474 on item 6863
# Fallback prediction for user 474 on item 2716
# Fallback prediction for user 474 on item 6807
# Fallback prediction for user 474 on item 2554
# Fallback prediction for user 474 on item 8943
# Fallback prediction for user 474 on item 1959
# Fallback prediction for user 474 on item 36517
# Fallback prediction for user 474 on item 2723
# Fallback prediction for user 474 on item 6732
# Fallback prediction for user 474 on item 1977
# Fallback prediction for user 474 on item 4189
# Fallback prediction for user 474 on item 1350
# Fallback prediction for user 474 on item 4396
# Fallback prediction for user 474 on item 6288
# Fallback prediction for user 474 on item 7705
# Fallback prediction for user 474 on item 216
# Fallback prediction for user 474 on item 3451
# Fallback prediction for user 474 on item 1663
# Fallback prediction for user 474 on item 2628
# Fallback prediction for user 474 on item 36
# Fallback prediction for user 474 on item 350
# Fallback prediction for user 474 on item 8464
# Fallback prediction for user 474 on item 3028
# Fallback prediction for user 474 on item 34542
# Fallback prediction for user 474 on item 7073
# Fallback prediction for user 474 on item 1207
# Fallback prediction for user 474 on item 976
# Fallback prediction for user 474 on item 4857
# Fallback prediction for user 474 on item 1797
# Fallback prediction for user 474 on item 6368
# Fallback prediction for user 474 on item 2421
# Fallback prediction for user 474 on item 3097
# Fallback prediction for user 474 on item 6944
# Fallback prediction for user 474 on item 2064
# Fallback prediction for user 474 on item 1223
# Fallback prediction for user 474 on item 6770
# Fallback prediction for user 474 on item 858
# Fallback prediction for user 474 on item 2424
# Fallback prediction for user 474 on item 477
# Fallback prediction for user 474 on item 7053
# Fallback prediction for user 474 on item 272
# Fallback prediction for user 474 on item 8951
# Fallback prediction for user 474 on item 1237
# Fallback prediction for user 474 on item 6377
# Fallback prediction for user 474 on item 3044
# Fallback prediction for user 474 on item 1345
# Fallback prediction for user 474 on item 357
# Fallback prediction for user 474 on item 7361
# Fallback prediction for user 474 on item 6101
# Fallback prediction for user 474 on item 6768
# Fallback prediction for user 474 on item 7070
# Fallback prediction for user 474 on item 947
# Fallback prediction for user 474 on item 4184
# Fallback prediction for user 474 on item 2202
# Fallback prediction for user 474 on item 1101
# Fallback prediction for user 474 on item 648
# Fallback prediction for user 474 on item 3174
# Fallback prediction for user 474 on item 30749
# Fallback prediction for user 474 on item 2066
# Fallback prediction for user 474 on item 2194
# Fallback prediction for user 474 on item 8638
# Fallback prediction for user 474 on item 2640
# Fallback prediction for user 474 on item 1025
# Fallback prediction for user 474 on item 2410
# Fallback prediction for user 474 on item 6218
# Fallback prediction for user 474 on item 4993
# Fallback prediction for user 474 on item 2959
# Fallback prediction for user 474 on item 39292
# Fallback prediction for user 474 on item 5601
# Fallback prediction for user 474 on item 7451
# Fallback prediction for user 474 on item 5690
# Fallback prediction for user 474 on item 7440
# Fallback prediction for user 474 on item 6339
# Fallback prediction for user 474 on item 4623
# Fallback prediction for user 474 on item 8337
# Fallback prediction for user 474 on item 6422
# Fallback prediction for user 474 on item 5629
# Fallback prediction for user 474 on item 2336
# Fallback prediction for user 474 on item 3712
# Fallback prediction for user 474 on item 2919
# Fallback prediction for user 474 on item 7162
# Fallback prediction for user 474 on item 1029
# Fallback prediction for user 474 on item 5603
# Fallback prediction for user 474 on item 1643
# Fallback prediction for user 474 on item 8341
# Fallback prediction for user 474 on item 199
# Fallback prediction for user 474 on item 3095
# Fallback prediction for user 474 on item 2300
# Fallback prediction for user 474 on item 2470
# Fallback prediction for user 474 on item 8695
# Fallback prediction for user 474 on item 6101
# Fallback prediction for user 474 on item 2186
# Fallback prediction for user 474 on item 3683
# Fallback prediction for user 474 on item 971
# Fallback prediction for user 474 on item 282
# Fallback prediction for user 474 on item 26776
# Fallback prediction for user 474 on item 39234
# Fallback prediction for user 474 on item 1423
# Fallback prediction for user 474 on item 1374
# Fallback prediction for user 474 on item 3385
# Fallback prediction for user 474 on item 921
# Fallback prediction for user 474 on item 364
# Fallback prediction for user 474 on item 1942
# Fallback prediction for user 474 on item 2412
# Fallback prediction for user 474 on item 647
# Fallback prediction for user 474 on item 1380
# Fallback prediction for user 474 on item 4812
# Fallback prediction for user 474 on item 6547
# Fallback prediction for user 474 on item 4600
# Fallback prediction for user 474 on item 6874
# Fallback prediction for user 474 on item 6708
# Fallback prediction for user 474 on item 46
# Fallback prediction for user 474 on item 911
# Fallback prediction for user 474 on item 4210
# Fallback prediction for user 474 on item 33493
# Fallback prediction for user 474 on item 3087
# Fallback prediction for user 474 on item 33154
# Fallback prediction for user 474 on item 40629
# Fallback prediction for user 474 on item 778
# Fallback prediction for user 474 on item 1136
# Fallback prediction for user 474 on item 5064
# Fallback prediction for user 474 on item 2494
# Fallback prediction for user 474 on item 3386
# Fallback prediction for user 474 on item 1711
# Fallback prediction for user 474 on item 150
# Fallback prediction for user 474 on item 551
# Fallback prediction for user 474 on item 2203
# Fallback prediction for user 474 on item 6331
# Fallback prediction for user 474 on item 1135
# Fallback prediction for user 474 on item 6337
# Fallback prediction for user 474 on item 3072
# Fallback prediction for user 474 on item 5398
# Fallback prediction for user 474 on item 2797
# Fallback prediction for user 474 on item 6041
# Fallback prediction for user 474 on item 4190
# Fallback prediction for user 474 on item 6948
# Fallback prediction for user 474 on item 1187
# Fallback prediction for user 474 on item 37741
# Fallback prediction for user 474 on item 6502
# Fallback prediction for user 474 on item 6552
# Fallback prediction for user 474 on item 6708
# Fallback prediction for user 474 on item 1212
# Fallback prediction for user 474 on item 3114
# Fallback prediction for user 474 on item 1959
# Fallback prediction for user 474 on item 6909
# Fallback prediction for user 474 on item 8338
# Fallback prediction for user 474 on item 947
# Fallback prediction for user 474 on item 2987
# Fallback prediction for user 474 on item 6242
# Fallback prediction for user 474 on item 2804
# Fallback prediction for user 474 on item 4046
# Fallback prediction for user 474 on item 1954
# Fallback prediction for user 474 on item 26662
# Fallback prediction for user 474 on item 1500
# Fallback prediction for user 474 on item 1301
# Fallback prediction for user 474 on item 3475
# Fallback prediction for user 474 on item 162
# Fallback prediction for user 474 on item 2167
# Fallback prediction for user 474 on item 7160
# Fallback prediction for user 474 on item 1147
# Fallback prediction for user 474 on item 6870
# Fallback prediction for user 474 on item 356
# Fallback prediction for user 474 on item 4678
# Fallback prediction for user 474 on item 6400
# Fallback prediction for user 474 on item 2302
# Fallback prediction for user 474 on item 3730
# Fallback prediction for user 474 on item 5450
# Fallback prediction for user 474 on item 1089
# Fallback prediction for user 474 on item 1358
# Fallback prediction for user 474 on item 4025
# Fallback prediction for user 474 on item 2463
# Fallback prediction for user 474 on item 1080
# Fallback prediction for user 474 on item 30812
# Fallback prediction for user 474 on item 2641
# Fallback prediction for user 474 on item 474
# Fallback prediction for user 474 on item 1356
# Fallback prediction for user 474 on item 2171
# Fallback prediction for user 474 on item 7728
# Fallback prediction for user 474 on item 1240
# Fallback prediction for user 474 on item 608
# Fallback prediction for user 474 on item 4857
# Fallback prediction for user 474 on item 1210
# Fallback prediction for user 474 on item 6163
# Fallback prediction for user 474 on item 910
# Fallback prediction for user 474 on item 1299
# Fallback prediction for user 474 on item 515
# Fallback prediction for user 474 on item 8424
# Fallback prediction for user 474 on item 5446
# Fallback prediction for user 474 on item 2411
# Fallback prediction for user 474 on item 1254
# Fallback prediction for user 474 on item 5008
# Fallback prediction for user 474 on item 899
# Fallback prediction for user 474 on item 5673
# Fallback prediction for user 474 on item 8368
# Fallback prediction for user 474 on item 31658
# Fallback prediction for user 474 on item 1272
# Fallback prediction for user 474 on item 17
# Fallback prediction for user 474 on item 529
# Fallback prediction for user 474 on item 1608
# Fallback prediction for user 474 on item 1059
# Fallback prediction for user 474 on item 1093
# Fallback prediction for user 474 on item 2054
# Fallback prediction for user 474 on item 1084
# Fallback prediction for user 474 on item 1983
# Fallback prediction for user 474 on item 5238
# Fallback prediction for user 474 on item 6327
# Fallback prediction for user 474 on item 3044
# Fallback prediction for user 474 on item 2502
# Fallback prediction for user 474 on item 1197
# Fallback prediction for user 474 on item 1188
# Fallback prediction for user 474 on item 6350
# Fallback prediction for user 474 on item 6579
# Fallback prediction for user 474 on item 1735
# Fallback prediction for user 474 on item 500
# Fallback prediction for user 474 on item 1645
# Fallback prediction for user 474 on item 6963
# Fallback prediction for user 474 on item 32584
# Fallback prediction for user 474 on item 2247
# Fallback prediction for user 474 on item 6936
# Fallback prediction for user 474 on item 7932
# Fallback prediction for user 474 on item 2291
# Fallback prediction for user 474 on item 586
# Fallback prediction for user 474 on item 7301
# Fallback prediction for user 474 on item 8094
# Fallback prediction for user 474 on item 1344
# Fallback prediction for user 474 on item 2968
# Fallback prediction for user 474 on item 7323
# Fallback prediction for user 474 on item 5820
# Fallback prediction for user 474 on item 3996
# Fallback prediction for user 474 on item 3801
# Fallback prediction for user 474 on item 2122
# Fallback prediction for user 474 on item 5135
# Fallback prediction for user 474 on item 27820
# Fallback prediction for user 474 on item 7932
# Fallback prediction for user 474 on item 318
# Fallback prediction for user 474 on item 41566
# Fallback prediction for user 474 on item 1363
# Fallback prediction for user 474 on item 2139
# Fallback prediction for user 474 on item 5603
# Fallback prediction for user 474 on item 556
# Fallback prediction for user 474 on item 5791
# Fallback prediction for user 474 on item 5690
# Fallback prediction for user 474 on item 1367
# Fallback prediction for user 474 on item 1345
# Fallback prediction for user 474 on item 1267
# Fallback prediction for user 474 on item 2097
# Fallback prediction for user 474 on item 3512
# Fallback prediction for user 474 on item 7234
# Fallback prediction for user 474 on item 2145
# Fallback prediction for user 474 on item 5012
# Fallback prediction for user 474 on item 7219
# Fallback prediction for user 474 on item 1125
# Fallback prediction for user 474 on item 1945
# Fallback prediction for user 474 on item 2115
# Fallback prediction for user 474 on item 6890
# Fallback prediction for user 474 on item 3421
# Fallback prediction for user 474 on item 3052
# Fallback prediction for user 474 on item 27790
# Fallback prediction for user 474 on item 1214
# Fallback prediction for user 474 on item 6565
# Fallback prediction for user 474 on item 457
# Fallback prediction for user 474 on item 671
# Fallback prediction for user 474 on item 1080
# Fallback prediction for user 474 on item 30850
# Fallback prediction for user 474 on item 6932
# Fallback prediction for user 474 on item 1088
# Fallback prediction for user 474 on item 1413
# Fallback prediction for user 474 on item 6609
# Fallback prediction for user 474 on item 30820
# Fallback prediction for user 474 on item 8914
# Fallback prediction for user 474 on item 4808
# Fallback prediction for user 474 on item 936
# Fallback prediction for user 474 on item 296
# Fallback prediction for user 474 on item 3910
# Fallback prediction for user 474 on item 6031
# Fallback prediction for user 474 on item 4027
# Fallback prediction for user 474 on item 2248
# Fallback prediction for user 474 on item 8809
# Fallback prediction for user 474 on item 32582
# Fallback prediction for user 474 on item 2431
# Fallback prediction for user 474 on item 4191
# Fallback prediction for user 474 on item 3469
# Fallback prediction for user 474 on item 1082
# Fallback prediction for user 474 on item 1079
# Fallback prediction for user 474 on item 6791
# Fallback prediction for user 474 on item 25952
# Fallback prediction for user 474 on item 2423
# Fallback prediction for user 474 on item 31658
# Fallback prediction for user 474 on item 1006
# Fallback prediction for user 474 on item 1193
# Fallback prediction for user 474 on item 1212
# Fallback prediction for user 474 on item 6390
# Fallback prediction for user 474 on item 222
# Fallback prediction for user 474 on item 1291
# Fallback prediction for user 474 on item 6170
# Fallback prediction for user 474 on item 25753
# Fallback prediction for user 474 on item 7766
# Fallback prediction for user 474 on item 5379
# Fallback prediction for user 474 on item 4537
# Fallback prediction for user 474 on item 8880
# Fallback prediction for user 474 on item 2116
# Fallback prediction for user 474 on item 1650
# Fallback prediction for user 474 on item 5012
# Fallback prediction for user 474 on item 5989
# Fallback prediction for user 474 on item 1198
# Fallback prediction for user 474 on item 1367
# Fallback prediction for user 474 on item 26151
# Fallback prediction for user 474 on item 6296
# Fallback prediction for user 474 on item 7714
# Fallback prediction for user 474 on item 8446
# Fallback prediction for user 474 on item 6273
# Fallback prediction for user 474 on item 4034
# Fallback prediction for user 474 on item 6090
# Fallback prediction for user 474 on item 8874
# Fallback prediction for user 474 on item 1921
# Fallback prediction for user 474 on item 3317
# Fallback prediction for user 474 on item 1282
# Fallback prediction for user 474 on item 1474
# Fallback prediction for user 474 on item 5445
# Fallback prediction for user 474 on item 31437
# Fallback prediction for user 474 on item 1196
# Fallback prediction for user 474 on item 339
# Fallback prediction for user 474 on item 1178
# Fallback prediction for user 474 on item 6367
# Fallback prediction for user 474 on item 277
# Fallback prediction for user 474 on item 480
# Fallback prediction for user 474 on item 4448
# Fallback prediction for user 474 on item 22
# Fallback prediction for user 474 on item 4189
# Fallback prediction for user 474 on item 616
# Fallback prediction for user 474 on item 7217
# Fallback prediction for user 474 on item 8609
# Fallback prediction for user 474 on item 973
# Fallback prediction for user 474 on item 4639
# Fallback prediction for user 474 on item 8167
# Fallback prediction for user 474 on item 25841
# Fallback prediction for user 474 on item 6867
# Fallback prediction for user 474 on item 7301
# Fallback prediction for user 474 on item 1719
# Fallback prediction for user 474 on item 1197
# Fallback prediction for user 474 on item 1220
# Fallback prediction for user 474 on item 513
# Fallback prediction for user 474 on item 1253
# Fallback prediction for user 474 on item 1084
# Fallback prediction for user 474 on item 6788
# Fallback prediction for user 474 on item 2028
# Fallback prediction for user 474 on item 516
# Fallback prediction for user 474 on item 3273
# Fallback prediction for user 474 on item 2927
# Fallback prediction for user 474 on item 37733
# Fallback prediction for user 474 on item 515
# Fallback prediction for user 474 on item 40583
# Fallback prediction for user 474 on item 924
# Fallback prediction for user 474 on item 1957
# Fallback prediction for user 474 on item 1296
# Fallback prediction for user 474 on item 1189
# Fallback prediction for user 474 on item 1093
# Fallback prediction for user 474 on item 3481
# Fallback prediction for user 474 on item 3608
# Fallback prediction for user 474 on item 2310
# Fallback prediction for user 474 on item 8875
# Fallback prediction for user 474 on item 4029
# Fallback prediction for user 474 on item 3451
# Fallback prediction for user 474 on item 1912
# Fallback prediction for user 474 on item 2791
# Fallback prediction for user 474 on item 5
# Fallback prediction for user 474 on item 2728
# Fallback prediction for user 474 on item 1569
# Fallback prediction for user 474 on item 1185
# Fallback prediction for user 474 on item 11
# Fallback prediction for user 474 on item 4221
# Fallback prediction for user 474 on item 2728
# Fallback prediction for user 474 on item 96
# Fallback prediction for user 474 on item 945
# Fallback prediction for user 474 on item 508
# Fallback prediction for user 474 on item 35015
# Fallback prediction for user 474 on item 5548
# Fallback prediction for user 474 on item 2424
# Fallback prediction for user 474 on item 6297
# Fallback prediction for user 474 on item 8376
# Fallback prediction for user 474 on item 4998
# Fallback prediction for user 474 on item 3210
# Fallback prediction for user 474 on item 6002
# Fallback prediction for user 474 on item 1246
# Fallback prediction for user 474 on item 1148
# Fallback prediction for user 474 on item 1393
# Fallback prediction for user 474 on item 1179
# Fallback prediction for user 474 on item 4489
# Fallback prediction for user 474 on item 3000
# Fallback prediction for user 474 on item 1348
# Fallback prediction for user 474 on item 3528
# Fallback prediction for user 474 on item 6970
# Fallback prediction for user 474 on item 6810
# Fallback prediction for user 474 on item 3160
# Fallback prediction for user 474 on item 927
# Fallback prediction for user 474 on item 6852
# Fallback prediction for user 474 on item 3087
# Fallback prediction for user 474 on item 4263
# Fallback prediction for user 474 on item 5224
# Fallback prediction for user 474 on item 237
# Fallback prediction for user 474 on item 4979
# Fallback prediction for user 474 on item 4347
# Fallback prediction for user 474 on item 912
# Fallback prediction for user 474 on item 4970
# Fallback prediction for user 474 on item 6159
# Fallback prediction for user 474 on item 1984
# Fallback prediction for user 474 on item 3675
# Fallback prediction for user 474 on item 2249
# Fallback prediction for user 474 on item 282
# Fallback prediction for user 474 on item 8191
# Fallback prediction for user 474 on item 6881
# Fallback prediction for user 474 on item 3793
# Fallback prediction for user 474 on item 2248
# Fallback prediction for user 474 on item 8207
# Fallback prediction for user 474 on item 4969
# Fallback prediction for user 474 on item 8938
# Fallback prediction for user 474 on item 4447
# Fallback prediction for user 474 on item 1028
# Fallback prediction for user 474 on item 2581
# Fallback prediction for user 474 on item 1228
# Fallback prediction for user 474 on item 5
# Fallback prediction for user 474 on item 11
# Fallback prediction for user 474 on item 1136
# Fallback prediction for user 474 on item 8875
# Fallback prediction for user 474 on item 6299
# Fallback prediction for user 474 on item 37736
# Fallback prediction for user 474 on item 916
# Fallback prediction for user 474 on item 8382
# Fallback prediction for user 474 on item 39
# Fallback prediction for user 474 on item 6016
# Fallback prediction for user 474 on item 3421
# Fallback prediction for user 474 on item 6063
# Fallback prediction for user 474 on item 2745
# Fallback prediction for user 474 on item 4477
# Fallback prediction for user 474 on item 3306
# Fallback prediction for user 474 on item 968
# Fallback prediction for user 474 on item 38
# Fallback prediction for user 474 on item 1200
# Fallback prediction for user 474 on item 2145
# Fallback prediction for user 474 on item 140
# Fallback prediction for user 474 on item 349
# Fallback prediction for user 474 on item 1212
# Fallback prediction for user 474 on item 185
# Fallback prediction for user 474 on item 9018
# Fallback prediction for user 474 on item 914
# Fallback prediction for user 474 on item 425
# Fallback prediction for user 474 on item 5316
# Fallback prediction for user 474 on item 6333
# Fallback prediction for user 474 on item 252
# Fallback prediction for user 474 on item 2937
# Fallback prediction for user 474 on item 7584
# Fallback prediction for user 474 on item 116
# Fallback prediction for user 474 on item 8153
# Fallback prediction for user 474 on item 1954
# Fallback prediction for user 474 on item 3429
# Fallback prediction for user 474 on item 38038
# Fallback prediction for user 474 on item 3006
# Fallback prediction for user 474 on item 1976
# Fallback prediction for user 474 on item 2334
# Fallback prediction for user 474 on item 1544
# Fallback prediction for user 474 on item 25886
# Fallback prediction for user 474 on item 7141
# Fallback prediction for user 474 on item 4259
# Fallback prediction for user 474 on item 223
# Fallback prediction for user 474 on item 316
# Fallback prediction for user 474 on item 2491
# Fallback prediction for user 474 on item 838
# Fallback prediction for user 474 on item 1041
# Fallback prediction for user 474 on item 1224
# Fallback prediction for user 474 on item 1952
# Fallback prediction for user 474 on item 3211
# Fallback prediction for user 474 on item 6536
# Fallback prediction for user 474 on item 728
# Fallback prediction for user 474 on item 356
# Fallback prediction for user 474 on item 5475
# Fallback prediction for user 474 on item 7619
# Fallback prediction for user 474 on item 905
# Fallback prediction for user 474 on item 7438
# Fallback prediction for user 474 on item 160
# Fallback prediction for user 474 on item 2020
# Fallback prediction for user 474 on item 4361
# Fallback prediction for user 474 on item 4801
# Fallback prediction for user 474 on item 3341
# Fallback prediction for user 474 on item 2750
# Fallback prediction for user 474 on item 733
# Fallback prediction for user 474 on item 513
# Fallback prediction for user 474 on item 4214
# Fallback prediction for user 474 on item 262
# Fallback prediction for user 474 on item 6787
# Fallback prediction for user 474 on item 345
# Fallback prediction for user 474 on item 2006
# Fallback prediction for user 474 on item 2712
# Fallback prediction for user 474 on item 1653
# Fallback prediction for user 474 on item 593
# Fallback prediction for user 474 on item 951
# Fallback prediction for user 474 on item 1124
# Fallback prediction for user 474 on item 1407
# Fallback prediction for user 474 on item 2726
# Fallback prediction for user 474 on item 1198
# Fallback prediction for user 474 on item 329
# Fallback prediction for user 474 on item 2791
# Fallback prediction for user 474 on item 5483
# Fallback prediction for user 474 on item 342
# Fallback prediction for user 474 on item 1372
# Fallback prediction for user 474 on item 5015
# Fallback prediction for user 474 on item 8275
# Fallback prediction for user 474 on item 3462
# Fallback prediction for user 474 on item 8360
# Fallback prediction for user 474 on item 1097
# Fallback prediction for user 474 on item 7061
# Fallback prediction for user 474 on item 6852
# Fallback prediction for user 474 on item 1263
# Fallback prediction for user 474 on item 936
# Fallback prediction for user 474 on item 6948
# Fallback prediction for user 474 on item 5527
# Fallback prediction for user 474 on item 1103
# Fallback prediction for user 474 on item 381
# Fallback prediction for user 474 on item 6785
# Fallback prediction for user 474 on item 2761
# Fallback prediction for user 474 on item 952
# Fallback prediction for user 474 on item 6104
# Fallback prediction for user 474 on item 6003
# Fallback prediction for user 474 on item 249
# Fallback prediction for user 474 on item 318
# Fallback prediction for user 474 on item 3281
# Fallback prediction for user 474 on item 50
# Fallback prediction for user 474 on item 40815
# Fallback prediction for user 474 on item 1408
# Fallback prediction for user 474 on item 1398
# Fallback prediction for user 474 on item 6195
# Fallback prediction for user 474 on item 34528
# Fallback prediction for user 474 on item 6378
# Fallback prediction for user 474 on item 42740
# Fallback prediction for user 474 on item 261
# Fallback prediction for user 474 on item 280
# Fallback prediction for user 474 on item 3178
# Fallback prediction for user 474 on item 272
# Fallback prediction for user 474 on item 1466
# Fallback prediction for user 474 on item 2787
# Fallback prediction for user 474 on item 4639
# Fallback prediction for user 474 on item 5991
# Fallback prediction for user 474 on item 1376
# Fallback prediction for user 474 on item 2583
# Fallback prediction for user 474 on item 3566
# Fallback prediction for user 474 on item 6662
# Fallback prediction for user 474 on item 1288
# Fallback prediction for user 474 on item 7479
# Fallback prediction for user 474 on item 36527
# Fallback prediction for user 474 on item 4370
# Fallback prediction for user 474 on item 345
# Fallback prediction for user 474 on item 2391
# Fallback prediction for user 474 on item 4963
# Fallback prediction for user 474 on item 4920
# Fallback prediction for user 474 on item 6216
# Fallback prediction for user 474 on item 224
# Fallback prediction for user 474 on item 1042
# Fallback prediction for user 474 on item 4571
# Fallback prediction for user 474 on item 940
# Fallback prediction for user 474 on item 923
# Fallback prediction for user 474 on item 524
# Fallback prediction for user 474 on item 8920
# Fallback prediction for user 474 on item 1243
# Fallback prediction for user 474 on item 412
# Fallback prediction for user 474 on item 6281
# Fallback prediction for user 474 on item 953
# Fallback prediction for user 474 on item 30822
# Fallback prediction for user 474 on item 16
# Fallback prediction for user 474 on item 1408
# Fallback prediction for user 474 on item 3006
# Fallback prediction for user 474 on item 965
# Fallback prediction for user 474 on item 2268
# Fallback prediction for user 474 on item 1266
# Fallback prediction for user 474 on item 4166
# Fallback prediction for user 474 on item 6711
# Fallback prediction for user 474 on item 2076
# Fallback prediction for user 474 on item 3247
# Fallback prediction for user 474 on item 1496
# Fallback prediction for user 474 on item 3095
# Fallback prediction for user 474 on item 8645
# Fallback prediction for user 474 on item 522
# Fallback prediction for user 474 on item 1902
# Fallback prediction for user 474 on item 6178
# Fallback prediction for user 474 on item 3176
# Fallback prediction for user 474 on item 8754
# Fallback prediction for user 474 on item 3115
# Fallback prediction for user 474 on item 1996
# Fallback prediction for user 474 on item 670
# Fallback prediction for user 474 on item 31030
# Fallback prediction for user 474 on item 2941
# Fallback prediction for user 474 on item 4007
# Fallback prediction for user 474 on item 6753
# Fallback prediction for user 474 on item 3461
# Fallback prediction for user 474 on item 6195
# Fallback prediction for user 474 on item 40815
# Fallback prediction for user 474 on item 14
# Fallback prediction for user 474 on item 5816
# Fallback prediction for user 474 on item 2728
# Fallback prediction for user 474 on item 6385
# Fallback prediction for user 474 on item 1222
# Fallback prediction for user 474 on item 4874
# Fallback prediction for user 474 on item 1196
# Fallback prediction for user 474 on item 5450
# Fallback prediction for user 474 on item 8879
# Fallback prediction for user 474 on item 8019
# Fallback prediction for user 474 on item 970
# Fallback prediction for user 474 on item 6545
# Fallback prediction for user 474 on item 1242
# Fallback prediction for user 474 on item 6183
# Fallback prediction for user 474 on item 3877
# Fallback prediction for user 474 on item 522
# Fallback prediction for user 474 on item 1957
# Fallback prediction for user 474 on item 6308
# Fallback prediction for user 474 on item 4545
# Fallback prediction for user 474 on item 6245
# Fallback prediction for user 474 on item 27741
# Fallback prediction for user 474 on item 1387
# Fallback prediction for user 474 on item 1962
# Fallback prediction for user 474 on item 5875
# Fallback prediction for user 474 on item 926
# Fallback prediction for user 474 on item 4980
# Fallback prediction for user 474 on item 928
# Fallback prediction for user 474 on item 7156
# Fallback prediction for user 474 on item 7371
# Fallback prediction for user 474 on item 913
# Fallback prediction for user 474 on item 262
# Fallback prediction for user 474 on item 534
# Fallback prediction for user 474 on item 3724
# Fallback prediction for user 474 on item 2750
# Fallback prediction for user 474 on item 6373
# Fallback prediction for user 474 on item 7789
# Fallback prediction for user 474 on item 3629
# Fallback prediction for user 474 on item 500
# Fallback prediction for user 474 on item 7932
# Fallback prediction for user 474 on item 1293
# Fallback prediction for user 474 on item 5577
# Fallback prediction for user 474 on item 1931
# Fallback prediction for user 474 on item 6592
# Fallback prediction for user 474 on item 1913
# Fallback prediction for user 474 on item 4874
# Fallback prediction for user 474 on item 1210
# Fallback prediction for user 474 on item 1260
# Fallback prediction for user 474 on item 1
# Fallback prediction for user 474 on item 1225
# Fallback prediction for user 474 on item 36517
# Fallback prediction for user 474 on item 1635
# Fallback prediction for user 474 on item 7158
# Fallback prediction for user 474 on item 215
# Fallback prediction for user 474 on item 2553
# Fallback prediction for user 474 on item 7572
# Fallback prediction for user 474 on item 5379
# Fallback prediction for user 474 on item 6268
# Fallback prediction for user 474 on item 628
# Fallback prediction for user 474 on item 1411
# Fallback prediction for user 474 on item 471
# Fallback prediction for user 474 on item 4292
# Fallback prediction for user 474 on item 1961
# Fallback prediction for user 474 on item 3040
# Fallback prediction for user 474 on item 307
# Fallback prediction for user 474 on item 31903
# Fallback prediction for user 474 on item 720
# Fallback prediction for user 474 on item 4546
# Fallback prediction for user 474 on item 3469
# Fallback prediction for user 474 on item 1302
# Fallback prediction for user 474 on item 954
# Fallback prediction for user 474 on item 246
# Fallback prediction for user 474 on item 3556
# Fallback prediction for user 474 on item 488
# Fallback prediction for user 474 on item 1093
# Fallback prediction for user 474 on item 4809
# Fallback prediction for user 474 on item 1189
# Fallback prediction for user 474 on item 34437
# Fallback prediction for user 474 on item 6228
# Fallback prediction for user 474 on item 1834
# Fallback prediction for user 474 on item 5630
# Fallback prediction for user 474 on item 3949
# Fallback prediction for user 474 on item 1231
# Fallback prediction for user 474 on item 1748
# Fallback prediction for user 474 on item 8879
# Fallback prediction for user 474 on item 1203
# Fallback prediction for user 474 on item 1345
# Fallback prediction for user 474 on item 592
# Fallback prediction for user 474 on item 41
# Fallback prediction for user 474 on item 1947
# Fallback prediction for user 474 on item 832
# Fallback prediction for user 474 on item 4973
# Fallback prediction for user 474 on item 8366
# Fallback prediction for user 474 on item 8366
# Fallback prediction for user 474 on item 597
# Fallback prediction for user 474 on item 34359
# Fallback prediction for user 474 on item 2642
# Fallback prediction for user 474 on item 638
# Fallback prediction for user 474 on item 1951
# Fallback prediction for user 474 on item 7190
# Fallback prediction for user 474 on item 5404
# Fallback prediction for user 474 on item 1719
# Fallback prediction for user 474 on item 257
# Fallback prediction for user 474 on item 7013
# Fallback prediction for user 474 on item 2243
# Fallback prediction for user 474 on item 3263
# Fallback prediction for user 474 on item 2693
# Fallback prediction for user 474 on item 4024
# Fallback prediction for user 474 on item 934
# Fallback prediction for user 474 on item 3125
# Fallback prediction for user 474 on item 915
# Fallback prediction for user 474 on item 590
# Fallback prediction for user 474 on item 497
# Fallback prediction for user 474 on item 6183
# Fallback prediction for user 474 on item 5899
# Fallback prediction for user 474 on item 6856
# Fallback prediction for user 474 on item 745
# Fallback prediction for user 474 on item 104
# Fallback prediction for user 474 on item 2919
# Fallback prediction for user 474 on item 351
# Fallback prediction for user 474 on item 92
# Fallback prediction for user 474 on item 2118
# Fallback prediction for user 474 on item 4380
# Fallback prediction for user 474 on item 7069
# Fallback prediction for user 474 on item 30812
# Fallback prediction for user 474 on item 1680
# Fallback prediction for user 474 on item 1573
# Fallback prediction for user 474 on item 36
# Fallback prediction for user 474 on item 4546
# Fallback prediction for user 474 on item 4902
# Fallback prediction for user 474 on item 237
# Fallback prediction for user 474 on item 4359
# Fallback prediction for user 474 on item 7062
# Fallback prediction for user 474 on item 1233
# Fallback prediction for user 474 on item 1917
# Fallback prediction for user 474 on item 4113
# Fallback prediction for user 474 on item 7646
# Fallback prediction for user 474 on item 1257
# Fallback prediction for user 474 on item 3147
# Fallback prediction for user 474 on item 3071
# Fallback prediction for user 474 on item 7932
# Fallback prediction for user 474 on item 1423
# Fallback prediction for user 474 on item 994
# Fallback prediction for user 474 on item 260
# Fallback prediction for user 474 on item 930
# Fallback prediction for user 474 on item 1396
# Fallback prediction for user 474 on item 1276
# Fallback prediction for user 474 on item 6002
# Fallback prediction for user 474 on item 668
# Fallback prediction for user 474 on item 31
# Fallback prediction for user 474 on item 7618
# Fallback prediction for user 474 on item 5451
# Fallback prediction for user 474 on item 1207
# Fallback prediction for user 474 on item 5008
# Fallback prediction for user 474 on item 4326
# Fallback prediction for user 474 on item 2295
# Fallback prediction for user 474 on item 224
# Fallback prediction for user 474 on item 7055
# Fallback prediction for user 474 on item 1025
# Fallback prediction for user 474 on item 6770
# Fallback prediction for user 474 on item 4246
# Fallback prediction for user 474 on item 6407
# Fallback prediction for user 474 on item 8961
# Fallback prediction for user 474 on item 1033
# Fallback prediction for user 474 on item 6380
# Fallback prediction for user 474 on item 2935
# Fallback prediction for user 474 on item 1235
# Fallback prediction for user 474 on item 8645
# Fallback prediction for user 474 on item 58
# Fallback prediction for user 474 on item 3152
# Fallback prediction for user 474 on item 7834
# Fallback prediction for user 474 on item 2717
# Fallback prediction for user 474 on item 5633
# Fallback prediction for user 474 on item 8228
# Fallback prediction for user 474 on item 2022
# Fallback prediction for user 474 on item 6660
# Fallback prediction for user 474 on item 2915
# Fallback prediction for user 474 on item 3175
# Fallback prediction for user 474 on item 818
# Fallback prediction for user 474 on item 4812
# Fallback prediction for user 474 on item 1449
# Fallback prediction for user 474 on item 4218
# Fallback prediction for user 474 on item 1270
# Fallback prediction for user 474 on item 2762
# Fallback prediction for user 474 on item 3330
# Fallback prediction for user 474 on item 36535
# Fallback prediction for user 474 on item 3108
# Fallback prediction for user 474 on item 1343
# Fallback prediction for user 474 on item 1245
# Fallback prediction for user 474 on item 1301
# Fallback prediction for user 474 on item 260
# Fallback prediction for user 474 on item 8949
# Fallback prediction for user 474 on item 7981
# Fallback prediction for user 474 on item 1893
# Fallback prediction for user 474 on item 3897
# Fallback prediction for user 474 on item 852
# Fallback prediction for user 474 on item 40819
# Fallback prediction for user 474 on item 2420
# Fallback prediction for user 474 on item 371
# Fallback prediction for user 474 on item 1307
# Fallback prediction for user 474 on item 2324
# Fallback prediction for user 474 on item 4835
# Fallback prediction for user 474 on item 2335
# Fallback prediction for user 474 on item 30707
# Fallback prediction for user 474 on item 300
# Fallback prediction for user 474 on item 4077
# Fallback prediction for user 474 on item 6333
# Fallback prediction for user 474 on item 27882
# Fallback prediction for user 474 on item 3273
# Fallback prediction for user 474 on item 1810
# Fallback prediction for user 474 on item 6591
# Fallback prediction for user 474 on item 30812
# Fallback prediction for user 474 on item 39292
# Fallback prediction for user 474 on item 6620
# Fallback prediction for user 474 on item 21
# Fallback prediction for user 474 on item 1278
# Fallback prediction for user 474 on item 1068
# Fallback prediction for user 474 on item 2070
# Fallback prediction for user 474 on item 107
# Fallback prediction for user 474 on item 4019
# Fallback prediction for user 474 on item 595
# Fallback prediction for user 474 on item 1304
# Fallback prediction for user 474 on item 2171
# Fallback prediction for user 474 on item 3983
# Fallback prediction for user 474 on item 1010
# Fallback prediction for user 474 on item 6710
# Fallback prediction for user 474 on item 1353
# Fallback prediction for user 474 on item 2919
# Fallback prediction for user 474 on item 8879
# Fallback prediction for user 474 on item 7090
# Fallback prediction for user 474 on item 2019
# Fallback prediction for user 474 on item 8950
# Fallback prediction for user 474 on item 2762
# Fallback prediction for user 474 on item 2918
# Fallback prediction for user 474 on item 4638
# Fallback prediction for user 474 on item 7705
# Fallback prediction for user 474 on item 4138
# Fallback prediction for user 474 on item 34542
# Fallback prediction for user 474 on item 587
# Fallback prediction for user 474 on item 4489
# Fallback prediction for user 474 on item 5618
# Fallback prediction for user 474 on item 6650
# Fallback prediction for user 474 on item 969
# Fallback prediction for user 474 on item 6407
# Fallback prediction for user 474 on item 1198
# Fallback prediction for user 474 on item 8961
# Fallback prediction for user 474 on item 28
# Fallback prediction for user 474 on item 1945
# Fallback prediction for user 474 on item 1188
# Fallback prediction for user 474 on item 3408
# Fallback prediction for user 474 on item 2357
# Fallback prediction for user 474 on item 7649
# Fallback prediction for user 474 on item 6912
# Fallback prediction for user 474 on item 8784
# Fallback prediction for user 474 on item 4621
# Fallback prediction for user 474 on item 922
# Fallback prediction for user 474 on item 673
# Fallback prediction for user 474 on item 6181
# Fallback prediction for user 474 on item 338
# Fallback prediction for user 474 on item 3994
# Fallback prediction for user 474 on item 3307
# Fallback prediction for user 474 on item 1953
# Fallback prediction for user 474 on item 3330
# Fallback prediction for user 474 on item 34
# Fallback prediction for user 474 on item 1221
# Fallback prediction for user 474 on item 3135
# Fallback prediction for user 474 on item 7132
# Fallback prediction for user 474 on item 8827
# Fallback prediction for user 474 on item 2394
# Fallback prediction for user 474 on item 7087
# Fallback prediction for user 474 on item 1206
# Fallback prediction for user 474 on item 1366
# Fallback prediction for user 474 on item 1617
# Fallback prediction for user 474 on item 918
# Fallback prediction for user 474 on item 4677
# Fallback prediction for user 474 on item 6744
# Fallback prediction for user 474 on item 5952
# Fallback prediction for user 474 on item 33493
# Fallback prediction for user 474 on item 317
# Fallback prediction for user 474 on item 5876
# Fallback prediction for user 474 on item 2940
# ...
# Fallback prediction for user 599 on item 924
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 2959
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 924
# Fallback prediction for user 599 on item 1732
# Fallback prediction for user 599 on item 293
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 2959
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 2959
# Fallback prediction for user 599 on item 1732
# Fallback prediction for user 599 on item 2959
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 924
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 2959
# Fallback prediction for user 599 on item 293
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 296
# Fallback prediction for user 599 on item 1732
# Fallback prediction for user 599 on item 296
#
# -------------------
# User 18 (12/25):
# Fallback prediction for user 18 on item 431
# Fallback prediction for user 18 on item 431
# Fallback prediction for user 18 on item 5995
# Fallback prediction for user 18 on item 144210
# Fallback prediction for user 18 on item 88094
# Fallback prediction for user 18 on item 88094
# Fallback prediction for user 18 on item 52604
# Fallback prediction for user 18 on item 52604
# Fallback prediction for user 18 on item 431
# Fallback prediction for user 18 on item 144210
# Fallback prediction for user 18 on item 1221
# Fallback prediction for user 18 on item 44665
# Fallback prediction for user 18 on item 52604
# Fallback prediction for user 18 on item 88094
# Fallback prediction for user 18 on item 1221
# Fallback prediction for user 18 on item 5995
#
# -------------------
# User 537 (13/25):
# Fallback prediction for user 537 on item 72998
# Fallback prediction for user 537 on item 55765
# Fallback prediction for user 537 on item 80906
# Fallback prediction for user 537 on item 90439
# Fallback prediction for user 537 on item 527
# Fallback prediction for user 537 on item 58295
# Fallback prediction for user 537 on item 72998
# Fallback prediction for user 537 on item 90439
# Fallback prediction for user 537 on item 5989
# Fallback prediction for user 537 on item 79132
# Fallback prediction for user 537 on item 104841
# Fallback prediction for user 537 on item 72998
# Fallback prediction for user 537 on item 80906
# Fallback prediction for user 537 on item 105504
# Fallback prediction for user 537 on item 5989
# Fallback prediction for user 537 on item 1721
# Fallback prediction for user 537 on item 8533
# Fallback prediction for user 537 on item 69122
# Fallback prediction for user 537 on item 79132
# Fallback prediction for user 537 on item 89745
# Fallback prediction for user 537 on item 95067
# Fallback prediction for user 537 on item 90439
# Fallback prediction for user 537 on item 97304
# Fallback prediction for user 537 on item 69122
# Fallback prediction for user 537 on item 72998
# Fallback prediction for user 537 on item 5989
# Fallback prediction for user 537 on item 90439
# Fallback prediction for user 537 on item 90439
# Fallback prediction for user 537 on item 69122
# Fallback prediction for user 537 on item 97304
# Fallback prediction for user 537 on item 2571
# Fallback prediction for user 537 on item 90439
# Fallback prediction for user 537 on item 2329
# Fallback prediction for user 537 on item 79132
# Fallback prediction for user 537 on item 79132
# Fallback prediction for user 537 on item 5989
# Fallback prediction for user 537 on item 79132
# Fallback prediction for user 537 on item 72998
# Fallback prediction for user 537 on item 2329
# Fallback prediction for user 537 on item 104218
# Fallback prediction for user 537 on item 69122
# Fallback prediction for user 537 on item 8533
# Fallback prediction for user 537 on item 104841
# Fallback prediction for user 537 on item 58295
# Fallback prediction for user 537 on item 79132
# Fallback prediction for user 537 on item 5989
# Fallback prediction for user 537 on item 58295
# Fallback prediction for user 537 on item 527
# Fallback prediction for user 537 on item 8533
# Fallback prediction for user 537 on item 72998
# Fallback prediction for user 537 on item 2571
# Fallback prediction for user 537 on item 105504
# Fallback prediction for user 537 on item 2329
# Fallback prediction for user 537 on item 90439
# Fallback prediction for user 537 on item 72998
# Fallback prediction for user 537 on item 104841
# Fallback prediction for user 537 on item 106782
# Fallback prediction for user 537 on item 80906
# Fallback prediction for user 537 on item 79132
# Fallback prediction for user 537 on item 79132
# Fallback prediction for user 537 on item 79132
# Fallback prediction for user 537 on item 89745
# Fallback prediction for user 537 on item 106782
# Fallback prediction for user 537 on item 5989
# Fallback prediction for user 537 on item 90439
# Fallback prediction for user 537 on item 79132
# Fallback prediction for user 537 on item 80906
# Fallback prediction for user 537 on item 79132
# Fallback prediction for user 537 on item 104841
# Fallback prediction for user 537 on item 80906
# Fallback prediction for user 537 on item 69481
# Fallback prediction for user 537 on item 105504
# Fallback prediction for user 537 on item 80906
# Fallback prediction for user 537 on item 89745
# Fallback prediction for user 537 on item 99114
# Fallback prediction for user 537 on item 72998
# Fallback prediction for user 537 on item 69122
# Fallback prediction for user 537 on item 527
# Fallback prediction for user 537 on item 79132
# Fallback prediction for user 537 on item 55765
# Fallback prediction for user 537 on item 527
# Fallback prediction for user 537 on item 55765
# Fallback prediction for user 537 on item 104841
# Fallback prediction for user 537 on item 97304
# Fallback prediction for user 537 on item 104841
# Fallback prediction for user 537 on item 55765
# Fallback prediction for user 537 on item 89745
# Fallback prediction for user 537 on item 90439
# Fallback prediction for user 537 on item 5989
# Fallback prediction for user 537 on item 79132
#
# -------------------
# User 318 (14/25):
# Fallback prediction for user 318 on item 127172
# Fallback prediction for user 318 on item 68954
# Fallback prediction for user 318 on item 96084
# Fallback prediction for user 318 on item 118784
# Fallback prediction for user 318 on item 71494
# Fallback prediction for user 318 on item 118784
# Fallback prediction for user 318 on item 82459
# Fallback prediction for user 318 on item 68954
# Fallback prediction for user 318 on item 68954
# Fallback prediction for user 318 on item 81158
# Fallback prediction for user 318 on item 68954
# Fallback prediction for user 318 on item 127172
# Fallback prediction for user 318 on item 778
# Fallback prediction for user 318 on item 4708
# Fallback prediction for user 318 on item 111364
# Fallback prediction for user 318 on item 68954
# Fallback prediction for user 318 on item 82459
# Fallback prediction for user 318 on item 64034
# Fallback prediction for user 318 on item 68954
# Fallback prediction for user 318 on item 778
# Fallback prediction for user 318 on item 90769
# Fallback prediction for user 318 on item 778
# Fallback prediction for user 318 on item 127172
# Fallback prediction for user 318 on item 4612
# Fallback prediction for user 318 on item 118784
# Fallback prediction for user 318 on item 90769
# Fallback prediction for user 318 on item 96084
# Fallback prediction for user 318 on item 68954
# Fallback prediction for user 318 on item 82459
# Fallback prediction for user 318 on item 82459
# Fallback prediction for user 318 on item 90769
# Fallback prediction for user 318 on item 64034
# Fallback prediction for user 318 on item 82459
# Fallback prediction for user 318 on item 68954
# Fallback prediction for user 318 on item 68954
# Fallback prediction for user 318 on item 96084
#
# -------------------
# User 573 (15/25):
# Fallback prediction for user 573 on item 52712
# Fallback prediction for user 573 on item 35836
# Fallback prediction for user 573 on item 836
# Fallback prediction for user 573 on item 35836
# Fallback prediction for user 573 on item 6373
# Fallback prediction for user 573 on item 5064
# Fallback prediction for user 573 on item 1801
# Fallback prediction for user 573 on item 52712
# Fallback prediction for user 573 on item 5254
# Fallback prediction for user 573 on item 35836
# Fallback prediction for user 573 on item 5254
# Fallback prediction for user 573 on item 35836
#
# Processed 15 users, pausing for 5 seconds...
#
# -------------------
# User 327 (16/25):
# Fallback prediction for user 327 on item 1288
# Fallback prediction for user 327 on item 1923
# Fallback prediction for user 327 on item 8641
# Fallback prediction for user 327 on item 2616
# Fallback prediction for user 327 on item 3897
# Fallback prediction for user 327 on item 3481
# Fallback prediction for user 327 on item 51255
#
# -------------------
# User 606 (17/25):
# Fallback prediction for user 606 on item 1357
# Fallback prediction for user 606 on item 1948
# Fallback prediction for user 606 on item 7382
# Fallback prediction for user 606 on item 3578
# Fallback prediction for user 606 on item 6107
# Fallback prediction for user 606 on item 5694
#
# -------------------
# User 125 (18/25):
# Fallback prediction for user 125 on item 8957
# Fallback prediction for user 125 on item 100083
# Fallback prediction for user 125 on item 8957
# Fallback prediction for user 125 on item 158872
# Fallback prediction for user 125 on item 8957
# Fallback prediction for user 125 on item 100083
# Fallback prediction for user 125 on item 7022
# Fallback prediction for user 125 on item 7254
# Fallback prediction for user 125 on item 3052
# Fallback prediction for user 125 on item 8957
# Fallback prediction for user 125 on item 5088
# Fallback prediction for user 125 on item 2387
# Fallback prediction for user 125 on item 3052
# Fallback prediction for user 125 on item 100083
# Fallback prediction for user 125 on item 60950
# Fallback prediction for user 125 on item 7022
# Fallback prediction for user 125 on item 7022
# Fallback prediction for user 125 on item 158872
# Fallback prediction for user 125 on item 7022
# Fallback prediction for user 125 on item 7022
# Fallback prediction for user 125 on item 7022
# Fallback prediction for user 125 on item 8957
# Fallback prediction for user 125 on item 58301
# Fallback prediction for user 125 on item 158872
# Fallback prediction for user 125 on item 1726
# Fallback prediction for user 125 on item 42632
# Fallback prediction for user 125 on item 9010
# Fallback prediction for user 125 on item 3052
# Fallback prediction for user 125 on item 7022
# Fallback prediction for user 125 on item 62434
# Fallback prediction for user 125 on item 1726
# Fallback prediction for user 125 on item 158872
# Fallback prediction for user 125 on item 7254
# Fallback prediction for user 125 on item 2387
# Fallback prediction for user 125 on item 67695
# Fallback prediction for user 125 on item 62434
# Fallback prediction for user 125 on item 8957
# Fallback prediction for user 125 on item 100083
# Fallback prediction for user 125 on item 7022
# Fallback prediction for user 125 on item 7254
# Fallback prediction for user 125 on item 7022
# Fallback prediction for user 125 on item 158872
# Fallback prediction for user 125 on item 7254
# Fallback prediction for user 125 on item 3052
# Fallback prediction for user 125 on item 156371
# Fallback prediction for user 125 on item 7022
# Fallback prediction for user 125 on item 8957
# Fallback prediction for user 125 on item 100083
#
# -------------------
# User 356 (19/25):
# Fallback prediction for user 356 on item 37384
# Fallback prediction for user 356 on item 61323
# Fallback prediction for user 356 on item 40955
# Fallback prediction for user 356 on item 2146
# Fallback prediction for user 356 on item 44889
#
# -------------------
# User 184 (20/25):
# Fallback prediction for user 184 on item 27156
# Fallback prediction for user 184 on item 4226
# Fallback prediction for user 184 on item 6283
# Fallback prediction for user 184 on item 5388
# Fallback prediction for user 184 on item 4226
# Fallback prediction for user 184 on item 27156
# Fallback prediction for user 184 on item 4896
# Fallback prediction for user 184 on item 4226
# Fallback prediction for user 184 on item 3793
# Fallback prediction for user 184 on item 4896
# Fallback prediction for user 184 on item 3793
# Fallback prediction for user 184 on item 193565
# Fallback prediction for user 184 on item 2579
# Fallback prediction for user 184 on item 2579
# Fallback prediction for user 184 on item 4896
# Fallback prediction for user 184 on item 27156
# Fallback prediction for user 184 on item 2579
# Fallback prediction for user 184 on item 4226
# Fallback prediction for user 184 on item 2579
# Fallback prediction for user 184 on item 2579
# Fallback prediction for user 184 on item 193565
# Fallback prediction for user 184 on item 2579
# Fallback prediction for user 184 on item 27156
# Fallback prediction for user 184 on item 6283
# Fallback prediction for user 184 on item 193565
# Fallback prediction for user 184 on item 3793
# Fallback prediction for user 184 on item 5388
# Fallback prediction for user 184 on item 4896
# Fallback prediction for user 184 on item 6283
# Fallback prediction for user 184 on item 3793
# Fallback prediction for user 184 on item 5388
# Fallback prediction for user 184 on item 193565
# Fallback prediction for user 184 on item 3793
# Fallback prediction for user 184 on item 4226
# Fallback prediction for user 184 on item 27156
#
# Processed 20 users, pausing for 5 seconds...
#
# -------------------
# User 305 (21/25):
# Fallback prediction for user 305 on item 4995
# Fallback prediction for user 305 on item 34405
# Fallback prediction for user 305 on item 4034
# Fallback prediction for user 305 on item 83134
# Fallback prediction for user 305 on item 6502
# Fallback prediction for user 305 on item 8641
# Fallback prediction for user 305 on item 6953
# Fallback prediction for user 305 on item 55721
#
# -------------------
# User 2 (22/25):
# Fallback prediction for user 2 on item 106782
# Fallback prediction for user 2 on item 60756
# Fallback prediction for user 2 on item 89774
# Fallback prediction for user 2 on item 60756
# Fallback prediction for user 2 on item 106782
# Fallback prediction for user 2 on item 60756
# Fallback prediction for user 2 on item 89774
# Fallback prediction for user 2 on item 89774
# Fallback prediction for user 2 on item 106782
#
# -------------------
# User 419 (23/25):
# Fallback prediction for user 419 on item 98961
# Fallback prediction for user 419 on item 98961
# Fallback prediction for user 419 on item 98961
# Fallback prediction for user 419 on item 98961
# Fallback prediction for user 419 on item 98961
#
# -------------------
# User 119 (24/25):
# Fallback prediction for user 119 on item 120635
# Fallback prediction for user 119 on item 120635
# Fallback prediction for user 119 on item 101142
# Fallback prediction for user 119 on item 115617
# Fallback prediction for user 119 on item 115149
# Fallback prediction for user 119 on item 101142
# Fallback prediction for user 119 on item 101142
# Fallback prediction for user 119 on item 120635
# Fallback prediction for user 119 on item 115149
# Fallback prediction for user 119 on item 115617
# Fallback prediction for user 119 on item 115149
# Fallback prediction for user 119 on item 115617
#
# -------------------
# User 462 (25/25):
# Fallback prediction for user 462 on item 152711
# Fallback prediction for user 462 on item 152711
# Fallback prediction for user 462 on item 152711
# Fallback prediction for user 462 on item 152711
# Fallback prediction for user 462 on item 152711
#
# Processed 25 users, pausing for 5 seconds...
# Predictions completed and saved.
# CPU times: user 1.55 s, sys: 110 ms, total: 1.66 s
# Wall time: 26.6 s

# %%
# Evaluate Few-shot Model
evaluate_model_predictions_rmse_mae(
    data_path=CF_FEW_SHOT_1_OBS_SAVE_PATH,
    num_examples=NUM_EXAMPLES,
    actual_ratings_column='actual_rating',
    predicted_ratings_column='predicted_rating'
)
# Out:
# RMSE: 0.2386 (95% CI: (0.2178, 0.2606)) ± 0.0002
# MAE: 0.0787 (95% CI: (0.0713, 0.0863)) ± 0.0001
#
# First few actual vs predicted ratings:
# Actual: 2.5, Predicted: 3.7857
# Actual: 3.0, Predicted: 3.0000
# Actual: 4.0, Predicted: 4.0000
# Actual: 4.0, Predicted: 3.8333
# Actual: 3.5, Predicted: 3.5000
