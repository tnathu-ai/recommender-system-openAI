# %%
import numpy as np
import openai
import pandas as pd
import os
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tenacity import retry, wait_random_exponential, stop_after_attempt
import sys
# Add the path to the constants file to the system path
sys.path.append('../../')
from constants import RANDOM_STATE, OPENAI_API_KEY

# OpenAI API Key
openai.api_key = OPENAI_API_KEY
# OpenAI GPT Model parameters
GPT_MODEL_NAME = "gpt-3.5-turbo"
TEMPERATURE = 0

# Get the current directory of the notebook
current_dir = os.path.dirname(os.path.abspath("../../../data/movie-ml-latest-small/continuous_rating_prediction.ipynb"))
print(f"current directory: {current_dir}")
# Out:
# current directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/movie-ml-latest-small

# %% [markdown]
# # RMSE & MAE evaluation metrics

# %%
# calculate RMSE and MAE manually
def calculate_rmse_and_mae(actual_ratings, predicted_ratings):
    differences = [actual - predicted for actual, predicted in zip(actual_ratings, predicted_ratings)]
    
    # RMSE
    squared_differences = [diff ** 2 for diff in differences]
    mean_squared_difference = sum(squared_differences) / len(squared_differences)
    rmse = mean_squared_difference ** 0.5

    # MAE
    absolute_differences = [abs(diff) for diff in differences]
    mae = sum(absolute_differences) / len(absolute_differences)

    return rmse, mae

# Test
actual_ratings = [4, 4]  # Ground truth ratings
predicted_ratings = [3, 5]  # Predicted ratings

rmse, mae = calculate_rmse_and_mae(actual_ratings, predicted_ratings)
print("RMSE: ", rmse)
print("MAE: ", mae)
# Out:
# RMSE:  1.0
# MAE:  1.0

# %% [markdown]
# # Data Overview

# %%
# Construct the path to data file
data_path = os.path.join(current_dir, 'merged_data.csv')
print(f'data path: {data_path}')
# Out:
# data path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/movie-ml-latest-small/merged_data.csv

# %%
# Read the data
data = pd.read_csv(data_path)
# get sample data of 100 rows
movie_data = data.sample(100, random_state=2002)
movie_data.info()
movie_data.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 2828 to 2502
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  100 non-null    int64
#  1   imdbId   100 non-null    int64
#  2   tmdbId   100 non-null    float64
#  3   title    100 non-null    object
#  4   genres   100 non-null    object
#  5   userId   100 non-null    int64
#  6   rating   100 non-null    float64
#  7   tag      100 non-null    object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 7.0+ KB
#       movieId  imdbId   tmdbId                        title  \
# 2828    68157  361748  16869.0  Inglourious Basterds (2009)
# 2458    27773  364569    670.0               Old Boy (2003)
# 2939    72998  499549  19995.0                Avatar (2009)
#
#                             genres  userId  rating                tag
# 2828              Action|Drama|War     424     4.5             satire
# 2458              Mystery|Thriller     567     4.5            bizarre
# 2939  Action|Adventure|Sci-Fi|IMAX     537     5.0  visually stunning

# %% [markdown]
# # Simple statistical methods (mean calculations)
#
# + **Zero-Shot Prediction (zero_shot_predict function):**
# This method calculates the average rating for a given movie title from the `movie_data` DataFrame.
# It does not take into account any user-specific information and predicts the rating based on the average rating of the movie across all users.
#
# + **Few-Shot Prediction (few_shot_predict function):**
# This method calculates the average rating for a given movie title by a specific user from the `movie_data` DataFrame.
# It predicts the rating based on the average rating of the movie by that specific user, thus incorporating user-specific information.

# %%
# %%time 

def zero_shot_predict(movie_title):
    # Get the average rating for the given title
    avg_rating = movie_data.loc[movie_data['title'] == movie_title, 'rating'].mean()
    return avg_rating

def few_shot_predict(movie_title, user_id):
    # Get the average rating for the given title by the specific user
    avg_rating = movie_data.loc[(movie_data['title'] == movie_title) & (movie_data['userId'] == user_id), 'rating'].mean()
    return avg_rating

# Applying predictions
movie_data['predicted_rating_zero_shot'] = movie_data['title'].apply(zero_shot_predict)
movie_data['predicted_rating_few_shot'] = [few_shot_predict(row['title'], row['userId']) for _, row in movie_data.iterrows()]

# Calculating RMSE and MAE for Zero-Shot
rmse_zero_shot = mean_squared_error(movie_data['rating'], movie_data['predicted_rating_zero_shot'], squared=False)
mae_zero_shot = mean_absolute_error(movie_data['rating'], movie_data['predicted_rating_zero_shot'])

# Calculating RMSE and MAE for Few-Shot
rmse_few_shot = mean_squared_error(movie_data['rating'], movie_data['predicted_rating_few_shot'], squared=False)
mae_few_shot = mean_absolute_error(movie_data['rating'], movie_data['predicted_rating_few_shot'])

print(f"Zero-Shot RMSE: {rmse_zero_shot}, MAE: {mae_zero_shot}")
print(f"Few-Shot RMSE: {rmse_few_shot}, MAE: {mae_few_shot}")

movie_data.head()
# Out:
# Zero-Shot RMSE: 0.1414213562373095, MAE: 0.02
# Few-Shot RMSE: 0.0, MAE: 0.0
# CPU times: user 53.1 ms, sys: 4.43 ms, total: 57.5 ms
# Wall time: 55.6 ms
#       movieId   imdbId   tmdbId                     title  \
# 1233     2506   123209  18417.0  Other Sister, The (1999)
# 2535    34359    60453  42719.0        Georgy Girl (1966)
# 1054     1921   138704    473.0                 Pi (1998)
# 2990    80906  1645089  44639.0         Inside Job (2010)
# 448       500   107614    788.0     Mrs. Doubtfire (1993)
#
#                      genres  userId  rating          tag  \
# 1233   Comedy|Drama|Romance     474     2.0   disability
# 2535                 Comedy     474     4.0    pregnancy
# 1054  Drama|Sci-Fi|Thriller     567     3.0  atmospheric
# 2990            Documentary     537     5.0        truth
# 448            Comedy|Drama     474     2.5  men in drag
#
#       predicted_rating_zero_shot  predicted_rating_few_shot
# 1233                         2.0                        2.0
# 2535                         4.0                        4.0
# 1054                         3.0                        3.0
# 2990                         5.0                        5.0
# 448                          2.5                        2.5

# %% [markdown]
# # Zero-shot (GPT-3.5-turbo)

# %%
data = movie_data

# %%
# %%time

import openai

def predict_rating(title):
    prompt = f"How will users rate this movie title: '{title}'? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text."

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {
                "role": "system",
                "content": "You are a movie critic."
            },
            {
                "role": "user",
                "content": prompt
            }
        ]
    )

    rating_text = response.choices[0].message['content'].strip()
    try:
        # Extract a float number from the response
        rating = float(rating_text)
        if rating < 0.5 or rating > 5.0:
            raise ValueError("Rating out of bounds")
    except ValueError:
        print(f"Unexpected response for '{title}': {rating_text}")
        rating = None

    return rating


# Iterate through the dataset and predict ratings
predicted_ratings = []
for title in data['title'].unique():
    predicted_rating = predict_rating(title)
    print(f"Predicted rating for {title}: {predicted_rating}")
    predicted_ratings.append(predicted_rating)

# Create a DataFrame with titles and predicted ratings
predicted_ratings_df = pd.DataFrame({
    'title': data['title'].unique(),
    'predicted_rating': predicted_ratings
})

# Merge the predicted ratings with the original data
merged_data_with_predictions = pd.merge(data, predicted_ratings_df, on='title')

# Save the merged data with predictions to a new CSV file
merged_data_with_predictions.to_csv('../../data/movie-ml-latest-small/merged_data_with_predictions.csv', index=False)
# Out:
# Predicted rating for Other Sister, The (1999): 4.0
# Predicted rating for Georgy Girl (1966): 4.0
# Predicted rating for Pi (1998): 4.0
# Predicted rating for Inside Job (2010): 4.5
# Predicted rating for Mrs. Doubtfire (1993): 4.0
# Predicted rating for Armageddon (1998): 4.0
# Predicted rating for Shawshank Redemption, The (1994): 5.0
# Predicted rating for Bourne Ultimatum, The (2007): 4.5
# Predicted rating for Dances with Wolves (1990): 4.5
# Predicted rating for Rock, The (1996): 4.0
# Predicted rating for Year of Living Dangerously, The (1982): 4.0
# Predicted rating for Movie 43 (2013): 2.5
# Predicted rating for My Blue Heaven (1990): 3.5
# Predicted rating for Chamber, The (1996): 4.0
# Predicted rating for Fahrenheit 9/11 (2004): 4.0
# Predicted rating for Inception (2010): 4.5
# Predicted rating for 12 Angry Men (1957): 4.9
# Predicted rating for Insider, The (1999): 4.0
# Predicted rating for Terminator 2: Judgment Day (1991): 5.0
# Predicted rating for Crucible, The (1996): 3.5
# Predicted rating for Clueless (1995): 4.0
# Predicted rating for Good Night, and Good Luck. (2005): 4.0
# Predicted rating for The Machinist (2004): 4.0
# Predicted rating for UHF (1989): 3.5
# Predicted rating for Mean Girls (2004): 4.0
# Predicted rating for World of Tomorrow (2015): 4.0
# Predicted rating for Toy Story 2 (1999): 4.5
# Predicted rating for Little Princess, A (1995): 4.0
# Predicted rating for Double Indemnity (1944): 4.5
# Predicted rating for Mark of Zorro, The (1940): 4.0
# Predicted rating for Who Killed Chea Vichea? (2010): 4.0
# Predicted rating for Sword in the Stone, The (1963): 4.5
# Predicted rating for Blade Runner (1982): 4.5
# Predicted rating for Pulp Fiction (1994): 4.0
# Predicted rating for Dumbo (1941): 4.5
# Predicted rating for Interstellar (2014): 4.0
# Predicted rating for Walk the Line (2005): 4.5
# Predicted rating for Saw (2004): 4.0
# Predicted rating for Camelot (1967): 3.0
# Predicted rating for Fracture (2007): 4.0
# Predicted rating for Nowhere in Africa (Nirgendwo in Afrika) (2001): 4.5
# Predicted rating for Talented Mr. Ripley, The (1999): 4.0
# Predicted rating for Avatar (2009): 4.0
# Predicted rating for Trekkies (1997): 4.5
# Predicted rating for Luzhin Defence, The (2000): 4.5
# Predicted rating for Scream (1996): 4.5
# Predicted rating for Gladiator (2000): 4.5
# Predicted rating for Scott Pilgrim vs. the World (2010): 4.0
# Predicted rating for Standing in the Shadows of Motown (2002): 4.0
# Predicted rating for Lemony Snicket's A Series of Unfortunate Events (2004): 4.0
# Predicted rating for Avengers: Infinity War - Part I (2018): 5.0
# Predicted rating for Addams Family Values (1993): 4.0
# Predicted rating for Batman Returns (1992): 4.0
# Predicted rating for Hustle & Flow (2005): 4.0
# Predicted rating for Persuasion (1995): 4.0
# Predicted rating for Logan (2017): 4.5
# Predicted rating for Matrix, The (1999): 4.9
# Predicted rating for College (1927): 3.5
# Predicted rating for Day of the Jackal, The (1973): 4.5
# Predicted rating for Donnie Darko (2001): 4.5
# Predicted rating for Possession (2002): 3.5
# Predicted rating for Zombieland (2009): 4.0
# Predicted rating for Batman v Superman: Dawn of Justice (2016): 3.0
# Predicted rating for Mother! (2017): 3.0
# Predicted rating for Hangover, The (2009): 4.5
# Predicted rating for Fight Club (1999): 4.5
# Predicted rating for Patch of Blue, A (1965): 3.0
# Predicted rating for Killing Fields, The (1984): 4.5
# Predicted rating for Blood Simple (1984): 4.0
# Predicted rating for Star Trek: Insurrection (1998): 4.0
# Predicted rating for Apollo 13 (1995): 5.0
# Predicted rating for Grand Illusion (La grande illusion) (1937): 4.5
# Predicted rating for Deer Hunter, The (1978): 4.5
# Predicted rating for Suicide Squad (2016): 3.5
# Predicted rating for Zoolander (2001): 4.5
# Predicted rating for Fantastic Four (2005): 3.0
# Predicted rating for Mary and Max (2009): 4.0
# Predicted rating for Eraserhead (1977): 4.0
# Predicted rating for Third Man, The (1949): 4.7
# Predicted rating for Pee-wee's Big Adventure (1985): 4.5
# Predicted rating for I.Q. (1994): 3.5
# Predicted rating for Thin Man, The (1934): 4.5
# Predicted rating for Bug (2007): 4.0
# Predicted rating for Captain Phillips (2013): 4.5
# Predicted rating for Dark Knight Rises, The (2012): 4.5
# Predicted rating for A Story of Children and Film (2013): 4.0
# Predicted rating for Django Unchained (2012): 4.5
# Predicted rating for The Man from U.N.C.L.E. (2015): 4.5
# Predicted rating for Seven Brides for Seven Brothers (1954): 4.0
# Predicted rating for Zulu (1964): 4.0
# Predicted rating for Sausage Party (2016): 4.0
# Predicted rating for Session 9 (2001): 4.0
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File <timed exec>:50
#
# File ~/opt/anaconda3/envs/test/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/test/lib/python3.11/site-packages/pandas/core/generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File ~/opt/anaconda3/envs/test/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/test/lib/python3.11/site-packages/pandas/io/formats/format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File ~/opt/anaconda3/envs/test/lib/python3.11/site-packages/pandas/io/formats/csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~/opt/anaconda3/envs/test/lib/python3.11/site-packages/pandas/io/common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~/opt/anaconda3/envs/test/lib/python3.11/site-packages/pandas/io/common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '../data/ml-latest-small'

# %%
# how many predicted_rating values are null? Why null output?
print(f"Number of null predicted_rating values: {merged_data_with_predictions['predicted_rating'].isnull().sum()}")

merged_data_with_predictions.head(3)
# Out:
# Number of null predicted_rating values: 1
#    movieId   imdbId    tmdbId                    title               genres  \
# 0     1423   116506   55146.0  Hearts and Minds (1996)                Drama
# 1   135536  1386697  297761.0     Suicide Squad (2016)  Action|Crime|Sci-Fi
# 2   135536  1386697  297761.0     Suicide Squad (2016)  Action|Crime|Sci-Fi
#
#    userId  rating               tag  predicted_rating_zero_shot  \
# 0     474     4.0  In Netflix queue                         4.0
# 1      62     4.0      lack of plot                         4.0
# 2      62     4.0       Ben Affleck                         4.0
#
#    predicted_rating_few_shot  predicted_rating
# 0                        4.0               NaN
# 1                        4.0               3.0
# 2                        4.0               3.0

# %%
# evaluate the rating prediction model

movie_titles = merged_data_with_predictions['title']
actual_ratings = merged_data_with_predictions['rating']

# Remove None predictions if any
actual_ratings_filtered, predicted_ratings_filtered = zip(*[(actual, predicted) for actual, predicted in zip(actual_ratings, predicted_ratings) if predicted is not None])

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(actual_ratings_filtered, predicted_ratings_filtered))
print(f'Root Mean Squared Error (RMSE): {rmse}')

# Calculate MAE
mae = mean_absolute_error(actual_ratings_filtered, predicted_ratings_filtered)
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Root Mean Squared Error (RMSE): 1.132809969485744
# Mean Absolute Error (MAE): 0.8640449438202248

# %%
# calculate RMSE and MAE manually using calculate_rmse_and_mae function
rmse, mae = calculate_rmse_and_mae(
    actual_ratings_filtered, predicted_ratings_filtered
)
print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
# Out:
# RMSE: 1.132809969485744
# MAE: 0.8640449438202248

# %% [markdown]
# # Few-shot

# %%
# %%time

import re

def predict_rating_few_shot(movie_title, rating_history):
    prompt = f"Here is user rating history: {rating_history}; Based on the above rating history, please predict user's rating for the movie: '{movie_title}', (1 being lowest and 5 being highest). Attention! Just give me back the exact number as a result, and you don't need a lot of text."

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {
                "role": "system",
                "content": "You are a movie critic."
            },
            {
                "role": "user",
                "content": prompt
            }
        ]
    )

    rating_text = response.choices[0].message['content'].strip()
    try:
        # Extract the first numerical value from the response
        rating = float(re.search(r'\d+(\.\d+)?', rating_text).group())
        if rating < 0.5 or rating > 5.0:
            raise ValueError("Rating out of bounds")
    except (ValueError, AttributeError):
        print(f"Unexpected response for '{movie_title}': {rating_text}")
        rating = None

    return rating


predicted_ratings = []
for title in data['title'].unique():
    # Randomly sample 4 rows from the entire dataset
    rating_history_samples = data.sample(4)
    rating_history_str = ', '.join([f"{row['title']} ({row['rating']} stars)" for _, row in rating_history_samples.iterrows()])

    predicted_rating = predict_rating_few_shot(title, rating_history_str)
    print(f"Predicted rating for {title}: {predicted_rating}")
    predicted_ratings.append(predicted_rating)

# Create a DataFrame with titles and predicted ratings
predicted_ratings_df = pd.DataFrame({
    'title': data['title'].unique(),
    'predicted_rating_few_shot': predicted_ratings
})

# Merge the predicted ratings with the original data
merged_data_with_predictions = pd.merge(data, predicted_ratings_df, on='title')

# Save the merged data with predictions to a new CSV file
merged_data_with_predictions.to_csv('../data/ml-latest-small/merged_data_with_predictions.csv', index=False)


# evaluate the rating prediction model

movie_titles = merged_data_with_predictions['title']
actual_ratings = merged_data_with_predictions['rating']

# Remove None predictions if any
actual_ratings_filtered, predicted_ratings_filtered = zip(*[(actual, predicted) for actual, predicted in zip(actual_ratings, predicted_ratings) if predicted is not None])

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(actual_ratings_filtered, predicted_ratings_filtered))
print(f'Root Mean Squared Error (RMSE): {rmse}')
# Calculate MAE
mae = mean_absolute_error(actual_ratings_filtered, predicted_ratings_filtered)
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Unexpected response for 'Hearts and Minds (1996)': Based on the user's rating history, the predicted rating for the movie "Hearts and Minds (1996)" would be 4.0 stars.
# Predicted rating for Hearts and Minds (1996): None
# Predicted rating for Suicide Squad (2016): 4.0
# Unexpected response for 'Elephant Man, The (1980)': Based on the user's rating history, the predicted rating for the movie "Elephant Man, The (1980)" would be 4.0 stars.
# Predicted rating for Elephant Man, The (1980): None
# Predicted rating for Pulp Fiction (1994): 5.0
# Predicted rating for Corpse Bride (2005): 4.0
# Predicted rating for Enigma (2001): 4.0
# Predicted rating for Green Lantern (2011): 3.0
# Predicted rating for Monster (2003): 4.0
# Unexpected response for 'Ginger Snaps (2000)': Based on the user's rating history, I predict the user's rating for the movie "Ginger Snaps (2000)" would be 4.0 stars.
# Predicted rating for Ginger Snaps (2000): None
# Predicted rating for Clerks (1994): 4.5
# Predicted rating for Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964): 4.5
# Predicted rating for Fracture (2007): 4.5
# Predicted rating for Father of the Bride Part II (1995): 4.0
# Predicted rating for Inception (2010): 2.5
# Predicted rating for Bug (2007): 4.0
# Predicted rating for Twins (1988): 3.5
# Predicted rating for South Park: Bigger, Longer and Uncut (1999): 3.0
# Predicted rating for Cinderella (1950): 3.5
# Predicted rating for Usual Suspects, The (1995): 4.5
# Predicted rating for While You Were Sleeping (1995): 4.0
# Predicted rating for Good Night, and Good Luck. (2005): 4.5
# Predicted rating for Zoolander (2001): 3.5
# Predicted rating for Love Liza (2002): 3.5
# Predicted rating for Ghostbusters (a.k.a. Ghost Busters) (1984): 4.0
# Unexpected response for 'Virgin Suicides, The (1999)': Based on the user's rating history, the predicted rating for the movie "Virgin Suicides, The (1999)" would be 4.0 stars.
# Predicted rating for Virgin Suicides, The (1999): None
# Unexpected response for 'Whiplash (2014)': Based on the user's rating history, the predicted rating for the movie 'Whiplash (2014)' would be 5.0 stars.
# Predicted rating for Whiplash (2014): None
# Predicted rating for Layer Cake (2004): 3.0
# Predicted rating for One Flew Over the Cuckoo's Nest (1975): 4.5
# Predicted rating for Red River (1948): 4.5
# Predicted rating for X2: X-Men United (2003): 4.0
# Unexpected response for 'Seven (a.k.a. Se7en) (1995)': I predict the user's rating for "Seven (a.k.a. Se7en) (1995)" to be 4.0 stars.
# Predicted rating for Seven (a.k.a. Se7en) (1995): None
# Predicted rating for Pride of the Yankees, The (1942): 3.5
# Predicted rating for Straight Story, The (1999): 4.0
# Predicted rating for Who Killed Chea Vichea? (2010): 4.0
# Predicted rating for Old Boy (2003): 4.5
# Predicted rating for Frida (2002): 4.0
# Predicted rating for Short Term 12 (2013): 4.5
# Predicted rating for Moonstruck (1987): 4.0
# Predicted rating for Star Wars: Episode V - The Empire Strikes Back (1980): 4.5
# Unexpected response for 'Gladiator (2000)': Based on the user's rating history, it is likely that the user would rate the movie "Gladiator (2000)" with a rating of 4.0 stars.
# Predicted rating for Gladiator (2000): None
# Predicted rating for The Martian (2015): 4.5
# Predicted rating for Sleeping with the Enemy (1991): 4.0
# Unexpected response for 'Punch-Drunk Love (2002)': Based on the user's rating history, the predicted rating for the movie "Punch-Drunk Love (2002)" is 3.5 stars.
# Predicted rating for Punch-Drunk Love (2002): None
# Unexpected response for 'Fight Club (1999)': Based on the user's rating history, the predicted rating for the movie 'Fight Club (1999)' is 5.0 stars.
# Predicted rating for Fight Club (1999): None
# Predicted rating for Stand and Deliver (1988): 3.5
# Predicted rating for Blade Runner (1982): 4.0
# Predicted rating for Jurassic Park (1993): 3.5
# Predicted rating for Kill Bill: Vol. 1 (2003): 3.5
# Predicted rating for Big Business (1988): 5.0
# Unexpected response for 'Bourne Ultimatum, The (2007)': Based on the rating history, the predicted rating for "Bourne Ultimatum, The (2007)" would be 3.5 stars.
# Predicted rating for Bourne Ultimatum, The (2007): None
# Predicted rating for Braveheart (1995): 4.5
# Predicted rating for The Butterfly Effect (2004): 3.0
# Predicted rating for 25th Hour (2002): 4.0
# Predicted rating for Happy Gilmore (1996): 3.5
# Unexpected response for 'Lost World: Jurassic Park, The (1997)': Based on the given rating history, the predicted rating for "Lost World: Jurassic Park, The (1997)" is 3.5 stars.
# Predicted rating for Lost World: Jurassic Park, The (1997): None
# Predicted rating for It Comes at Night (2017): 3.0
# Predicted rating for Missing (1982): 3.5
# Predicted rating for Twilight Samurai, The (Tasogare Seibei) (2002): 3.0
# Predicted rating for Duma (2005): 4.5
# Predicted rating for Iron Giant, The (1999): 4.0
# Predicted rating for I'm Not Scared (Io non ho paura) (2003): 4.0
# Predicted rating for Network (1976): 4.5
# Predicted rating for Angel's Egg (Tenshi no tamago) (1985): 3.0
# Unexpected response for 'Funny Thing Happened on the Way to the Forum, A (1966)': Based on the user's rating history, the predicted rating for the movie "Funny Thing Happened on the Way to the Forum, A (1966)" would be 4.0 stars.
# Predicted rating for Funny Thing Happened on the Way to the Forum, A (1966): None
# Predicted rating for Murder on a Sunday Morning (Un coupable idéal) (2001): 3.5
# Predicted rating for History of Violence, A (2005): 4.0
# Predicted rating for Talented Mr. Ripley, The (1999): 4.0
# Predicted rating for Good Copy Bad Copy (2007): 3.5
# Predicted rating for Butch Cassidy and the Sundance Kid (1969): 4.0
# Predicted rating for Never Been Kissed (1999): 3.5
# Predicted rating for Alfie (1966): 3.0
# Unexpected response for 'Cry in the Dark, A (1988)': Based on the rating history, the predicted user rating for the movie "Cry in the Dark, A (1988)" would be 3.5 stars.
# Predicted rating for Cry in the Dark, A (1988): None
# Predicted rating for Triplets of Belleville, The (Les triplettes de Belleville) (2003): 4.0
# Unexpected response for 'Battle Royale (Batoru rowaiaru) (2000)': Based on the user's rating history, the predicted rating for "Battle Royale (Batoru rowaiaru) (2000)" is 4.0 stars.
# Predicted rating for Battle Royale (Batoru rowaiaru) (2000): None
# Predicted rating for Mean Girls (2004): 4.5
# Predicted rating for Persuasion (1995): 3.5
# Unexpected response for 'Legal Eagles (1986)': Based on the user's rating history, it is predicted that the user would rate the movie 'Legal Eagles (1986)' with 4.0 stars.
# Predicted rating for Legal Eagles (1986): None
# Predicted rating for The Hateful Eight (2015): 4.5
# Predicted rating for Jetée, La (1962): 3.0
# Predicted rating for Next Stop Wonderland (1998): 4.0
# Predicted rating for Mighty Aphrodite (1995): 4.0
# Unexpected response for 'Up (2009)': Based on the given rating history, the predicted rating for the movie "Up (2009)" would be 4.0 stars.
# Predicted rating for Up (2009): None
# Predicted rating for Winged Migration (Peuple migrateur, Le) (2001): 4.0
# Predicted rating for Hulk (2003): 4.0
# Predicted rating for Batman v Superman: Dawn of Justice (2016): 4.0
# Predicted rating for Imitation of Life (1959): 4.5
# Predicted rating for Invisible Man, The (1933): 3.0
# Predicted rating for Invisible, The (2007): 4.0
# Predicted rating for West Side Story (1961): 4.5
# Predicted rating for Constant Gardener, The (2005): 3.5
# Root Mean Squared Error (RMSE): 1.085842554910266
# Mean Absolute Error (MAE): 0.8986486486486487
# CPU times: user 791 ms, sys: 136 ms, total: 927 ms
# Wall time: 52.5 s

# %%
# demonstrate the output of 4 random historical ratings
predicted_ratings = []
for title in data['title'].unique():
    # Randomly sample 4 rows from the entire dataset
    rating_history_samples = data.sample(4)
    rating_history_str = ', '.join([f"{row['title']} ({row['rating']} stars)" for _, row in rating_history_samples.iterrows()])

rating_history_str
# Out:
# "Imitation of Life (1959) (4.0 stars), Enigma (2001) (2.5 stars), Seven (a.k.a. Se7en) (1995) (5.0 stars), Angel's Egg (Tenshi no tamago) (1985) (3.5 stars)"

# %% [markdown]
# # References
#
# + https://platform.openai.com/docs/api-reference/authentication
