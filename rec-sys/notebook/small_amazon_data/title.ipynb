# %%
import numpy as np
import openai
import pandas as pd
import os
import sys
import time

# Add the path to the constants file to the system path
sys.path.append('../../')
from constants import *
from evaluation_utils import *
from path_utils import *
from ChatCompletion_OpenAI_API import *

# OpenAI API Key
openai.api_key = OPENAI_API_KEY

# %%
# source code folder path
rec_sys_dir = get_rec_sys_directory()
print(f"Rec-sys directory: {rec_sys_dir}")

# data folder path
DATA_DIR = os.path.join(rec_sys_dir, 'data')
print(f"Data directory: {DATA_DIR}")

# data path
data_path = os.path.join(DATA_DIR, 'amazon-beauty/merged_data.csv')
print(f'Data path: {data_path}')

# zero shot save path
ZERO_SHOT_SAVE_PATH = os.path.join(DATA_DIR, 'amazon-beauty/title_small_predictions_zero_shot.csv')
print(f'Zero shot save path: {ZERO_SHOT_SAVE_PATH}')

# few shot save path
FEW_SHOT_1_OBS_SAVE_PATH = os.path.join(DATA_DIR, 'amazon-beauty/title_small_1_test_predictions_few_shot.csv')
print(f'Few shot save path: {FEW_SHOT_1_OBS_SAVE_PATH}')
# Out:
# Rec-sys directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys
# Data directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data
# Data path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/merged_data.csv
# Zero shot save path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/title_small_predictions_zero_shot.csv
# Few shot save path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/title_small_1_test_predictions_few_shot.csv

# %% [markdown]
# # Data Overview

# %%
# Read the data
data = pd.read_csv(data_path)

# get statistic and first few data of NUM_SAMPLES rows
data.info()
data.head(NUM_EXAMPLES)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rating          34 non-null     float64
#  1   verified        34 non-null     bool
#  2   reviewTime      34 non-null     object
#  3   reviewerID      34 non-null     object
#  4   asin            34 non-null     object
#  5   reviewerName    34 non-null     object
#  6   reviewText      34 non-null     object
#  7   summary         34 non-null     object
#  8   unixReviewTime  34 non-null     object
#  9   vote            3 non-null      float64
#  10  style           17 non-null     object
#  11  category        34 non-null     object
#  12  tech1           0 non-null      float64
#  13  description     34 non-null     object
#  14  fit             0 non-null      float64
#  15  title           34 non-null     object
#  16  also_buy        34 non-null     object
#  17  tech2           0 non-null      float64
#  18  brand           26 non-null     object
#  19  feature         34 non-null     object
#  20  rank            34 non-null     float64
#  21  also_view       34 non-null     object
#  22  details         34 non-null     object
#  23  main_cat        34 non-null     object
#  24  similar_item    1 non-null      object
#  25  date            0 non-null      float64
#  26  price           14 non-null     float64
# dtypes: bool(1), float64(8), object(18)
# memory usage: 7.1+ KB
#    rating  verified  reviewTime      reviewerID        asin     reviewerName  \
# 0     5.0      True  2015-09-17    ANV9L0JU6BNL  B000052YAN           Dennis
# 1     5.0      True  2015-09-17    ANV9L0JU6BNL  B000052YAN           Dennis
# 2     2.0      True  2018-03-27  A2TU781PWGS09X  B00006L9LC  Amazon Customer
# 3     2.0      True  2018-03-27  A2TU781PWGS09X  B00006L9LC  Amazon Customer
# 4     5.0      True  2017-02-02  A3A8F2URN7MEPR  B00006L9LC        Sheila T.
#
#                                           reviewText               summary  \
# 0  best floss i've used. does not break as easily...  best floss i've used
# 1  best floss i've used. does not break as easily...  best floss i've used
# 2                                       Doesnt smell             Two Stars
# 3                                       Doesnt smell             Two Stars
# 4                                My favorite powder!            Five Stars
#
#   unixReviewTime  vote  ... tech2        brand  feature   rank  \
# 0     2015-09-17   NaN  ...   NaN        Reach       []  120.0
# 1     2015-09-17   NaN  ...   NaN        Reach       []  120.0
# 2     2018-03-27   NaN  ...   NaN  Citre Shine       []    1.0
# 3     2018-03-27   NaN  ...   NaN  Citre Shine       []    1.0
# 4     2017-02-02   NaN  ...   NaN  Citre Shine       []    1.0
#
#                                            also_view  \
# 0  ['B01I9TJRN4', 'B003XDVERE', 'B0722XHMGZ', 'B0...
# 1  ['B01I9TJRN4', 'B003XDVERE', 'B0722XHMGZ', 'B0...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                              details    main_cat  \
# 0  {'\n    Product Dimensions: \n    ': '1 x 1 x ...  All Beauty
# 1  {'\n    Product Dimensions: \n    ': '1 x 1 x ...  All Beauty
# 2  {'ASIN: ': 'B00006L9LC', 'UPC:': '795827187965...  All Beauty
# 3  {'ASIN: ': 'B00006L9LC', 'UPC:': '795827187965...  All Beauty
# 4  {'ASIN: ': 'B00006L9LC', 'UPC:': '795827187965...  All Beauty
#
#    similar_item date  price
# 0           NaN  NaN   5.17
# 1           NaN  NaN   5.17
# 2           NaN  NaN  23.00
# 3           NaN  NaN  23.00
# 4           NaN  NaN  23.00
#
# [5 rows x 27 columns]

# %% [markdown]
# # Zero-shot (OpenAI API)

# %%
# %%time

predict_ratings_zero_shot_and_save(data,
                                       columns_for_prediction=['title'],
                                       pause_every_n_users=PAUSE_EVERY_N_USERS,
                                       sleep_time=SLEEP_TIME,
                                       save_path=ZERO_SHOT_SAVE_PATH)
# Out:
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Reach Dentotape Waxed Dental Floss with Extra Wide Cleaning Surface for Large Spaces between Teeth, Unflavored, 100 Yards, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 1/34
#
# Details: Reach Dentotape Waxed Dental Floss with Extra Wide Cleaning Surface for Large Spaces between Teeth, Unflavored, 100 Yards
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Reach Dentotape Waxed Dental Floss with Extra Wide Cleaning Surface for Large Spaces between Teeth, Unflavored, 100 Yards, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 2/34
#
# Details: Reach Dentotape Waxed Dental Floss with Extra Wide Cleaning Surface for Large Spaces between Teeth, Unflavored, 100 Yards
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Citre Shine Moisture Burst Shampoo - 16 fl oz, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 3/34
#
# Details: Citre Shine Moisture Burst Shampoo - 16 fl oz
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Citre Shine Moisture Burst Shampoo - 16 fl oz, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 4/34
#
# Details: Citre Shine Moisture Burst Shampoo - 16 fl oz
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Citre Shine Moisture Burst Shampoo - 16 fl oz, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 5/34
#
# Details: Citre Shine Moisture Burst Shampoo - 16 fl oz
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Citre Shine Moisture Burst Shampoo - 16 fl oz, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 6/34
#
# Details: Citre Shine Moisture Burst Shampoo - 16 fl oz
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bonne Bell Smackers Bath and Body Starburst Collection, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 7/34
#
# Details: Bonne Bell Smackers Bath and Body Starburst Collection
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bonne Bell Smackers Bath and Body Starburst Collection, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "Rating: 4"
# Processing item 8/34
#
# Details: Bonne Bell Smackers Bath and Body Starburst Collection
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 9/34
#
# Details: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 10/34
#
# Details: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Pausing for 60 seconds...
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 11/34
#
# Details: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 12/34
#
# Details: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Zapzyt Maximum Strength 10% Benzoyl Peroxide Acne Treatment Gel, 1 Ounce, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 13/34
#
# Details: Zapzyt Maximum Strength 10% Benzoyl Peroxide Acne Treatment Gel, 1 Ounce
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Zapzyt Maximum Strength 10% Benzoyl Peroxide Acne Treatment Gel, 1 Ounce, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 14/34
#
# Details: Zapzyt Maximum Strength 10% Benzoyl Peroxide Acne Treatment Gel, 1 Ounce
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 15/34
#
# Details: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 16/34
#
# Details: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Astra Platinum Double Edge Safety Razor Blades ,100 Blades (20 x 5), and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 17/34
#
# Details: Astra Platinum Double Edge Safety Razor Blades ,100 Blades (20 x 5)
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Mehron Makeup Skin Prep Pro (4 oz), and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 18/34
#
# Details: Mehron Makeup Skin Prep Pro (4 oz)
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Vktech&reg; 20pcs Mix Colors Rhinestone Nose Studs Ring Bone Bar Pin Piercing Jewelry, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 19/34
#
# Details: Vktech&reg; 20pcs Mix Colors Rhinestone Nose Studs Ring Bone Bar Pin Piercing Jewelry
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Vintage Cinderella Pumpkin Carriage Locket Pendant Chain Necklace Xmas Gift, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 20/34
#
# Details: Vintage Cinderella Pumpkin Carriage Locket Pendant Chain Necklace Xmas Gift
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Pausing for 60 seconds...
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Professional Waterproof Black Elegant EyeLiner Beauty Gel Mascara + Eyeliner Brush Makeup Tools, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 21/34
#
# Details: Professional Waterproof Black Elegant EyeLiner Beauty Gel Mascara + Eyeliner Brush Makeup Tools
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Charming Silver Colored Earring / Ear Cuff / Clip In Snake / Spiral Shape By VAGA, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 22/34
#
# Details: Charming Silver Colored Earring / Ear Cuff / Clip In Snake / Spiral Shape By VAGA
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Maquita Waterproof Portable Face Facial Highlighter Stick Shimmer Powder Makeup Silver, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 23/34
#
# Details: Maquita Waterproof Portable Face Facial Highlighter Stick Shimmer Powder Makeup Silver
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Maquita Waterproof Portable Face Facial Highlighter Stick Shimmer Powder Makeup Silver, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 24/34
#
# Details: Maquita Waterproof Portable Face Facial Highlighter Stick Shimmer Powder Makeup Silver
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: ROPALIA Cosmetic Makeup Waterproof Moisturize Lipstick Lip Stick Lip Gloss, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 25/34
#
# Details: ROPALIA Cosmetic Makeup Waterproof Moisturize Lipstick Lip Stick Lip Gloss
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Weixinbuy 1PC Secret Jelly Lipstick Color Changing Long Lasting Lip Gloss Random Color, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "3 stars, 60%"
# Processing item 26/34
#
# Details: Weixinbuy 1PC Secret Jelly Lipstick Color Changing Long Lasting Lip Gloss Random Color
#
# Predicted Rating: 3.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Oud Wood Oil. IMPRESSION of Tom Ford Oud Wood* Cologne for Men with SIMILAR Fragrance Accords, 10ml Amber Glass Roller, Black Cap; 100% Pure (Perfume Studio Oud Wood VERSION/TYPE; Not Original Brand), and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 27/34
#
# Details: Oud Wood Oil. IMPRESSION of Tom Ford Oud Wood* Cologne for Men with SIMILAR Fragrance Accords, 10ml Amber Glass Roller, Black Cap; 100% Pure (Perfume Studio Oud Wood VERSION/TYPE; Not Original Brand)
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: ABASSKY Lip Gloss Lipstick Matte Velvet Waterproof Super Long Lasting Not Fade (#18), and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 28/34
#
# Details: ABASSKY Lip Gloss Lipstick Matte Velvet Waterproof Super Long Lasting Not Fade (#18)
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: BIOAQUA 24K Gold Essence Collagen Skin Face Moisturizing Hyaluronic Acid Mask, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 29/34
#
# Details: BIOAQUA 24K Gold Essence Collagen Skin Face Moisturizing Hyaluronic Acid Mask
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Urparcel Liquid Foundation Smooth Natural Long Lasting Makeup Beauty Cosmetics, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 85%"
# Processing item 30/34
#
# Details: Urparcel Liquid Foundation Smooth Natural Long Lasting Makeup Beauty Cosmetics
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Pausing for 60 seconds...
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: (Pack of 3) L.A. Colors Mineral Pressed Powder #Mp303 &quot;Creamy Natural&quot;, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 31/34
#
# Details: (Pack of 3) L.A. Colors Mineral Pressed Powder #Mp303 &quot;Creamy Natural&quot;
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Orangesky Professional 15 Concealer Camouflage Foundation Makeup Palette, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 32/34
#
# Details: Orangesky Professional 15 Concealer Camouflage Foundation Makeup Palette
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Dolce &amp; Gabbana Compact Parfum, 0.05 Ounce, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 33/34
#
# Details: Dolce &amp; Gabbana Compact Parfum, 0.05 Ounce
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Constructed Prompt for zero-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Sankuwen 15PCs Wool Makeup Brush Set Tools Toiletry Kit, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4"
# Processing item 34/34
#
# Details: Sankuwen 15PCs Wool Makeup Brush Set Tools Toiletry Kit
#
# Predicted Rating: 4.0 stars
#
# ------------------------------------
#
# Predictions saved to /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/title_small_predictions_zero_shot.csv
# CPU times: user 264 ms, sys: 33.7 ms, total: 298 ms
# Wall time: 3min 30s

# %%
evaluate_model_predictions_rmse_mae(
    data_path=ZERO_SHOT_SAVE_PATH,
    num_examples=NUM_EXAMPLES,
    actual_ratings_column='rating',
    predicted_ratings_column='zero_shot_predicted_rating'
)
# Out:
# RMSE: 1.3253 (95% CI: (1.1504, 1.4951)) ± 0.0017
# MAE: 1.2352 (95% CI: (1.0882, 1.4118)) ± 0.0016
#
# First few actual vs predicted ratings:
# Actual: 5.0, Predicted: 4.0000
# Actual: 5.0, Predicted: 4.0000
# Actual: 2.0, Predicted: 4.0000
# Actual: 2.0, Predicted: 4.0000
# Actual: 5.0, Predicted: 4.0000

# %% [markdown]
# # Few-shot (OpenAI API)
#
#
# + For each user, we'll use 4 of their ratings as training data to predict ratings for the rest of their products. Finally, we'll evaluate the predictions against the actual ratings to calculate the overall RMSE and MAE.
#
# + The rating_history_str now includes both the title and the review text for each of the training data rows

# %% [markdown]
# # 1 observation per reviewer - Few-shot OpenAI

# %%
# %%time

predict_ratings_few_shot_and_save(data,
                                      columns_for_training=['title'],
                                       columns_for_prediction=['title'],
                                       obs_per_user=1,
                                       pause_every_n_users=PAUSE_EVERY_N_USERS,
                                       sleep_time=SLEEP_TIME,
                                       save_path=FEW_SHOT_1_OBS_SAVE_PATH)
# Out:
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Astra Platinum Double Edge Safety Razor Blades ,100 Blades (20 x 5), and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Zapzyt Maximum Strength 10% Benzoyl Peroxide Acne Treatment Gel, 1 Ounce - Rating: 5.0 stars
# * title: Oud Wood Oil. IMPRESSION of Tom Ford Oud Wood* Cologne for Men with SIMILAR Fragrance Accords, 10ml Amber Glass Roller, Black Cap; 100% Pure (Perfume Studio Oud Wood VERSION/TYPE; Not Original Brand) - Rating: 2.0 stars
# * title: Reach Dentotape Waxed Dental Floss with Extra Wide Cleaning Surface for Large Spaces between Teeth, Unflavored, 100 Yards - Rating: 5.0 stars
# * title: Zapzyt Maximum Strength 10% Benzoyl Peroxide Acne Treatment Gel, 1 Ounce - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "3 stars, 60%"
# Processing user 1/5, item 1/6
# User ANV9L0JU6BNL:
# Rating History for Prediction:
# * title: Zapzyt Maximum Strength 10% Benzoyl Peroxide Acne Treatment Gel, 1 Ounce - Rating: 5.0 stars
# * title: Oud Wood Oil. IMPRESSION of Tom Ford Oud Wood* Cologne for Men with SIMILAR Fragrance Accords, 10ml Amber Glass Roller, Black Cap; 100% Pure (Perfume Studio Oud Wood VERSION/TYPE; Not Original Brand) - Rating: 2.0 stars
# * title: Reach Dentotape Waxed Dental Floss with Extra Wide Cleaning Surface for Large Spaces between Teeth, Unflavored, 100 Yards - Rating: 5.0 stars
# * title: Zapzyt Maximum Strength 10% Benzoyl Peroxide Acne Treatment Gel, 1 Ounce - Rating: 5.0 stars
# Predicted Item: Astra Platinum Double Edge Safety Razor Blades ,100 Blades (20 x 5) (Code: B001QY8QXM)
# Predicted Rating: 3.0 stars
#
# ----------------
#
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 2.0 stars
# * title: Dolce &amp; Gabbana Compact Parfum, 0.05 Ounce - Rating: 2.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 2.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 2.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "2 stars, 40%"
# Processing user 2/5, item 1/7
# User A2TU781PWGS09X:
# Rating History for Prediction:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 2.0 stars
# * title: Dolce &amp; Gabbana Compact Parfum, 0.05 Ounce - Rating: 2.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 2.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 2.0 stars
# Predicted Item: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz (Code: B0012Y0ZG2)
# Predicted Rating: 2.0 stars
#
# ----------------
#
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: (Pack of 3) L.A. Colors Mineral Pressed Powder #Mp303 &quot;Creamy Natural&quot; - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4.0 stars"
# Processing user 3/5, item 1/7
# User A3A8F2URN7MEPR:
# Rating History for Prediction:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: (Pack of 3) L.A. Colors Mineral Pressed Powder #Mp303 &quot;Creamy Natural&quot; - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
# Predicted Item: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz (Code: B0012Y0ZG2)
# Predicted Rating: 4.0 stars
#
# ----------------
#
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Maquita Waterproof Portable Face Facial Highlighter Stick Shimmer Powder Makeup Silver, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Urparcel Liquid Foundation Smooth Natural Long Lasting Makeup Beauty Cosmetics - Rating: 5.0 stars
# * title: BIOAQUA 24K Gold Essence Collagen Skin Face Moisturizing Hyaluronic Acid Mask - Rating: 5.0 stars
# * title: Orangesky Professional 15 Concealer Camouflage Foundation Makeup Palette - Rating: 5.0 stars
# * title: Mehron Makeup Skin Prep Pro (4 oz) - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "3 stars, 60%"
# Processing user 4/5, item 1/7
# User A1U8L4X1O2LXXF:
# Rating History for Prediction:
# * title: Urparcel Liquid Foundation Smooth Natural Long Lasting Makeup Beauty Cosmetics - Rating: 5.0 stars
# * title: BIOAQUA 24K Gold Essence Collagen Skin Face Moisturizing Hyaluronic Acid Mask - Rating: 5.0 stars
# * title: Orangesky Professional 15 Concealer Camouflage Foundation Makeup Palette - Rating: 5.0 stars
# * title: Mehron Makeup Skin Prep Pro (4 oz) - Rating: 5.0 stars
# Predicted Item: Maquita Waterproof Portable Face Facial Highlighter Stick Shimmer Powder Makeup Silver (Code: B010B5ZE4U)
# Predicted Rating: 3.0 stars
#
# ----------------
#
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: ROPALIA Cosmetic Makeup Waterproof Moisturize Lipstick Lip Stick Lip Gloss, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: ABASSKY Lip Gloss Lipstick Matte Velvet Waterproof Super Long Lasting Not Fade (#18) - Rating: 4.0 stars
# * title: Weixinbuy 1PC Secret Jelly Lipstick Color Changing Long Lasting Lip Gloss Random Color - Rating: 5.0 stars
# * title: Sankuwen 15PCs Wool Makeup Brush Set Tools Toiletry Kit - Rating: 5.0 stars
# * title: Vktech&reg; 20pcs Mix Colors Rhinestone Nose Studs Ring Bone Bar Pin Piercing Jewelry - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "3 stars, 60%"
# Processing user 5/5, item 1/7
# User A38IPSLKOQ5O2F:
# Rating History for Prediction:
# * title: ABASSKY Lip Gloss Lipstick Matte Velvet Waterproof Super Long Lasting Not Fade (#18) - Rating: 4.0 stars
# * title: Weixinbuy 1PC Secret Jelly Lipstick Color Changing Long Lasting Lip Gloss Random Color - Rating: 5.0 stars
# * title: Sankuwen 15PCs Wool Makeup Brush Set Tools Toiletry Kit - Rating: 5.0 stars
# * title: Vktech&reg; 20pcs Mix Colors Rhinestone Nose Studs Ring Bone Bar Pin Piercing Jewelry - Rating: 5.0 stars
# Predicted Item: ROPALIA Cosmetic Makeup Waterproof Moisturize Lipstick Lip Stick Lip Gloss (Code: B010L79142)
# Predicted Rating: 3.0 stars
#
# ----------------
#
# CPU times: user 36.8 ms, sys: 5.39 ms, total: 42.2 ms
# Wall time: 4.51 s

# %%
evaluate_model_predictions_rmse_mae(
    data_path=FEW_SHOT_1_OBS_SAVE_PATH,
    num_examples=NUM_EXAMPLES,
    actual_ratings_column='actual_rating',
    predicted_ratings_column='few_shot_predicted_rating'
)
# Out:
# RMSE: 1.2981 (95% CI: (0.4472, 1.8439)) ± 0.0068
# MAE: 1.0018 (95% CI: (0.2000, 1.8000)) ± 0.0078
#
# First few actual vs predicted ratings:
# Actual: 5.0, Predicted: 3.0000
# Actual: 2.0, Predicted: 2.0000
# Actual: 5.0, Predicted: 4.0000
# Actual: 5.0, Predicted: 3.0000
# Actual: 3.0, Predicted: 3.0000

# %% [markdown]
# # Limitations:
#
# The model might not fully understand the nuanced relationships between products based on titles alone. Additional context or features might be needed for more accurate predictions.
# This approach might be computationally expensive and slower than traditional matrix factorization or deep learning-based recommendation models, especially for a small number of users.
#
# # References
#
# + https://platform.openai.com/docs/api-reference/authentication
