# %%
import numpy as np
import openai
import pandas as pd
import os
import sys
import time

# Add the path to the constants file to the system path
sys.path.append('../../')
from constants import *
from evaluation_utils import *
from path_utils import *
from ChatCompletion_OpenAI_API import *

# OpenAI API Key
openai.api_key = OPENAI_API_KEY

# %%
# source code folder path
rec_sys_dir = get_rec_sys_directory()
print(f"Rec-sys directory: {rec_sys_dir}")

# data folder path
DATA_DIR = os.path.join(rec_sys_dir, 'data')
print(f"Data directory: {DATA_DIR}")

# data path
data_path = os.path.join(DATA_DIR, 'amazon-beauty/merged_data.csv')
print(f'Data path: {data_path}')

# zero shot save path
ZERO_SHOT_SAVE_PATH = os.path.join(DATA_DIR, 'amazon-beauty/all_small_predictions_zero_shot.csv')
print(f'Zero shot save path: {ZERO_SHOT_SAVE_PATH}')

# few shot save path
FEW_SHOT_1_OBS_SAVE_PATH = os.path.join(DATA_DIR, 'amazon-beauty/all_small_1_test_predictions_few_shot.csv')
print(f'Few shot save path: {FEW_SHOT_1_OBS_SAVE_PATH}')
# Out:
# Rec-sys directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys
# Data directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data
# Data path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/merged_data.csv
# Zero shot save path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/all_small_predictions_zero_shot.csv
# Few shot save path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/all_small_1_test_predictions_few_shot.csv

# %% [markdown]
# # Data Overview

# %%
# Read the data
data = pd.read_csv(data_path)

# get statistic and first few data of NUM_SAMPLES rows
data.info()
data.head(NUM_EXAMPLES)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rating          34 non-null     float64
#  1   verified        34 non-null     bool
#  2   reviewTime      34 non-null     object
#  3   reviewerID      34 non-null     object
#  4   asin            34 non-null     object
#  5   reviewerName    34 non-null     object
#  6   reviewText      34 non-null     object
#  7   summary         34 non-null     object
#  8   unixReviewTime  34 non-null     object
#  9   vote            3 non-null      float64
#  10  style           17 non-null     object
#  11  category        34 non-null     object
#  12  tech1           0 non-null      float64
#  13  description     34 non-null     object
#  14  fit             0 non-null      float64
#  15  title           34 non-null     object
#  16  also_buy        34 non-null     object
#  17  tech2           0 non-null      float64
#  18  brand           26 non-null     object
#  19  feature         34 non-null     object
#  20  rank            34 non-null     float64
#  21  also_view       34 non-null     object
#  22  details         34 non-null     object
#  23  main_cat        34 non-null     object
#  24  similar_item    1 non-null      object
#  25  date            0 non-null      float64
#  26  price           14 non-null     float64
# dtypes: bool(1), float64(8), object(18)
# memory usage: 7.1+ KB
#    rating  verified  reviewTime      reviewerID        asin     reviewerName  \
# 0     5.0      True  2015-09-17    ANV9L0JU6BNL  B000052YAN           Dennis
# 1     5.0      True  2015-09-17    ANV9L0JU6BNL  B000052YAN           Dennis
# 2     2.0      True  2018-03-27  A2TU781PWGS09X  B00006L9LC  Amazon Customer
# 3     2.0      True  2018-03-27  A2TU781PWGS09X  B00006L9LC  Amazon Customer
# 4     5.0      True  2017-02-02  A3A8F2URN7MEPR  B00006L9LC        Sheila T.
#
#                                           reviewText               summary  \
# 0  best floss i've used. does not break as easily...  best floss i've used
# 1  best floss i've used. does not break as easily...  best floss i've used
# 2                                       Doesnt smell             Two Stars
# 3                                       Doesnt smell             Two Stars
# 4                                My favorite powder!            Five Stars
#
#   unixReviewTime  vote  ... tech2        brand  feature   rank  \
# 0     2015-09-17   NaN  ...   NaN        Reach       []  120.0
# 1     2015-09-17   NaN  ...   NaN        Reach       []  120.0
# 2     2018-03-27   NaN  ...   NaN  Citre Shine       []    1.0
# 3     2018-03-27   NaN  ...   NaN  Citre Shine       []    1.0
# 4     2017-02-02   NaN  ...   NaN  Citre Shine       []    1.0
#
#                                            also_view  \
# 0  ['B01I9TJRN4', 'B003XDVERE', 'B0722XHMGZ', 'B0...
# 1  ['B01I9TJRN4', 'B003XDVERE', 'B0722XHMGZ', 'B0...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                              details    main_cat  \
# 0  {'\n    Product Dimensions: \n    ': '1 x 1 x ...  All Beauty
# 1  {'\n    Product Dimensions: \n    ': '1 x 1 x ...  All Beauty
# 2  {'ASIN: ': 'B00006L9LC', 'UPC:': '795827187965...  All Beauty
# 3  {'ASIN: ': 'B00006L9LC', 'UPC:': '795827187965...  All Beauty
# 4  {'ASIN: ': 'B00006L9LC', 'UPC:': '795827187965...  All Beauty
#
#    similar_item date  price
# 0           NaN  NaN   5.17
# 1           NaN  NaN   5.17
# 2           NaN  NaN  23.00
# 3           NaN  NaN  23.00
# 4           NaN  NaN  23.00
#
# [5 rows x 27 columns]

# %% [markdown]
# # Zero-shot (OpenAI API)

# %%
# %%time

predict_ratings_zero_shot_and_save(data,
                                       columns_for_prediction=ITEM_SIDE,
                                       pause_every_n_users=PAUSE_EVERY_N_USERS,
                                       sleep_time=SLEEP_TIME,
                                       save_path=ZERO_SHOT_SAVE_PATH)
# Out:
# System Fingerprint: fp_eeff13170a
# Processing item 1/34
#
# Details: Reach Dentotape Waxed Dental Floss with Extra Wide Cleaning Surface for Large Spaces between Teeth, Unflavored, 100 Yards
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 2/34
#
# Details: Reach Dentotape Waxed Dental Floss with Extra Wide Cleaning Surface for Large Spaces between Teeth, Unflavored, 100 Yards
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 3/34
#
# Details: Citre Shine Moisture Burst Shampoo - 16 fl oz
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 4/34
#
# Details: Citre Shine Moisture Burst Shampoo - 16 fl oz
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 5/34
#
# Details: Citre Shine Moisture Burst Shampoo - 16 fl oz
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 6/34
#
# Details: Citre Shine Moisture Burst Shampoo - 16 fl oz
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 7/34
#
# Details: Bonne Bell Smackers Bath and Body Starburst Collection
#
# Predicted Rating: 3.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 8/34
#
# Details: Bonne Bell Smackers Bath and Body Starburst Collection
#
# Predicted Rating: 3.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 9/34
#
# Details: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 10/34
#
# Details: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# Pausing for 60 seconds...
# System Fingerprint: fp_eeff13170a
# Processing item 11/34
#
# Details: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 12/34
#
# Details: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the details provided, the product's rating might be influenced by factors such as the strength and effectiveness of the 10% benzoyl peroxide formula, its ability to kill acne-causing bacteria, the speed at which it clears acne pimples and blackheads, and its oil-free and odorless properties. Additionally, the product's dimensions, shipping weight, and availability for domestic shipping within the U.S. might also influence its rating. Overall, considering the strength and effectiveness of the formula, as well as its practical aspects, I would rate this product a 4 out of 5.
# Processing item 13/34
#
# Details: Zapzyt Maximum Strength 10% Benzoyl Peroxide Acne Treatment Gel, 1 Ounce
#
# Predicted Rating: 0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the details provided, the product's rating might be influenced by factors such as the strength and effectiveness of the 10% benzoyl peroxide formula, its ability to kill acne-causing bacteria, the speed at which it clears acne pimples and blackheads, and its oil-free and odorless properties. Additionally, the product's dimensions, shipping weight, and availability for domestic shipping within the U.S. might also influence its rating. Overall, considering the strength and effectiveness of the formula, as well as the practical aspects of the product, I would rate it a 4 out of 5.
# Processing item 14/34
#
# Details: Zapzyt Maximum Strength 10% Benzoyl Peroxide Acne Treatment Gel, 1 Ounce
#
# Predicted Rating: 0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 15/34
#
# Details: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 16/34
#
# Details: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 17/34
#
# Details: Astra Platinum Double Edge Safety Razor Blades ,100 Blades (20 x 5)
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the details provided, the Mehron Makeup Skin Prep Pro seems to offer several appealing features such as extending makeup wear, providing a long-lasting under stressful performance conditions, and having an advanced moisture barrier. Additionally, the fact that it is suitable for all skin types and proudly made in the USA since 1927 could also positively influence its rating. Considering these factors, I would rate this product a 4 out of 5.
# Processing item 18/34
#
# Details: Mehron Makeup Skin Prep Pro (4 oz)
#
# Predicted Rating: 0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 19/34
#
# Details: Vktech&reg; 20pcs Mix Colors Rhinestone Nose Studs Ring Bone Bar Pin Piercing Jewelry
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 20/34
#
# Details: Vintage Cinderella Pumpkin Carriage Locket Pendant Chain Necklace Xmas Gift
#
# Predicted Rating: 3.0 stars
#
# ----------------
#
# Pausing for 60 seconds...
# System Fingerprint: fp_eeff13170a
# Processing item 21/34
#
# Details: Professional Waterproof Black Elegant EyeLiner Beauty Gel Mascara + Eyeliner Brush Makeup Tools
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 22/34
#
# Details: Charming Silver Colored Earring / Ear Cuff / Clip In Snake / Spiral Shape By VAGA
#
# Predicted Rating: 3.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 23/34
#
# Details: Maquita Waterproof Portable Face Facial Highlighter Stick Shimmer Powder Makeup Silver
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 24/34
#
# Details: Maquita Waterproof Portable Face Facial Highlighter Stick Shimmer Powder Makeup Silver
#
# Predicted Rating: 2.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the limited details provided, it's difficult to accurately assess the potential rating of the product. However, some factors that might influence the product's rating could include the effectiveness of the waterproof and moisturizing properties, the longevity of the lipstick, the color payoff, the overall comfort and feel on the lips, and the brand reputation for quality cosmetics. Without more specific information, it's challenging to provide a precise rating.
# Processing item 25/34
#
# Details: ROPALIA Cosmetic Makeup Waterproof Moisturize Lipstick Lip Stick Lip Gloss
#
# Predicted Rating: 0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 26/34
#
# Details: Weixinbuy 1PC Secret Jelly Lipstick Color Changing Long Lasting Lip Gloss Random Color
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 27/34
#
# Details: Oud Wood Oil. IMPRESSION of Tom Ford Oud Wood* Cologne for Men with SIMILAR Fragrance Accords, 10ml Amber Glass Roller, Black Cap; 100% Pure (Perfume Studio Oud Wood VERSION/TYPE; Not Original Brand)
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the provided details, it is difficult to accurately assess the product's rating. The absence of a price, brand, category, description, and features makes it challenging to determine the quality and value of the product. Additionally, the lack of customer reviews and ratings further complicates the assessment. Therefore, without more information, it is not possible to provide a reliable rating for this product.
# Processing item 28/34
#
# Details: ABASSKY Lip Gloss Lipstick Matte Velvet Waterproof Super Long Lasting Not Fade (#18)
#
# Predicted Rating: 0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 29/34
#
# Details: BIOAQUA 24K Gold Essence Collagen Skin Face Moisturizing Hyaluronic Acid Mask
#
# Predicted Rating: 1.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the limited details provided, it's difficult to accurately assess the product's rating. However, factors that could influence the rating might include the effectiveness of the foundation in providing smooth and natural coverage, its longevity, the quality of the ingredients, the brand's reputation, and customer reviews. Without more specific information, it's challenging to provide a precise rating.
# Processing item 30/34
#
# Details: Urparcel Liquid Foundation Smooth Natural Long Lasting Makeup Beauty Cosmetics
#
# Predicted Rating: 0 stars
#
# ----------------
#
# Pausing for 60 seconds...
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the limited details provided, it's difficult to accurately assess the product's rating. However, factors that might influence the rating could include the quality and effectiveness of the mineral pressed powder, customer satisfaction, the brand's reputation, and the price point compared to similar products. Without more specific information, it's challenging to provide a precise rating.
# Processing item 31/34
#
# Details: (Pack of 3) L.A. Colors Mineral Pressed Powder #Mp303 &quot;Creamy Natural&quot;
#
# Predicted Rating: 0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the limited details provided, it's difficult to accurately assess the potential rating of the product. However, factors that could influence the rating might include the quality and coverage of the concealers, the range of shades available in the palette, the blendability and longevity of the product, and the overall value for money. Additionally, customer reviews and feedback would play a significant role in determining the product's rating. Without more specific information, it's challenging to provide a precise rating.
# Processing item 32/34
#
# Details: Orangesky Professional 15 Concealer Camouflage Foundation Makeup Palette
#
# Predicted Rating: 0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Processing item 33/34
#
# Details: Dolce &amp; Gabbana Compact Parfum, 0.05 Ounce
#
# Predicted Rating: 4.0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the limited details provided, it's difficult to accurately assess the product's rating. However, factors that might influence the rating could include the quality and softness of the wool makeup brushes, the durability of the tools, the variety of brushes included in the set, and the overall value for the price. Additionally, customer reviews and feedback on the performance and longevity of the brushes would also play a significant role in determining the product's rating. Without more specific information, it's challenging to provide a precise rating.
# Processing item 34/34
#
# Details: Sankuwen 15PCs Wool Makeup Brush Set Tools Toiletry Kit
#
# Predicted Rating: 0 stars
#
# ----------------
#
# Predictions saved to /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/all_small_predictions_zero_shot.csv
# CPU times: user 462 ms, sys: 68.1 ms, total: 530 ms
# Wall time: 5min 30s

# %%
evaluate_model_predictions_rmse_mae(
    data_path=ZERO_SHOT_SAVE_PATH,
    num_examples=NUM_EXAMPLES,
    actual_ratings_column='rating',
    predicted_ratings_column='zero_shot_predicted_rating'
)
# Out:
# RMSE: 3.5732 (95% CI: (3.1436, 3.9779)) ± 0.0041
# MAE: 3.2331 (95% CI: (2.7059, 3.7353)) ± 0.0052
#
# First few actual vs predicted ratings:
# Actual: 5.0, Predicted: 1.0000
# Actual: 5.0, Predicted: 1.0000
# Actual: 2.0, Predicted: 1.0000
# Actual: 2.0, Predicted: 1.0000
# Actual: 5.0, Predicted: 1.0000

# %% [markdown]
# # Few-shot (OpenAI API)
#
#
# + For each user, we'll use 4 of their ratings as training data to predict ratings for the rest of their products. Finally, we'll evaluate the predictions against the actual ratings to calculate the overall RMSE and MAE.
#
# + The rating_history_str now includes both the title and the review text for each of the training data rows

# %% [markdown]
# # 1 observation per reviewer - Few-shot OpenAI

# %%
# %%time

predict_ratings_few_shot_and_save(data,
                                      columns_for_training=ITEM_SIDE + USER_SIDE + INTERACTION_SIDE,
                                       columns_for_prediction=ITEM_SIDE,
                                       obs_per_user=1,
                                       pause_every_n_users=PAUSE_EVERY_N_USERS,
                                       sleep_time=SLEEP_TIME,
                                       save_path=FEW_SHOT_1_OBS_SAVE_PATH)
# Out:
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the product details provided, the Reach Dentotape Waxed Dental Floss seems to offer several appealing features such as an extra wide cleaning surface, being ADA accepted, and made in the USA. These factors could positively influence the product's rating. Additionally, the product's long length of 100 yards and the brand's reputation for producing dental care products may also contribute to a higher rating. Given the user's previous rating of 5.0 stars for this product, it seems that these features have already had a positive influence on the rating.
# Processing user 1/5, item 2/1
#
# User ANV9L0JU6BNL:
# Rating History for Prediction: B001QY8QXM (5.0 stars), B0015S8026 (5.0 stars), B01A4XPV56 (2.0 stars), B000052YAN (5.0 stars)
# Predicted Item: Reach Dentotape Waxed Dental Floss with Extra Wide Cleaning Surface for Large Spaces between Teeth, Unflavored, 100 Yards (Code: B000052YAN)
# Predicted Rating: 0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the product details provided, the rating of the Bonne Bell Smackers Bath and Body Starburst Collection might be influenced by factors such as the quality and longevity of the lip gloss, the variety and appeal of the Starburst fruit flavors, the packaging and presentation of the limited collection, and the overall value for the price. Additionally, the shipping options and international availability as mentioned in the details might also impact the rating for potential customers.
# Processing user 2/5, item 7/1
#
# User A2TU781PWGS09X:
# Rating History for Prediction: B0012Y0ZG2 (2.0 stars), B001OHV1H4 (2.0 stars), B0012Y0ZG2 (2.0 stars), B019V2KYZS (2.0 stars)
# Predicted Item: Bonne Bell Smackers Bath and Body Starburst Collection (Code: B000URXP6E)
# Predicted Rating: 0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the product details provided, the rating of the Bonne Bell Smackers Bath and Body Starburst Collection might be influenced by factors such as the variety and quality of the Starburst fruit flavored Lip Smacker lip glosses, the longevity of the juicy flavor, the smoothness of the formula, and the appeal of the limited collection offered, especially during holidays. Additionally, the shipping weight and availability for domestic shipping within the U.S. might also impact the rating for potential customers.
# Processing user 3/5, item 8/1
#
# User A3A8F2URN7MEPR:
# Rating History for Prediction: B0012Y0ZG2 (5.0 stars), B001OHV1H4 (5.0 stars), B0012Y0ZG2 (5.0 stars), B00VARTPKS (5.0 stars)
# Predicted Item: Bonne Bell Smackers Bath and Body Starburst Collection (Code: B000URXP6E)
# Predicted Rating: 0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the details provided, the product's rating might be influenced by factors such as its waterproof feature, portability, shimmer powder makeup effect, and the affordable price of $7.99. Additionally, the brand reputation and the positive ratings from other users could also contribute to the product's rating. Given the user's history of consistently rating similar beauty products with 5.0 stars, it is likely that they value qualities such as effectiveness, durability, and value for money, which could also influence their rating of this product.
# Processing user 4/5, item 23/1
#
# User A1U8L4X1O2LXXF:
# Rating History for Prediction: B010B5ZE4U (5.0 stars), B00T5W0GKS (5.0 stars), B01GZWUSYY (5.0 stars), B017LU859E (5.0 stars)
# Predicted Item: Maquita Waterproof Portable Face Facial Highlighter Stick Shimmer Powder Makeup Silver (Code: B010B5ZE4U)
# Predicted Rating: 0 stars
#
# ----------------
#
# System Fingerprint: fp_eeff13170a
# Unexpected response for the provided details: Based on the product details provided, the rating for the Charming Silver Colored Earring / Ear Cuff / Clip In Snake / Spiral Shape By VAGA might be influenced by factors such as the ease of placing the ear cuff without piercing, the quality of the material used, the design and aesthetic appeal of the snake shape, and the overall value for the price. Additionally, customer satisfaction with the brand's other products and the uniqueness of the ear cuff design could also impact the rating.
# Processing user 5/5, item 22/1
#
# User A38IPSLKOQ5O2F:
# Rating History for Prediction: B010L79142 (3.0 stars), B01DWBI43I (4.0 stars), B019DWCJDG (5.0 stars), B01FQQMNLQ (5.0 stars)
# Predicted Item: Charming Silver Colored Earring / Ear Cuff / Clip In Snake / Spiral Shape By VAGA (Code: B00RIWAJCM)
# Predicted Rating: 0 stars
#
# ----------------
#
# CPU times: user 92.7 ms, sys: 21.7 ms, total: 114 ms
# Wall time: 13.2 s

# %%
evaluate_model_predictions_rmse_mae(
    data_path=FEW_SHOT_1_OBS_SAVE_PATH,
    num_examples=NUM_EXAMPLES,
    actual_ratings_column='actual_rating',
    predicted_ratings_column='few_shot_predicted_rating'
)
# Out:
# RMSE: 4.5403 (95% CI: (3.5214, 5.0000)) ± 0.0084
# MAE: 4.3999 (95% CI: (3.2000, 5.0000)) ± 0.0105
#
# First few actual vs predicted ratings:
# Actual: 5.0, Predicted: 0.0000
# Actual: 2.0, Predicted: 0.0000
# Actual: 5.0, Predicted: 0.0000
# Actual: 5.0, Predicted: 0.0000
# Actual: 5.0, Predicted: 0.0000

# %% [markdown]
# # Limitations:
#
# The model might not fully understand the nuanced relationships between products based on titles alone. Additional context or features might be needed for more accurate predictions.
# This approach might be computationally expensive and slower than traditional matrix factorization or deep learning-based recommendation models, especially for a small number of users.
#
# # References
#
# + https://platform.openai.com/docs/api-reference/authentication
