# %%
import numpy as np
import openai
import pandas as pd
import os
from sklearn.metrics import mean_squared_error, mean_absolute_error
import sys
import re
import time
from tenacity import retry, wait_random_exponential, stop_after_attempt

# Add the path to the constants file to the system path
sys.path.append('../../')
from constants import RANDOM_STATE, OPENAI_API_KEY

# OpenAI API Key
openai.api_key = OPENAI_API_KEY
# OpenAI GPT Model parameters
GPT_MODEL_NAME = "gpt-3.5-turbo"
TEMPERATURE = 0

# Get the current directory of the notebook
current_dir = os.path.dirname(os.path.abspath("../../data/amazon-beauty/rating_prediction.ipynb"))
print(f"current directory: {current_dir}")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# current directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty

# %% [markdown]
# # RMSE & MAE evaluation metrics

# %%
# calculate RMSE and MAE manually
def calculate_rmse_and_mae(actual_ratings, predicted_ratings):
    differences = [actual - predicted for actual, predicted in zip(actual_ratings, predicted_ratings)]
    
    # RMSE
    squared_differences = [diff ** 2 for diff in differences]
    mean_squared_difference = sum(squared_differences) / len(squared_differences)
    rmse = mean_squared_difference ** 0.5

    # MAE
    absolute_differences = [abs(diff) for diff in differences]
    mae = sum(absolute_differences) / len(absolute_differences)

    return rmse, mae

# Test
actual_ratings = [4, 4]  # Ground truth ratings
predicted_ratings = [3, 5]  # Predicted ratings
rmse, mae = calculate_rmse_and_mae(actual_ratings, predicted_ratings)
print("RMSE: ", rmse)
print("MAE: ", mae)
# Out:
# RMSE:  1.0
# MAE:  1.0

# %% [markdown]
# # Data Overview

# %%
# Construct the path to data file
data_path = os.path.join(current_dir, 'large_merged_data.csv')
print(f'data path: {data_path}')
# Out:
# data path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/large_merged_data.csv

# %%
# Read the data
amazon_data = pd.read_csv(data_path)
# get sample data of NUM_SAMPLES rows
amazon_data.info()
# get neccessary columns
amazon_data = amazon_data[['title', 'rating', 'reviewText', 'reviewerID']]
amazon_data.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9767 entries, 0 to 9766
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rating      9767 non-null   float64
#  1   reviewerID  9767 non-null   object
#  2   asin        9767 non-null   object
#  3   reviewText  9759 non-null   object
#  4   summary     9759 non-null   object
#  5   title       9767 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 458.0+ KB
#                                                title  rating  \
# 0  Jenna Jameson Heartbreaker Perfume for women 3...     1.0
# 1  Norelco 6885XL Deluxe Quadra Action Cord/Cordl...     5.0
# 2  Norelco 6885XL Deluxe Quadra Action Cord/Cordl...     5.0
#
#                                           reviewText      reviewerID
# 0  I use a lot of perfume, I go through a new bot...  A2RYSCZOPEXOCQ
# 1  First, a little background.  I've switched bet...  A141OPVE376YFI
# 2  First, a little background.  I've switched bet...  A141OPVE376YFI

# %% [markdown]
# # Simple statistical methods (mean calculations)
#
# + **Zero-Shot Prediction (zero_shot_predict function):**
# This method calculates the average rating for a given product title from the `amazon_data` DataFrame.
# It does not take into account any user-specific information and predicts the rating based on the average rating of the product across all users.
#
# + **Few-Shot Prediction (few_shot_predict function):**
# This method calculates the average rating for a given product title by a specific user from the `amazon_data` DataFrame.
# It predicts the rating based on the average rating of the product by that specific user, thus incorporating user-specific information.

# %%
# %%time 

def zero_shot_predict(product_title):
    # Get the average rating for the given title
    avg_rating = amazon_data.loc[amazon_data['title'] == product_title, 'rating'].mean()
    return avg_rating

def few_shot_predict(product_title, user_id):
    # Get the average rating for the given title by the specific user
    avg_rating = amazon_data.loc[(amazon_data['title'] == product_title) & (amazon_data['reviewerID'] == user_id), 'rating'].mean()
    return avg_rating

# Applying predictions
amazon_data['predicted_rating_zero_shot'] = amazon_data['title'].apply(zero_shot_predict)
amazon_data['predicted_rating_few_shot'] = [few_shot_predict(row['title'], row['reviewerID']) for _, row in amazon_data.iterrows()]

# Calculating RMSE and MAE for Zero-Shot
rmse_zero_shot = mean_squared_error(amazon_data['rating'], amazon_data['predicted_rating_zero_shot'], squared=False)
mae_zero_shot = mean_absolute_error(amazon_data['rating'], amazon_data['predicted_rating_zero_shot'])

# Calculating RMSE and MAE for Few-Shot
rmse_few_shot = mean_squared_error(amazon_data['rating'], amazon_data['predicted_rating_few_shot'], squared=False)
mae_few_shot = mean_absolute_error(amazon_data['rating'], amazon_data['predicted_rating_few_shot'])

print(f"Zero-Shot RMSE: {rmse_zero_shot}, MAE: {mae_zero_shot}")
print(f"Few-Shot RMSE: {rmse_few_shot}, MAE: {mae_few_shot}")

amazon_data.head(3)
# Out:
# Zero-Shot RMSE: 0.6822555528345602, MAE: 0.33366073923025447
# Few-Shot RMSE: 0.08738080415620557, MAE: 0.007011706085116549
# CPU times: user 20.9 s, sys: 79.4 ms, total: 21 s
# Wall time: 21 s
#                                                title  rating  \
# 0  Jenna Jameson Heartbreaker Perfume for women 3...     1.0
# 1  Norelco 6885XL Deluxe Quadra Action Cord/Cordl...     5.0
# 2  Norelco 6885XL Deluxe Quadra Action Cord/Cordl...     5.0
#
#                                           reviewText      reviewerID  \
# 0  I use a lot of perfume, I go through a new bot...  A2RYSCZOPEXOCQ
# 1  First, a little background.  I've switched bet...  A141OPVE376YFI
# 2  First, a little background.  I've switched bet...  A141OPVE376YFI
#
#    predicted_rating_zero_shot  predicted_rating_few_shot
# 0                         1.0                        1.0
# 1                         5.0                        5.0
# 2                         5.0                        5.0

# %% [markdown]
# # Zero-shot (GPT-3.5-turbo)

# %%
data = amazon_data

# %%
# %%time
@retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(6))
def predict_rating(title, model=GPT_MODEL_NAME, temperature=TEMPERATURE):
    prompt = f"How will users rate this product title: '{title}'? (1 being lowest and 5 being highest) Attention! Just give me back the exact whole number as a result, and you don't need a lot of text."

    response = openai.ChatCompletion.create(
        model=model,
        temperature=temperature,
        messages=[
            {
                "role": "system",
                "content": "You are an Amazon Beauty products critic."
            },
            {
                "role": "user",
                "content": prompt
            }
        ]
    )

    rating_text = response.choices[0].message['content'].strip()
    try:
        # Extract the first numerical value from the response
        rating = float(re.search(r'\d+', rating_text).group())  # Only capture whole numbers
        if not (1 <= rating <= 5):
            raise ValueError("Rating out of bounds")
    except (ValueError, AttributeError):
        print(f"Unexpected response for '{product_title}': {rating_text}")
        rating = 0  # Set default value to 0 for unexpected responses

    return rating

# Parameters
PAUSE_EVERY_N = 20
SLEEP_TIME = 60 # Sleep for 60 seconds

# Iterate through the dataset and predict ratings
predicted_ratings = []
titles = data['title'].unique()
for idx, title in enumerate(titles):
    predicted_rating = predict_rating(title)
    print(f"Predicted rating for {title}: {predicted_rating}")
    predicted_ratings.append(predicted_rating)
    
    # Pause every PAUSE_EVERY_N rows
    if (idx + 1) % PAUSE_EVERY_N == 0:
        print(f"Pausing for {SLEEP_TIME} seconds...")
        time.sleep(SLEEP_TIME)

# Create a DataFrame with titles and predicted ratings
predicted_ratings_df = pd.DataFrame({
    'title': titles,
    'zero_shot_predicted_rating': predicted_ratings
})

# Merge the predicted ratings with the original data
merged_data_with_predictions = pd.merge(data, predicted_ratings_df, on='title')

# Save the merged data with predictions to a new CSV file
merged_data_with_predictions.to_csv('../../data/amazon-beauty/predictions_zero_shot.csv', index=False)
# Out:
# Predicted rating for Jenna Jameson Heartbreaker Perfume for women 3.4 oz Eau De Parfum Spray: 4.0
# Predicted rating for Norelco 6885XL Deluxe Quadra Action Cord/Cordless Rechargeable Men's Shaver: 4.0
# Predicted rating for Philips Norelco HQ5 Shaving Heads: 4.0
# Predicted rating for Braun Clean &amp; Renew Refill Cartridges CCR - 2 Count (Packaging May Vary): 4.0
# Predicted rating for Braun 3000 Series InterFace/Interface Excel Replacement Pack: 4.0
# Predicted rating for Philips Norelco HQ167 Cool Skin Replacement Heads for 6700 Series: 4.0
# Predicted rating for Scope Original Mint Mouthwash 50.7 Fl Oz: 4.0
# Predicted rating for Reach Dentotape Waxed Dental Floss with Extra Wide Cleaning Surface for Large Spaces between Teeth, Unflavored, 100 Yards: 4.0
# Predicted rating for Aqua Velva After Shave, Classic Ice Blue, 7 Ounce: 4.0
# Predicted rating for L'Oreal Studio Line Lasting Curls, Curl Enhancing , 6 oz (170 g): 4.0
# Predicted rating for Panasonic Bikini Shaper and Trimmer for Women ES246AC; Compact; Portable Design with Adjustable Trim Settings; Battery Operated: 4.0
# Predicted rating for Norelco 6756X Deluxe Advantage Wet/Dry Cordless Men's Razor: 4.0
# Predicted rating for Gillette Mach3 Turbo Cartridges with Aloe &amp; Vitamin E , 8 cartridges: 4.0
# Predicted rating for Crest Whitestrips Dental Whitening System, 56 Strips: 4.0
# Predicted rating for Norelco 7885XL Quadra Rechargeable Shaving System: 4.0
# Predicted rating for Norelco 5810XL Reflex Action Shaving System: 4.0
# Predicted rating for Norelco T-990 Acu-Control Beard and Mustache Trimmer with LCD, T990: 4.0
# Predicted rating for Norelco 8894 XL Spectra shaver Limited Edition, includes Automatic Charging stand with clock, 8894XL: 4.0
# Predicted rating for Norelco 7825XL Quadra Action Dry Razor: 4.0
# Predicted rating for Philips Norelco 7865XL Quadra Action Rechargeable Cord/Cordless Shaving System: 4.0
# Pausing for 60 seconds...
# Predicted rating for Kiss My Face Exfoliating Face Wash Start Up, 4 Fluid Ounce: 4.0
# Predicted rating for AXE Body Spray for Men, Kilo, 4 oz: 4.0
# Predicted rating for Citre Shine Moisture Burst Shampoo - 16 fl oz: 4.0
# Predicted rating for Philips Norelco HQ 55 Reflex Replacement Heads: 4.0
# Predicted rating for Philips Norelco 6613X Reflex Plus Rechargeable Cordless Men's Shaving System: 4.0
# Predicted rating for Philips Norelco 6423LC Reflex Plus Corded Men's Shaving System: 4.0
# Predicted rating for Philips Norelco HQ110 Shaving Head Cleaning Spray: 4.0
# Predicted rating for Norelco 8890XL / 8892XL Spectra Rechargeable Cord/Cordless Men's Shaving System ( 8890 XL / 8892 XL: 4.0
# Predicted rating for Norelco Mens Electric Razor - 7845XL: 4.0
# Predicted rating for DERMA E Soothing Oil-Free Moisturizer with Pycnogenol 2oz: 4.0
# Predicted rating for Oral-B EssentialFloss Cavity Defense Dental Floss, 50 M, Pack of 24: 4.0
# Predicted rating for Oral-B 54 Yards Floss Deep Clean Ultra (6 Pieces) Mint: 4.0
# Predicted rating for Biotone Herbal Select Massage Products Body Therapy Oil, 8 Ounce: 4.0
# Predicted rating for Helen of Troy 1514 Brush Iron, White, 1 1/2 Inches Barrel: 4.0
# Predicted rating for PLANTLIFE Patchouli Aromatherapy Soap Bar, 4 Ounce: 4.0
# Predicted rating for Super Nail Polish Thinner 4 Ounce (118ml): 4.0
# Predicted rating for Avalon Organics Vitamin C Renewal Moisture Plus Lotion SPF 15 -- 4 fl oz: 4.0
# Predicted rating for Dr. Singha's Mustard Bath, Therapeutic Bath Salts, 8 Ounce: 4.0
# Predicted rating for Juniper Sage Soap by MoonDance Soaps - Handmade Soap with Cocoa Butter and Shea Butter (One Bar): 4.0
# Predicted rating for Afirm 3x 0.60 % Retinol-1.05 oz: 4.0
# Pausing for 60 seconds...
# Predicted rating for Afirm 2x 0.30 % Retinol-1.05 oz: 4.0
# Predicted rating for Philips Norelco HQ177 Cool Skin Replacement Heads for 7700 Series Shavers: 4.0
# Predicted rating for Philips Norelco 7735X Cool Skin Lotion Dispensing Shaver: 4.0
# Predicted rating for Philips Norelco G270 Multi-Trim All Purpose Groomer: 4.0
# Predicted rating for Philips Norelco 7775X Cool Skin Lotion Dispensing Shaver: 4.0
# Predicted rating for Oral-B Hummingbird Flosser Starter Kit Unit, Assorted Colors (Pack of 3): 4.0
# Predicted rating for Oral-B Hummingbird Refill Picks, 25-Pack: 4.0
# Predicted rating for Gillette Venus Blade Refill, 8 Count: 4.0
# Predicted rating for Water-Rosewater Heritage Store 8 oz Liquid: 4.0
# Predicted rating for Crest Premium White Strips, 28 Count: 4.0
# Predicted rating for Permanent Color-8N/Natural Light Blonde Tints of Nature 4.4 oz Liquid: 4.0
# Predicted rating for Truefitt &amp; Hill Trafalgar After Shave Splash 100ml/3.38oz: 4.0
# Predicted rating for NARS Blush, Taj Mahal: 4.0
# Predicted rating for DERMA E Anti-Wrinkle Renewal Cream with Vitamin A Retinyl Palmitate 4oz: 4.0
# Predicted rating for NARS Powder Blush Cheek Color: 4.0
# Predicted rating for Gillette M3 Power Cartridges 8 Count: 4.0
# Predicted rating for J.R. Liggett Bar Shampoo, Tea Tree Oil Formula, 3.5 Ounce: 4.0
# Predicted rating for Revitalizing Therapy Serum Intensive Anttioxidant - Dry Skin Aubrey Organics .33oz (10ml) Liquid: 4.0
# Predicted rating for Tea Tree Therapy Tea Tree Antibacterial Liquid Soap 8 oz: 4.0
# Predicted rating for Avalon Organics Brilliant Balance with Lavender &amp; Prebiotics Ultimate Night Cream 2 oz: 4.0
# Pausing for 60 seconds...
# Predicted rating for Avalon Organics Wrinkle Therapy CoQ10 Cleansing Milk, 8.50 oz: 4.0
# Predicted rating for Braun 8000 Activator Combi-Pack Foil and Cutterblock Replacement Parts for Braun's Activator Razor Models 8595 and 8585: 4.0
# Predicted rating for Parissa Wax Strips Face &amp; Bikini, Hair Removal Waxing Kit for Women with Smaller Wax Strips for the Face &amp; Bikini, 16 Strips &amp; Aftercare oil: 4.0
# Predicted rating for Ardell Individual Lashes, Flare Short Brown: 4.0
# Predicted rating for Wilkinson Sword Double Edge Razor Blade Refills for Men - 5 Count: 4.0
# Predicted rating for eb5 Face Formula for Men (4 Ounces): 4.0
# Predicted rating for ZUM Zum Bar Anise Lavender, 3 Ounce: 4.0
# Predicted rating for Kama Sutra Honey Dust Powder, Raspberry Kiss, 6 Ounce: 4.0
# Predicted rating for LIP INK Organic Vegan 100% Smearproof Lash Color (Smoke): 4.0
# Predicted rating for Thymes Goldleaf Perfumed Body Wash 270ml/9.25oz: 4.0
# Predicted rating for Yankauer Suction Instrument With Tubing &amp; Vent: 4.0
# Predicted rating for Crest Whitestrips Pro Effects,10-Day Dental Whitening Formula System, 40 Strips (Packaging May Vary): 4.0
# Predicted rating for Philips Norelco 9170XLCC Smart Touch XL Shaver: 4.0
# Predicted rating for Norelco Clean Jet Solution 10oz Cool Breeze: 4.0
# Predicted rating for Africas Best Ultimate Herbal Oil 8 Ounce (235ml): 4.0
# Predicted rating for Yardley By Yardley Of London Unisexs Lay It On Thick Hand &amp; Foot Cream 5.3 Oz: 4.0
# Predicted rating for Gillette M3 Power Nitro Razor: 4.0
# Predicted rating for Aquafresh White Trays, 14 Trays: 4.0
# Predicted rating for Philips Norelco 9160XL SmartTouch-XL Men's Shaver: 4.0
# Predicted rating for Clubman Youth Air Creme, 16 fl. oz.: 4.0
# Pausing for 60 seconds...
# Predicted rating for Velform Arm Wrap Kit: 4.0
# Predicted rating for NOW Red Clay Powder Moroccan, 6-Ounce: 4.0
# Predicted rating for Afirm 2x .30% Retinol 1.05oz: 4.0
# Predicted rating for Celine Oriental Summer By Celine For Women. Eau De Toilette Spray 3.3 Ounces: 4.0
# Predicted rating for Zum Rub Lavender -- 2.5 oz: 4.0
# Predicted rating for Rainbow Light - MintAsure Fresh Breath Capsules, Powerful Support for Healthy Teeth and Gums and Lasting Minty Breath with Parsley Oil and Xylitol, Vegetarian Sugar-Free, Lactose-Free, 75 Capsules: 4.0
# Predicted rating for Philips Norelco BG2020 BodyGroom: 4.0
# Predicted rating for QUEEN HELENE Professional Cleansing Cream, Triple Whipped, 15 oz: 4.0
# Predicted rating for Queen Helene Cocoa Butter, Solid, 5.75 Ounce [Packaging May Vary]: 4.0
# Predicted rating for Murrays Pomade, 3 oz: 4.0
# Predicted rating for EO Essential Oil Products Liquid Hand Soap Rosemary and Mint -- 12 fl oz: 4.0
# Predicted rating for Philips Norelco G370 All-in-1 Grooming System: 4.0
# Predicted rating for Philips Norelco 7240XL Cord/Cordless Rechargeable Shaver: 4.0
# Predicted rating for Philips Norelco 7140 Cord/Cordless Rechargeable Shaver: 4.0
# Predicted rating for Philips Norelco T980 Turbo Vacuum Trimmer: 4.0
# Predicted rating for Philips Norelco 7110 Cordless Rechargeable Shaver: 4.0
# Predicted rating for Fruits &amp; Passion Blue Refreshing Shower Gel - 6.7 fl. oz.: 4.0
# Predicted rating for Aqua Velva After Shave, Classic Ice Blue, 3.5 Ounce: 4.0
# Predicted rating for Good Grips Rocker Knife with Serrated Blade: 4.0
# Predicted rating for Alpha Hydrox AHA Souffle Soothing Anti-Wrinkle 1.6 oz.: 4.0
# Pausing for 60 seconds...
# Predicted rating for DERMALOGIX PARTNERS Dermazinc Zinc Therapy Spray/Drops, 4 Ounce: 4.0
# Predicted rating for Palmer's Pressing Oil, 5.25 Ounce: 4.0
# Predicted rating for Queen Helene Cocoa Butter, Stick, 1 Ounce [Packaging May Vary]: 4.0
# Predicted rating for REACH Dentotape Waxed Tape, Unflavored 100 Yards: 4.0
# Predicted rating for Waterpik Ultra Water Flosser: 4.0
# Predicted rating for California Baby Diaper Area Wash - Calming - 6.5 fl oz: 4.0
# Predicted rating for Remington MS2-390 Microscreen Rechargeable/Corded Men's Shaver: 4.0
# Predicted rating for SK-II Facial Treatment Essence: 4.0
# Predicted rating for The Body Shop Bath Gloves, Natural: 4.0
# Predicted rating for Caswell-Massey - Newport Soap on a Rope: 4.0
# Predicted rating for Gotu Kola 450mg Now Foods 100 Caps: 4.0
# Predicted rating for Pre de Provence Artisanal French Soap Bar Enriched with Shea Butter, Quad-Milled For A Smooth &amp; Rich Lather (250 grams) - Milk: 4.0
# Predicted rating for Pre de Provence Artisanal French Soap Bar Enriched with Shea Butter, Quad-Milled For A Smooth &amp; Rich Lather (250 grams) - Green Tea: 4.0
# Predicted rating for Pre de Provence Artisanal French Soap Bar Enriched with Shea Butter, Quad-Milled For A Smooth &amp; Rich Lather (250 grams) - Rose Petal: 4.0
# Predicted rating for Pre de Provence Artisanal French Soap Bar Enriched with Shea Butter, Quad-Milled For A Smooth &amp; Rich Lather (250 grams) - Verbena: 4.0
# Predicted rating for Liquid Trust: 4.0
# Predicted rating for MAKE UP FOR EVER Mist &amp; Fix 4.22 oz: 4.0
# Predicted rating for Redken Smooth Down Detangling Cream, 8.5 Ounce: 4.0
# Predicted rating for Pure Instinct: 4.0
# Predicted rating for Fresh Eau de Parfum, Sugar Lemon, 3.4 oz: 4.0
# Pausing for 60 seconds...
# Predicted rating for Diva Darling Diva Wrap, One Size: 4.0
# Predicted rating for Women's Halston by Halston Bath Powder - 5.3 oz: 4.0
# Predicted rating for Gillette Venus ComfortGlide Freesia Women's Razor - 1 handle + 2 refills: 4.0
# Predicted rating for Gigi All Purpose Honee Microwave Kit, 16 Ounce: 4.0
# Predicted rating for Jean Nate Silkening Body Powder, 6 Ounce: 4.0
# Predicted rating for Alpha Hydrox Sheer Silk Moisturizer SPF 15, 1 Ounce: 4.0
# Predicted rating for Soft 'N Style Rubber Rod Set, 60 Piece: 4.0
# Predicted rating for Economy Wash Cloths 1/2 lb (Pack of 12): 4.0
# Predicted rating for Crest Pro-health Multi-Protection Rinse, Cool Wintergreen, 33.8 Fluid Ounce: 4.0
# Predicted rating for Mederma AG Advanced Dry Skin Therapy Body Cleanser 8 oz: 4.0
# Predicted rating for Ambi Skincare Even &amp; Clear Foaming Cleanser, 6 Ounce: 4.0
# Predicted rating for Crest Whitestrips, Daily Multicare, 84 strips: 4.0
# Predicted rating for Medicool Manicure Pedicure Station: 4.0
# Predicted rating for Love Potion&reg;: RED ~ 1/3 Fl. Oz. Concentrated Perfume Oil: 4.0
# Predicted rating for SilcSkin Decollette Pad, 1 pad (packaging may vary): 4.0
# Predicted rating for Philips Norelco arcitec 1060 Men's Shaving System: 4.0
# Predicted rating for Philips Norelco 1050CC arcitec Men's Shaving System: 4.0
# Predicted rating for Philips Norelco arcitec 1090 Men's Shaving System: 4.0
# Predicted rating for Philips Norelco arcitec 1050 Men's Shaver: 4.0
# Predicted rating for Banyan Botanicals Bhringaraj Oil - Certified Organic, 4 oz - Tranquility for the Body and Mind: 4.0
# Pausing for 60 seconds...
# Predicted rating for Panasonic Close Curves Wet/Dry Ladies Shaver: 4.0
# Predicted rating for Permanent Color-5R Rich Copper Brown Tints of Nature 4.4 oz Liquid: 4.0
# Predicted rating for Profoot Care Toe Beds, Women's 1 pr: 4.0
# Predicted rating for Ole Henriksen Ole Henriksen Black Currant Complexion Oil 1 fl 0z 30ml: 4.0
# Predicted rating for Philips Norelco 8020X Moisturizing Shaving System: 4.0
# Predicted rating for Norelco HS800 Lotion Refill: 4.0
# Predicted rating for Philips Norelco HS85 Shaving Unit: 4.0
# Predicted rating for Bonne Bell Smackers Bath and Body Starburst Collection: 4.0
# Predicted rating for Commonwealth Lavare Extra Large Pineapple Bath Soap 12 Oz. by CST: 4.0
# Predicted rating for Philips Sonicare UV Sanitizer: 4.0
# Predicted rating for Maggie's Functional Organics Raspberry Navy Forest 9-11: 4.0
# Predicted rating for essie nail polish, cuticle care, primers and finishers: 4.0
# Predicted rating for Sex In The City Kiss by Instyle Parfums Eau De Parfum Spray 3.4 oz: 4.0
# Predicted rating for Physicians Formula Baked Collection Matte Wet/Dry Eyeshadow, Baked Smores, 0.07 Ounce: 4.0
# Predicted rating for Suction connectuing tubing, 6 ft, 3/16&quot;, Each: 4.0
# Predicted rating for WiseWays Herbals Witch Hazel Salve 1 oz.: 4.0
# Predicted rating for Helen of Troy 1579 Tangle Free Hot Air Brush, White, 3/4 Inch Barrel: 4.0
# Predicted rating for Dr. Woods Pure Almond Liquid Castile Soap, 32 Ounce: 4.0
# Predicted rating for AMERICAN CREW by American Crew: CLASSIC BODY WASH 15.2 OZ: 4.0
# Predicted rating for [Trouble Solution] Acne Cleansing Foam for eliminating Sebum, balancing oil-water, Mild Body Cleansing(4.39 fl. oz. / 130 ml): 4.0
# Pausing for 60 seconds...
# Predicted rating for Albolene Moisturizing Cleanser Fragrance Free 12 oz (Pack of 2): 4.0
# Predicted rating for Kent The Handmade Comb - Fine and Coarse Toothed Pocket Comb Sawcut R7T, 130 mm: 4.0
# Predicted rating for Peter Thomas Roth Anti-Aging Buffing Beads, 8.5 Fluid Ounce: 4.0
# Predicted rating for BriteSmile Mouth Rinse 14 oz: 4.0
# Predicted rating for Urban Spa Moisturizing Booties to Keep your Feet Smooth, Hydrated and Moisturized: 4.0
# Predicted rating for PLANTLIFE Sandalwood Soap Bar, 4 Ounce: 4.0
# Predicted rating for AGELESS: UltraMAX Gold Capsules, 90 count: 4.0
# Predicted rating for Avalon Organics Vitamin C Renewal Creme, 2 oz: 4.0
# Predicted rating for PHARMADERM **** ACID MANTLE CREAM 1 OZ: 4.0
# Predicted rating for Maui Rain Hawaiian Perfume: 4.0
# Predicted rating for Whish Coconut Shaving Cream - Smooth, All Natural Shave Cream for Men &amp; Women, Leaves Skin so Soft, Shea Butter and Coconut Oil, Natural and Organic Skin Care - 5 oz. pump: 4.0
# Predicted rating for Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz: 4.0
# Predicted rating for Orajel Severe Toothache &amp; Gum Relief Cream, 0.33 Oz: 4.0
# Predicted rating for Williams Lectric Shave, 7 Ounce: 4.0
# Predicted rating for Pond's Dry Skin Cream , 6.5 Ounce: 4.0
# Predicted rating for Diane Salon Elements Fromm Shortie Vinyl Cape (Black): 4.0
# Predicted rating for CocoCare Cococare 100% Cocoa Butter Stick Pack of 1: 4.0
# Predicted rating for Summer's Eve Simply Sensitive Cleansing Wash for Sensitive Skin 9 oz: 4.0
# Predicted rating for FusionBeauty LiftFusion Face Lift: 4.0
# Predicted rating for Organic Fiji  Raw Organic Coconut Oil, 13-Ounce Jars: 4.0
# Pausing for 60 seconds...
# Predicted rating for Nag Champa Super Hit Cones, 144 Cones Box: 4.0
# Predicted rating for Zapzyt Maximum Strength 10% Benzoyl Peroxide Acne Treatment Gel, 1 Ounce: 4.0
# Predicted rating for QUEEN HELENE Cocoa Butter Creme 4.8 oz: 4.0
# Predicted rating for A Size Above Styling Cape with Snap Closure, Chocolate Brown: 4.0
# Predicted rating for Nullo Internal Deodorant (60 Caplets): 4.0
# Predicted rating for TRISWIM Chlorine Removal Swimmers Lotion Moisturizing Repairing Skin: 4.0
# Predicted rating for bareMinerals Essential Brow Kit - Dark Blond/Medium Brown: 4.0
# Predicted rating for ibd Builder Gel - Clear - 0.5oz / 14g: 4.0
# Predicted rating for St. Ives Olive Cleanser -- 6.75 oz.: 4.0
# Predicted rating for AXE Shower Tool, Detailer 1 ea, Pack of 4: 4.0
# Predicted rating for Oral-B Prohealth All-In-One Medium Toothbrush, Colors May Vary, 1 Count: 4.0
# Predicted rating for B&aacute;lla for Men Body Powder - Tingle Formula, 100g: 4.0
# Predicted rating for Sunshine Blue &trade; Caryopteris incana 'Jason' PPAF - Bluebeard - Proven Winners: 4.0
# Predicted rating for B&aacute;lla for Men Body Powder - Fragrance-Free Formula, 100g: 4.0
# Predicted rating for Graham Sanek Neck Strips- 2.5 x 17.5-12 pks w/60 Per Pack&quot;&quot;: 4.0
# Predicted rating for Kingsley Shave Soap Bowl with Lid Dark Wood: 4.0
# Predicted rating for No7 Day Cream SPF 15: 4.0
# Predicted rating for Terranova Gardenia Cologne with Box,2 Ounce: 4.0
# Predicted rating for Ole Henriksen Three Little Wonders Mini Box Set-3 ct: 4.0
# Predicted rating for Gillette Bodywash, Dry Skin Hydrator &amp; Body Wash, 12-Ounce Bottle (Pack of 6): 4.0
# Pausing for 60 seconds...
# Predicted rating for Dried Fruit &amp; Nut Medley 3lb 8oz Bag: 4.0
# Predicted rating for Philips Norelco 7310 Men's Shaving System: 4.0
# Predicted rating for Philips Norelco 7340 Men's Shaving System packaging may vary: 4.0
# Predicted rating for Philips Norelco 7810XL Men's Cutting System: 4.0
# Predicted rating for Alterna Hemp Organics Texturizing Glaze, 5.1-Ounce Tube: 4.0
# Predicted rating for Philips Norelco 8260 CC Men's Shaving System: 4.0
# Predicted rating for Philips Norelco Speed-XL 8240 Men's Shaving System: 4.0
# Predicted rating for Invisi Bond Waterproof Lace Wig Hair Adhesive Glue 4oz: 4.0
# Predicted rating for CELEBRITY Debra Manikin MK-D804: 4.0
# Predicted rating for Love Potion&reg;: Dominance Potion ~ UNscented Pheromone Blend for Women - 1/3 Fl.oz. (10ml): 4.0
# Predicted rating for Bell-Horn &quot;It Stays!&quot; Roll-On Body Adhesive, 2 fl oz: 4.0
# Predicted rating for Diane Practice Hand: 4.0
# Predicted rating for Gillette Foamy Shave Cream 11 Oz, Pack of 12: 4.0
# Predicted rating for Gillette Foamy Shaving Cream, Sensitive Skin, 11 Ounce (Pack of 12), Mens Razors/Blades: 4.0
# Predicted rating for Clubman Lustray Blue Spice After Shave, 128 Fluid Ounce: 4.0
# Predicted rating for Tea Tree Therapy Antibacterial Liquid Soap, with Tea Tree Oil, 8-Ounces  (Pack of 4): 4.0
# Predicted rating for  Neutrogena Oil-Free Deep Clean Cream Cleanser, 7 Ounce (Pack of 3) : 4.0
# Predicted rating for Clean &amp; Clear Deep Action Cream Facial Cleanser for Sensitive Skin, Gentle Daily Face Wash with Oil-Free, 6.5 oz (Pack of 4): 4.0
# Predicted rating for Indigo Wild Zum Bag Frankincense &amp; Myrrh: 4.0
# Predicted rating for DERMA E Anti-Wrinkle Advanced Antioxidant Moisturizer Cream with Vitamin A and Green tea 2oz: 4.0
# Pausing for 60 seconds...
# Predicted rating for  Colgate Fluoride Toothpaste Strawberry Smash Liquid Gel 4.60 oz (Pack of 6) : 4.0
# Predicted rating for  Mitchum Smart Solid Clinical Performance, Unscented, 2.5-Ounce (Pack of 4) : 4.0
# Predicted rating for APHOGEE Nutritional Supplement for Healthy Hair (30 Day-Supply): 4.0
# Predicted rating for  Gillette Clinical Advance Solid Sport Triumph 1.7 Ounce: 4.0
# Predicted rating for Gillette Customplus 3 Sensitive Men's Disposable Razor 4 Count (Pack of 3): 4.0
# Predicted rating for Oral-B Glide Pro-Health Dental Floss, Original Floss, 50m, Pack of 6: 4.0
# Predicted rating for Oral-B Glide Threader Floss (Pack of 4): 4.0
# Predicted rating for Olay Daily Exfoliating Body Wash with Sea Salts, 23.6 Ounce (Pack of 3): 4.0
# Predicted rating for Secret Smooth effects, Unscented, 2.6-Ounce Bottle (Pack of 4): 4.0
# Predicted rating for  Zest Aqua clean,fresh scent Bars, 12-Count Boxes (Pack of 2): 4.0
# Predicted rating for  JASON Purifying Tea Tree Nail Saver, 0.5 oz. (Pack of 4) (Packaging May Vary) : 4.0
# Predicted rating for Oral-B  Glide Floss, Mint , 54.6 yd (Pack of 4): 4.0
# Predicted rating for Divaderme Lash Extender II - 100% Natural Eyelash Fibers + Enhancer Treatment - Increases Your Lashes By 1000% - Made in USA (1 Pack): 4.0
# Predicted rating for  bareMinerals Essential Brow Kit - Dark Blond/Medium Brown : 4.0
# Predicted rating for Helen of Troy 1511 Brush Iron, White, 3/4 Inch Barrel: 4.0
# Predicted rating for Enessa Clove Acne Control 0.5 fl oz.: 4.0
# Predicted rating for  Walker Scalp Protector 1.4 oz Dab-on : 4.0
# Predicted rating for Gillette Razor Power, Fusion Gamer, 1-Count Package: 4.0
# Predicted rating for IMAN Lip Shimmer Velvet: 4.0
# Predicted rating for Goody 37 Pcs Satin Covered Rollers #45622: 4.0
# Pausing for 60 seconds...
# Predicted rating for Oral-B Indicator Contour Clean Soft Toothbrush 4 Count: 4.0
# Predicted rating for Pre de Provence Maison French Dried Lavender Blossoms for Fragrance: 4.0
# Predicted rating for  Supernail China Silk Wrap, 72 Inch : 4.0
# Predicted rating for COVERGIRL Smoothers Moisturizing Concealer, 1 Tube (0.14 oz), For Fair Skin Tones, Solid Stick Concealer, Fragrance Free, Moisturizing (packaging may vary): 4.0
# Predicted rating for Bare Escentuals Trudy Face Color 2.8 g NEW - SEALED: 4.0
# Predicted rating for Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce: 4.0
# Predicted rating for  Revlon ColorStay Liquid Foundation For Normal/dry Skin, Caramel, 1 Fl Oz : 4.0
# Predicted rating for Gengigel Hyaluronan Mouthrinse (150ml) [Misc.]: 4.0
# Predicted rating for Astra Platinum Double Edge Safety Razor Blades ,100 Blades (20 x 5): 4.0
# Predicted rating for  AquaTica Organic Botanical Night Cream with Caviar Extract, Reishi and CoQ10, 2oz : 4.0
# Predicted rating for LA CROSS Foot Smoothing Disk: 4.0
# Predicted rating for Loreal Skin Genesis Pore Minimizing 1 Oz: 4.0
# Predicted rating for Cleavage Control Clip (Set of 3): 4.0
# Predicted rating for Panasonic Pro-Curve Wet/Dry Travel Shaver: 4.0
# Predicted rating for  Hair Rules Curly Whip Styling, 8 oz: 4.0
# Predicted rating for Braun bodyCruzer Men's Body Groomer, Titanium: 4.0
# Predicted rating for eos Smooth Lip Balm Sphere, Honeysuckle Honeydew 0.25 oz: 4.0
# Predicted rating for  Beauticontrol Show of Hands Instant Manicure 10 Oz. : 4.0
# Predicted rating for Kids Natural Deodorant for Boys - Citrus Sport - by Junior Varsity Naturals: 4.0
# Predicted rating for Gillette Clear Shield Deodorant, Cool Wave, 2.6-Ounce Stick (Pack Of 6): 4.0
# Pausing for 60 seconds...
# Predicted rating for Philips Norelco Speed Electric Razor: 4.0
# Predicted rating for Foot Cleaning Brush: 4.0
# Predicted rating for Philips Norelco QC5055 Power Hair Clipper: 4.0
# Predicted rating for  Medicool&#39;s MED2191 Turbo File 2 Professional Electric Nail Filing System: 4.0
# Predicted rating for Philips Norelco HQ200 Jet Clean Solution, 10 Ounce: 4.0
# Predicted rating for Urban Spa Natural Bamboo and Jute Bath Mitt: 4.0
# Predicted rating for TIGI Bed Head B Men's Pure Texture Molding Paste, 2.93 Ounce: 4.0
# Predicted rating for Natureful Hyaluronic Acid Serum with Vitamin C 100 % Pure Beauty Anti Aging Skin Care Cream &amp; Moisturizer Treatment for Your Face Quality Topical Facial Solution with Vitamin C &amp; E, 1 oz: 4.0
# Predicted rating for Thermal Spa Heated Mitts with Display Box #49143: 4.0
# Predicted rating for Edens Garden Aphrodisiac 30 ml Value Pack Synergy Blend 100% Pure Undiluted Therapeutic Grade GC/MS Certified Essential Oil: 4.0
# Predicted rating for Kama Sutra Weekender Kit - Strawberry: 4.0
# Predicted rating for Kate Somerville&nbsp;ExfoliKate Intensive&nbsp;Exfoliating Treatment&nbsp;(5 Fl. Oz. Luxury Size): 4.0
# Predicted rating for Crest Classic 100% More Pack Whitestrips, 112-Count: 4.0
# Predicted rating for Primal Elements Bar Soap in Shrinkwrap, Penguins, 6 Ounce: 4.0
# Predicted rating for Fresh Brown Sugar Body Polish - 200g/7oz: 4.0
# Predicted rating for COVERGIRL Clean Matte Pressed Powder, 1 Container (0.35 oz), Classic Ivory Warm Tone, Oil Control Face Powder, Fragrance Free (packaging may vary): 4.0
# Predicted rating for Gillette Fusion Proglide Manual Men's Razor: 4.0
# Predicted rating for Gillette Venus Malibu With Aloe Disposable Women's Razor 3 Count (Pack of 2): 4.0
# Predicted rating for Stay On Satin Large Scarf: 4.0
# Predicted rating for Betty Dain Stretch Terry Cloth Turban, White: 4.0
# Pausing for 60 seconds...
# Predicted rating for Gillette Fusion Proglide Razor with Cartridge: 4.0
# Predicted rating for Gillette Fusion Aftershave Lotion - 3.3 Oz, Pack of 2: 4.0
# Predicted rating for Orajel Severe Toothache &amp; Gum Relief Plus, Cooling Gel, 0.25 Oz: 4.0
# Predicted rating for Hesh Multani Mati 100gms: 4.0
# Predicted rating for Listerine Total Care Whitening Mouthwash, 6 Benefit Fluoride Anticavity Mouthwash for Stain Removal and Bad Breath, Fresh Mint Flavor, 16 fl. oz: 4.0
# Predicted rating for Hesh Rose petal powder Herbal 100gms: 4.0
# Predicted rating for Crest Pro-Health Complete Clean Mint Flavor Fluoride Mouthwash 1 L (Pack of 6): 4.0
# Predicted rating for Brahmi Amla Hair Oil (8 oz) by Vadik Herbs | Ayurvedic herbal hair growth oil and hair conditioning oil | Great for hair loss, balding, thinning of hair, for beard growth, herbal scalp treatment: 4.0
# Predicted rating for Dri Sweat Fit Women's Style Protector Cap, Black, 1 Pound: 4.0
# Predicted rating for Booty Parlor Kissaholic Aphrodisiac Infused Plumping Lip Gloss - Swoon: 4.0
# Predicted rating for BACKSCRATCHERS Extreme Acrylic Dipping Powder Clear 1 oz.: 4.0
# Predicted rating for Goody Simple Styles Spin Pin Dark Hair: 4.0
# Predicted rating for Gillette Dry Skin Hydrator Body Wash 16 Fl Oz (Pack of 2): 4.0
# Predicted rating for Secret Antiperspirant and Deodorant for Women, Clinical Strength Soft Solid, Light and Fresh, 1.6 Oz: 4.0
# Predicted rating for Goody Simple Styles Spin Pin - Light Hair: 4.0
# Predicted rating for Fresh Balls The Solution For Men - 5 oz: 4.0
# Predicted rating for L'Or&eacute;al Paris Skincare HydraFresh Toner, Alcohol Free Toner with Pro-Vitamin B5 for Face, 8.5 fl. oz.: 4.0
# Predicted rating for BIC Comfort 3 Advance Men's Disposable Razor, 4-Count: 4.0
# Predicted rating for Shima Oil (8oz) Double The Size!: 4.0
# Predicted rating for essie Nail Color: 4.0
# Pausing for 60 seconds...
# Predicted rating for Bamboo Shine Silk-Sleek Brilliance Cream, 4.2-Ounce: 4.0
# Predicted rating for Zig Zag Orange Rolling Papers 1 1/4 - 2 Pack: 4.0
# Predicted rating for Paul Brown Hawaii Hapuna Hair Styling Paste, 8 Ounce: 4.0
# Predicted rating for The Doctor's Brushpicks Toothpicks 15 Pick Re- Fillable Keychain Dispenser (Pack of 6): 4.0
# Predicted rating for Axe Detailer 2-Sided Shower Tool, Colors May Vary 1 ea: 4.0
# Predicted rating for World Famous South Beach Natural Lightening Gel - Salon Strength for Anal Bleaching, Vaginal, Bikini, Breast, Melasma, Acne Scars - Non-irritating, No Harmful Chemicals like Hydroquinone or Kojic Acid: 4.0
# Predicted rating for Bumble and Bumble Texture Hair Un Dressing Creme 5 oz: 4.0
# Predicted rating for Secret Natural Mineral Invisible Solid Antiperspirant and Deodorant, Eucalyptus Blossom, 2.6 Ounce: 4.0
# Predicted rating for Bamboo Smooth Kendi Intense Moisture Masque, 4.7 Ounce: 4.0
# Predicted rating for Opalpix 32ct., 6 packs 192 total picks: 4.0
# Predicted rating for Titanium Dioxide Powder 1 Lb: 4.0
# Predicted rating for Garnier Fructis Color Sealer, Instant, Lightweight Leave-In, Color Shield, For Color-Treated Hair, 6 oz.: 4.0
# Predicted rating for Bvlgari Mon Jasmin Noir, Shower Gel, 3.4 Ounce: 4.0
# Predicted rating for 80 Acres Blood Orange Hand &amp; Body Lotion - 2.5 oz: 4.0
# Predicted rating for bareMinerals READY Blush - The Aphrodisiac: 4.0
# Predicted rating for Crest Pro-Health Clinical Deep Clean Mint Mouthwash 473 Ml: 4.0
# Predicted rating for Crest Pro-Health Clinical Deep Clean Mint Flavor Mouthwash 237 mL: 4.0
# Predicted rating for Scope Dualblast Mouthwash Fresh Mint Blast 750 Ml: 4.0
# Predicted rating for Wet n Wild MegaLast Lip Color C918D Cherry Bomb: 4.0
# Predicted rating for Revitalash By Revitalash Revitalash Advanced Eyelash Conditioner-- 3.5 Ml / .118 Oz: 4.0
# Predicted rating for EVO FLEX Sunnies Flexible Tanning Bed Goggles Eye Protection UV PINK Glasses: 4.0
# Predicted rating for Nail Art Accessories Real Dry Dried Flowers 12 Colors Bundle Set in Wheel - Ready to Use by Winstonia: 4.0
# Predicted rating for Sinful Colors Professional Nail Polish Enamel 56 Neon Melon: 4.0
# Predicted rating for Lansley Large-Fast Bust Enlargement Cream - 50 ml: 4.0
# Pausing for 60 seconds...
# Predicted rating for Philips Sonicare HX8111/30 Airfloss Rechargeable Electric Flosser: 4.0
# Predicted rating for Toe Separators, Soft Two Tone Toe Spacers, Great Toe Cushions, Apply Nail Polish During Pedicure and Other Uses, 12 Pack: 4.0
# Predicted rating for Bumble and Bumble Hairdresser's Invisible Oil, 3.4 Ounce: 4.0
# Predicted rating for Bee Yummy Skin Food (2oz.): 4.0
# Predicted rating for Crest 3d White High Performance Whitening Whitestrips 10 Count: 4.0
# Predicted rating for FOONEE Rhinestones Nail Art Gems Mixed Colours Shapes in Case (2mm,3000pcs): 4.0
# Predicted rating for Silent Snooz Snore Relief - Soothing Eucalyptus (30 Reuses): 4.0
# Predicted rating for Philosophy Old Fashioned Egg Nog Shower Gel, 16 Ounce: 4.0
# Predicted rating for 100 Disposable Panties Salon Spray Tan Undies Tanning Thong Underwear Spa Panty: 4.0
# Predicted rating for Colgate Enamel Health Mouthwash: 4.0
# Predicted rating for Donna Collection Black Weaving Thread &amp; Needle Set: 4.0
# Predicted rating for Andalou Naturals Brightening Get Started Kit, 5 Count: 4.0
# Predicted rating for Andalou Naturals Clementine + C Illuminating Toner, 6 Fl oz, Facial Toner Helps Hydrate &amp; Balance Skin pH, For Clear, Bright Skin: 4.0
# Predicted rating for Glide Pro-Health For Life Smooth Mint Floss 35 Meters: 4.0
# Predicted rating for Zest 8-Bar Bath Size Soap, Aqua, 4 Ounce: 4.0
# Predicted rating for The Body Shop Vineyard Peach Shower Gel 250ml A0, Peach, 8.4 Fluid Ounce: 4.0
# Predicted rating for All Natural Tooth Powder, 2 Oz Glass Jar: 4.0
# Predicted rating for Epic Cosplay Hestia Autumn Gold Curly Wig 22 Inches (08AG): 4.0
# Predicted rating for Crest 3D White Rinse 32 Fl Oz: 4.0
# Predicted rating for wet n wild Megalast Lip Color, In the Flesh, 0.11 Fluid Ounce: 4.0
# Pausing for 60 seconds...
# Predicted rating for Shea Moisture - Olive &amp; Marula Baby Head-to-Toe Wash &amp; Shampoo with Avocado &amp; Shea Butter - 13 oz.: 4.0
# Predicted rating for Bellini DermaPad Anti-Wrinkle Reusable Chest Pad (1 Pad): 4.0
# Predicted rating for Khadi Natural Ayurvedic Herbal 18 Herbs Hair Oil for Strong Smooth Hair (210 ml): 4.0
# Predicted rating for Gillette Fusion Proglide Silvertouch Manual Men's Razor With 2 Razor Bllade Refills, 1 Count: 4.0
# Predicted rating for NuKira Bergamot Essential Oil, 0.34 Ounce: 4.0
# Predicted rating for Qimisi 12 Color Glitter Hexagon Acrylic UV Gel False Tips Nail Art Salon Tool Set: 4.0
# Predicted rating for SenzAway Tooth Desensitizing Gel: 4.0
# Predicted rating for Sulwhasoo Essential Balancing Emulsion, 4.2 Fluid Ounce: 4.0
# Predicted rating for Mahabhringraj Ramakrishna Pharma Scalp Massaging Oil, 200 ml: 4.0
# Predicted rating for Toji Pure Density: Hair Nutrition. A Vegetarian Hair Vitamin Supplement w/ Organic Horsetail, Biotin, DHT Blocker Pack of 3 (90 Day Supply): 4.0
# Predicted rating for Chap Stick Classic Original in Camouflage Design, 24 Pack: 4.0
# Predicted rating for Beauty Town Weaving Set - 60 Yard - Blonde: 4.0
# Predicted rating for Age Defying Caffeine Eye Cream | 1 OZ | Puffy Eyes, Dark Circles, Fine Lines, Wrinkles | All Natural and Organic Ingredients: Contains Hyaluronic Acid | Cruelty Free | Made in USA!: 4.0
# Predicted rating for Mad Hippie Face Cream with Anti Wrinkle Peptide Complex 1.0 ounces: 4.0
# Predicted rating for Cotton Kufi Cap - Cream OSFM W14S17D: 4.0
# Predicted rating for Sleek Makeup - Blush By 3 Palette (363- Pumpkin): 4.0
# Predicted rating for Skinceuticals Neck, Chest and Hand Repair Treatment, 2.0 Fluid Ounce: 4.0
# Predicted rating for MILANI Color Statement Lipstick - Hot Pink Rage: 4.0
# Predicted rating for GREY SILVER HAIR EXTENSION SCRUNCHIE UPDO DOWN DO TOPPER 0N ELASTIC WHIRLY FUN C24: 4.0
# Predicted rating for 12 Classic Color Elegant Blush Set: 4.0
# Pausing for 60 seconds...
# Predicted rating for Style Edit Root Concealer 2 oz, Medium Brown: 4.0
# Predicted rating for Pure Instinct sex attractant cologne .5 fl.oz./15 ml: 4.0
# Predicted rating for Therapeutic Intensive Lip Repair Treatment Balm With Gentle Aromatherapy 3 pak - Herbal Infused, BPA And Paraben Free, non GMO, All Natural Earl Grey/Vanilla/Basil Rosemary 3 Pak, Ora's Amazing Herbal: 4.0
# Predicted rating for Fashion Hair Bun Beautiful Ponytail Extensions Hair Piece Charming Hair Wrap -Dark Brown: 4.0
# Predicted rating for BRIGHTEN &amp; RENEW Facial Cleansing Grains and Face Mask with Rice Powder, Australian Pink Caly, Organic Hisbiscus, Chamomile and Rose Geranium FACE CLEANSER: 4.0
# Predicted rating for CJESLNA Bombshell 3 Pieces Hair Chignon Donut Bun Maker (1 Large,1 Medium,1 Small) (Beige): 4.0
# Predicted rating for Braun Clean &amp; Renew Refill Cartridges CCR, 4 Count (Packaging May Vary): 4.0
# Predicted rating for ReNext White Pearl Nail Art Stone Different Size Wheel Rhinestones Beads: 4.0
# Predicted rating for RazoRock Alum Stick - 60 grams - After Shave Stick &ndash; Natural Healing and Toning: 4.0
# Predicted rating for Crest Pro-Health For Life CPC Antigingivitis/Antiplaque Smooth Mint Rinse 33.8 Fl Oz: 4.0
# Predicted rating for L'oreal Everstyle Strong Hold Styling Spray, 8.5 Fluid Ounce (Pack of 2): 4.0
# Predicted rating for Petitfee Gold and EGF Eye and Spotpatch, Eyepatch 60 Each and Spotpatch 30 Each: 4.0
# Pausing for 60 seconds...
# Predicted rating for Caswell-Massey - Verbena Bar Soap Set, 5.2 oz (Box of 3): 4.0
# Predicted rating for [Etude House] Lip Perfume: 4.0
# Predicted rating for 40 Piece Refill Tapes for Instant Face, Neck and Eye Lift Kit: 4.0
# Predicted rating for Toni&amp;Guy Glamour Volume Plumping Whip, 2.82 Fluid Ounce: 4.0
# Predicted rating for SIGNATURE CLUB A by Adrienne Platinum ElectroCharged Upper Eyelid Fix: 4.0
# Predicted rating for African Soft Black Soap Tub 1lb: 4.0
# Predicted rating for [Etude House] Rosy Tint Lips 7g #02 Sunny Flower: 4.0
# Predicted rating for Fekkai Full Blown Aerosol Foam Cond Us 6.6 Oz, 6.660-Fluid Ounce: 4.0
# Predicted rating for BMC Mix Design DIY 3D Silicone Nail Art Decortive Acrylic Cabochon Mold Kit - Set 4, 30pc Kit 1: 4.0
# Predicted rating for Avon Foot Work Action Pedi - Peel 22 Pads: 4.0
# Predicted rating for Mehron Makeup Skin Prep Pro (4 oz): 4.0
# Predicted rating for Beauty Aura 100% Pure Avocado Oil - 16 Fl Oz - For Healthy Hair, Skin &amp; Nails.: 4.0
# Predicted rating for Mirenesse Cosmetics Velvet Maxi Lift Foundation (23. Mocha) - AUTHENTIC: 4.0
# Predicted rating for Best Anti Aging Vitamin C Creams with Super Fine Natural Hydrolized Collagen Types 1 &amp; 3 - Moisturizers for Men and Women 35+: 4.0
# Predicted rating for All Season Glass Dappen Dish, 3pack: 4.0
# Predicted rating for Milliard NON-GMO Emulsifying Wax Pastilles NF &ndash;16 OZ. Resealable Freshness Storage Bag: 4.0
# Predicted rating for Fekkai Brilliant Glossing Starter Kit: 4.0
# Predicted rating for Acne Scar Reducing Cream, All Natural w/ Tomato,Cucumber &amp; Fenugreek, 2 oz, By Diva Stuff: 4.0
# Predicted rating for Shiseido beauty up cotton makeup cotton 108 pieces: 4.0
# Predicted rating for Philips Sonicare Sonic Electric Rechargeable Toothbrush for Kids, HX6311/07: 4.0
# Pausing for 60 seconds...
# Predicted rating for Sexy Red Lingerie Sequin Heart Tassel Breast Bra Nipple Sticker Cover Pasties (Red): 4.0
# Predicted rating for 1 Sheet 3D Beautiful Landscape Nail Art Tips Pack Decal Wrap Water Tattoo Noctilucent Transfer Stickers DIY Decoration Fashion Xmas Gift #4: 4.0
# Predicted rating for YESURPRISE 1pack 3D Beautiful Landscape Nail Art Tips Pack Decal Wrap Tattoo Transfer Stickers Decoration #11: 4.0
# Predicted rating for Home Health Evercln, Face Cream, 1.69 Fluid Ounce: 4.0
# Predicted rating for Womdee(TM) Fashion Women Silver Rhinestone Crystal Flower Hair Band / Elastic Headband-Silver With Womdee Accessory: 4.0
# Predicted rating for Cotton Clouds 200S White (100% Cotton Cosmetic Pads) (3 Pack): 4.0
# Predicted rating for E.l.f. Moisturizing Lipstick Party in The Buff, 0.11 Ounce: 4.0
# Predicted rating for e.l.f. Cosmetics Moisturizing Lipstick, Provides Vibrant Color and Luminous Shine, Flirty and Fabulous: 4.0
# Predicted rating for e.l.f. Cosmetics Moisturizing Lipstick, Provides Vibrant Color and Luminous Shine, Pink Minx: 4.0
# Predicted rating for E.l.f. Moisturizing Lipstick Ravishing Rose, 0.11 Ounce: 4.0
# Predicted rating for niceeshop(TM) Metallic Mirror Metal T-show Stage Style Women Circle Cuff Elastic Hair Band Ponytail Holder-Gold by niceeshop: 4.0
# Predicted rating for Change Korean Fashion Deer Pattern Women Long Cotton Scarf Shawls (Black): 4.0
# Predicted rating for Best Surgical Steel Nose Stud Lot - 40 Piece Set (Colorful): 4.0
# Predicted rating for Glycerin Vegetable Kosher USP-Highest Quality Available-1 Quart (32 Fluid Ounces)-From Element Six: 4.0
# Predicted rating for Universal Tablet Case Folio for 8.1 to 10.1 inch Devices | Fits TRIO Stealth G2 TRIOSTLG2 (10in), Apple iPad Air 2, Samsung Galaxy Tab S 10.5, Google Nexus 9 | Purple Orchid: 4.0
# Predicted rating for Simply Beautiful De Tangle Brush - Professional Detangling Hairbrush - Pink, Black, Purple, Blue or Green (Black): 4.0
# Predicted rating for Acne Scar Removal Treatment &amp; Dark Spot Corrector - With Rose Hip Oil and Salicylic Acid - Get rid of Pimples and Whiteheads with this Cream: 4.0
# Predicted rating for Nora Ross Garlic Shampoo Treatment Designed to Help Combat Hair Loss, dandruff, damaged hair. Helps regrow hair: 4.0
# Predicted rating for Mehron Makeup Liquid Latex (4.5 oz) (Light Flesh): 4.0
# Predicted rating for Hair Styling Anti Frizz Argan Kit - Normal to Thick Hair Care - Moroccan Leave In Conditioner Cream 10.1 oz and Hair Oil 3.4 oz Frizzy Hair Volume Control Moisturizing Set: 4.0
# Pausing for 60 seconds...
# Predicted rating for Fresh Guard Wipes Specially Formulated for Retainers Mouthguards and Removable Braces, 20 Count: 4.0
# Predicted rating for BMC Nail Stamping Lacquers - Creative Art Polish Collection, 6 Colors: Set 1: 4.0
# Predicted rating for BMC Nail Stamping Lacquers - Creative Art Polish Collection, 6 Colors: Set 2: 4.0
# Predicted rating for Alaffia - Beautiful Curls - Curl Reviving Tonic - 12 oz (FFP): 4.0
# Predicted rating for Physicians Formula Luxury Eye Cream for Normal to Dry Skin 0.5 oz, 14 g (2 pack): 4.0
# Predicted rating for Essential Makeup Brush Set - With Makeup Brush Holder - Leather Carrying Case 12 Professional Quality Brushes: 4.0
# Predicted rating for Optic Shop Pro Nose Guard-For Eyeglass Suspension: 4.0
# Predicted rating for Michel Design Works Bath Soap Bar, Peony, Large: 4.0
# Predicted rating for Natural Perfume - Lavender &amp; Sage Perfume Oil - Essential Oil Perfume - Sage Essential Oil - Lavender Perfume - Essential Oils - Women's Perfume - Organic Perfume Oil - Lavender Aromatherapy: 4.0
# Predicted rating for Im Natural Mamey Mascara (Value Pack of 8), Length and Volume for Super Long Lashes Guaranteed!: 4.0
# Predicted rating for Crystal butterfly Headband U86121-0120lavender: 4.0
# Predicted rating for Lice Shield Sh 2-1 Size 10z: 3.0
# ...
# Predicted rating for Beau Belle Pro Contour &amp; Highlight Palette - Contour Palette - Contouring Kit - Contouring Palette - Contouring and Highlighting Kit - Highlight and Contour - Highlighter Makeup - Contour Kit Powder: 4.0
# Predicted rating for Generic 1 Sheet Pink Sakura 3D Nail Art Stickers Full Nail Stickers Nail Decals: 4.0
# Predicted rating for Elite99 Soak Off UV LED Gel Nail Polish Manicure Lacquer Nail Art Decoration 7ml 1541 Greyish Brown: 4.0
# Predicted rating for Elite99 Soak Off UV LED Gel Nail Polish Manicure Lacquer Nail Art Decoration 7ml 1864 Glitter Peach Pink: 4.0
# Predicted rating for Elite99 Soak Off UV LED Gel Nail Polish Manicure Lacquer Nail Art Decoration 7ml 1361 Light Apricot Pink: 4.0
# Predicted rating for Elite99 Soak Off UV LED Gel Nail Polish Manicure Lacquer Nail Art Decoration 7ml 1862 Black White: 4.0
# Predicted rating for Elite99 Soak Off UV LED Gel Nail Polish Manicure Lacquer Nail Art Decoration 7ml 1435 Light Brown: 4.0
# Predicted rating for Born Pretty1 Sheet Colorful Feather Nail Art Water Decals Transfer Stickers: 4.0
# Predicted rating for Natural Being Skin Toner with Manuka Honey: 4.0
# Predicted rating for Natural Being Facial Cleanser for Oily Skin: 4.0
# Predicted rating for Natural Being Anti-Aging Oily Skin Night Cream: 4.0
# Pausing for 60 seconds...
# Predicted rating for (2pkg) TRL Thinning Spot Hair Growth Oil| Black Castor, Olive Oil Hair, Coconut Oil Hair Mix Regrowth Spot Treatment for Subtle Thinning Hair and Balding Areas| 5 Natural Hair Oils, 7 Organic Herbs: 4.0
# Predicted rating for Nudestix Skin Pencil - Matte and Blemish: 4.0
# Predicted rating for Peripera Ah Much Shy Blusher 0.7 Ounce 05 Haha Crisp Lavander: 4.0
# Predicted rating for eBoot 3D Nail Art Decorations Wheel with Mini Metal Studs, 2 Pack: 4.0
# Predicted rating for RoseFlower Pro 20 Colors Cream Concealer Makeup Palette Cosemetic Contouring Kit - Ideal for Professional and Daily Use: 4.0
# Predicted rating for InstaNatural Baby Shampoo &amp; Body Wash - With Aloe Vera, Vitamin E, Lavender Oil and Fruit Extracts - Soothing 2 in 1 Formula for Smooth Skin &amp; Soft Hair - 14 OZ: 4.0
# Predicted rating for Signature Club A by Adrienne Super Strength Secret C and Propolis Rapid Uplift (1 oz.): 4.0
# Predicted rating for Deko Neck Firming Cream with Vitamin C, Glycolic Acid &amp; Hyaluronic Acid for Tight, Youthful Face, Neck &amp; Chest 1.7 oz: 4.0
# Predicted rating for Valentines Day Nails Lips and Xoxo Stickers Decals (Red): 4.0
# Predicted rating for Urban_decay 24/7 Glide-on Eye Pencil in Shade Perversion Full Size (1 unit): 4.0
# Predicted rating for Nanacoco Nail Polish Love Black (6 Pieces) Black: 4.0
# Predicted rating for Mega Pro 2 Palette 32 Colors Authentic: 4.0
# Predicted rating for Kingfansion 2.8cm DIY Nail Art Stamping Stamper Scraper Image Plate Transfer Manicure Tool: 4.0
# Predicted rating for Born Pretty 1 Sheet Lotus Nail Art Water Decals Rose Flower Transfers Sticker Nail Water Slides: 4.0
# Predicted rating for Cleomee Donkey Snowy Pore Balm: 4.0
# Predicted rating for NOTS 28 Remedy Intensive Serum &ndash; Anti Acne Serum Treatment + Smoothing &amp; Soothing Serum + Reduce the Appearance of Scars, Wrinkles, and Dark Spots, 1.18oz: 4.0
# Pausing for 60 seconds...
# Predicted rating for Kingfansion Nail Art Stamping Stamper Scraper Image Plate Transfer Manicure Tool: 4.0
# Predicted rating for E.L.F. LIp Kiss Balm Pouty Raspberry 22176: 4.0
# Predicted rating for Holika Holika Face 2 Change Dodo Cat Cushion BB #21 Light Beige Refill (Compatible with DoDo Cat Relax, DoDo Cat Go Out Cushion): 4.0
# Predicted rating for Deko Triple Action Vitamin C Serum with Hyaluronic Acid &amp; Aloe for Wrinkles and anti aging, Sun &amp; Age Spots, Acne Scars, Dark Circles &amp; More: 4.0
# Predicted rating for Korean Natural Soda Bubble Volcanic Pore Mask - 80 ml: 4.0
# Predicted rating for Korean Natural 5 Seeds Apple Water Brightening Scrub - 80 ml: 4.0
# Predicted rating for New Nordic Skin Care Collagen Filler, 60 Count (120 count): 4.0
# Predicted rating for ZesGood Natural Purple Rose Oil Day and Night Stretch Eye Cream for Dark Circles and Crow's Feet, 30g(1.06 fl.oz): 4.0
# Predicted rating for Medicool Diamond Nail Drill Ball Bit 3/32 Inch: 4.0
# Predicted rating for Benefit Cosmetics Life's Little Correctors Color Correcting Kit ($60 Value!): 4.0
# Predicted rating for LKE 10Pcs Acrylic Nail Art Soak Off Cap Clip UV Gel Polish Remover Manicure Tool (Pink): 4.0
# Predicted rating for [MOGONG DODOOK] Legendary Empress AHA &amp; BHA Collagen Emulsion 200ml: 4.0
# Predicted rating for [MOGONG DODOOK] Legendary Empress AHA &amp; BHA Collagen Toner 200ml: 4.0
# Predicted rating for Korean Natural Long Eyelashes Brows Growth And Restore Tonic Essence #1 Rated Fix Broken Lashes And Treatment Essential Food To Grow And Recover Long Lashes Dermatologist Lab Tested 8 Months Supply - 5 ml / 10 ml: 4.0
# Predicted rating for 6 PCS KLEANCOLOR MASTER STROKES LONG WEAR SMOKY SHADOW STICK: 4.0
# Predicted rating for MagiDeal 3pcs Triangle Moon Star Shape Hairpin Side Clip Hair Styling Accessories Gold: 4.0
# Predicted rating for 1oz Amber Glass Dropper Bottles (12 pack), Refillable Glass Bottles for Essential Oils, Cosmetics, Cooking, and More! (12 Pack): 4.0
# Predicted rating for Body Tonique Repair &amp; Replenish Facial &amp; Body Oil: 4.0
# Predicted rating for 9pcs Girls Flower Heaband, Jmkcoz Head Wreath Bohemia Stylish Headbands Flower Crown Flower Garland Headbands Random Color: 4.0
# Predicted rating for Born Pretty 1 sheet Coconut Trees Water Decals Summer Style Transfer Sticker Anchors Nail Stickers YE-323: 4.0
# Pausing for 60 seconds...
# Predicted rating for Cash &amp; Bash | NUTSACK &amp; HOOF | 3-IN-ONE | Face Wash + Shaving Serum + Moisturizer | Vanilla + Rice Bran Oil | Premium Skin Care with Anti-inflammatory and Antibacterial Properties: 4.0
# Predicted rating for Nail-Aid Biotin Ultimate Strength Vitamin B7 Nail Polish (Pack of 2): 4.0
# Predicted rating for Star Tech Professional Grade Lady Beauty Tool Eyelash Curler (Pink): 4.0
# Predicted rating for 6 Color Peel Off Mask Tint Long Lasting Waterproof Lip Gloss + 12pc Lip Liner: 4.0
# Predicted rating for 24pc Lipstick Nabi Round Lipsticks: 4.0
# Pausing for 60 seconds...
# Predicted rating for Heritage Store Castor Oil Pack Kit (2 Pack): 4.0
# Predicted rating for tarte lippie lingerie matte tint- whisper (rosy beige): 4.0
# Predicted rating for Amalia Antioxidant Milk: 4.0
# Predicted rating for Eshion 12pcs High Quality Makeup Cosmetic Lipsticks Set of 12 Amazing Colors (Purple Tube): 4.0
# Predicted rating for [SNP] Aqua Energy Fermentation Mask (10EA): 4.0
# Predicted rating for Hair Straightener Brush, Instant Magic Silky Straight Hair Styling, Anti Scald Detangling Hair Brush, Anion Hair Care Ceramic Straightening Iron - (Pink): 4.0
# Predicted rating for Professional 1 Inch Ceramic Tourmaline Ionic Flat Iron 100~240V Dual Voltage Titanium Ion Infused Hair Straightener Auto Shut Off: 4.0
# Predicted rating for Reventin Deep Wrinkle 2 piece kit with Floral Carrying Case: 4.0
# Predicted rating for Zoella Beauty Double Cr&eacute;me Body Lotion 186g: 4.0
# CPU times: user 12.7 s, sys: 2.21 s, total: 14.9 s
# Wall time: 13h 14min 39s

# %%
# evaluate the rating prediction model

product_titles = merged_data_with_predictions['title']
actual_ratings = merged_data_with_predictions['rating']

# Remove None predictions if any
actual_ratings_filtered, predicted_ratings_filtered = zip(*[(actual, predicted) for actual, predicted in zip(actual_ratings, predicted_ratings) if predicted is not None])

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(actual_ratings_filtered, predicted_ratings_filtered))
print(f'Root Mean Squared Error (RMSE): {rmse}')

# Calculate MAE
mae = mean_absolute_error(actual_ratings_filtered, predicted_ratings_filtered)
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Root Mean Squared Error (RMSE): 1.1343651866449433
# Mean Absolute Error (MAE): 1.0117710005350455

# %%
# calculate RMSE and MAE manually using calculate_rmse_and_mae function
rmse, mae = calculate_rmse_and_mae(
    actual_ratings_filtered, predicted_ratings_filtered
)
print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
# Out:
# RMSE: 1.1343651866449433
# MAE: 1.0117710005350455

# %% [markdown]
# # Few-shot
#
#
# For each user, we'll use 4 of their ratings as training data to predict ratings for the rest of their products. Finally, we'll evaluate the predictions against the actual ratings to calculate the overall RMSE and MAE.

# %%
# %%time
@retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(6))
def predict_rating_few_shot(product_title, rating_history, model=GPT_MODEL_NAME, temperature=TEMPERATURE):
    """
    Predict the rating of a product based on user's past rating history using the GPT model.
    
    Parameters:
    - product_title (str): The title of the product for which rating needs to be predicted.
    - rating_history (str): A string representation of user's past product ratings.
    - model (str): The GPT model version to use.
    - temperature (float): Sampling temperature for the model response. 
    
    Returns:
    - float: Predicted rating for the product or None if the response is not valid.
    """
    # Construct the prompt to ask the model
    prompt = (f"Here is user rating history: {rating_history}; "
              f"Based on the above rating history, please predict user's rating for the product: '{product_title}', "
              "(1 being lowest and 5 being highest.). "
              "Attention! Just give me back the exact whole number as a result, and you don't need a lot of text.")
    
    # Make the API call
    response = openai.ChatCompletion.create(
        model=model,
        temperature=temperature,
        messages=[
            {"role": "system", "content": "You are a product critic."},
            {"role": "user", "content": prompt}
        ]
    )
    
    rating_text = response.choices[0].message['content'].strip()
    try:
        # Extract the first numerical value from the response
        rating = float(re.search(r'\d+?', rating_text).group())
        if not (0.5 <= rating <= 5.0):
            raise ValueError("Rating out of bounds")
    except (ValueError, AttributeError):
        print(f"Unexpected response for '{product_title}': {rating_text}")
        rating = 0  # Set default value to 0 for unexpected responses

    return rating

# Parameters for pausing
PAUSE_EVERY_N_USERS = 10
SLEEP_TIME = 60  # Sleep for 10 seconds
predicted_ratings = []
actual_ratings = []

# For each user in the dataset
users = data['reviewerID'].unique()
for idx, reviewerID in enumerate(users):
    user_data = data[data['reviewerID'] == reviewerID]
    for reviewerID in data['reviewerID'].unique():
    user_data = data[data['reviewerID'] == reviewerID]
    
    # Check if the user has at least 5 ratings
    if len(user_data) >= 5:
        train_data = user_data.sample(4, random_state=RANDOM_STATE)
        test_data = user_data.drop(train_data.index)

        # For each product in the testing set, use the training data to predict a rating
        for _, test_row in test_data.iterrows():
            rating_history_str = ', '.join([f"{row['title']} ({row['rating']} stars)" for _, row in train_data.iterrows()])
            predicted_rating = predict_rating_few_shot(test_row['title'], rating_history_str)
            
            predicted_ratings.append(predicted_rating)
            actual_ratings.append(test_row['rating'])
    
    # Introduce a pause after processing every PAUSE_EVERY_N_USERS
    if (idx + 1) % PAUSE_EVERY_N_USERS == 0:
        print(f"Processed {idx + 1} users. Pausing for {SLEEP_TIME} seconds...")
        time.sleep(SLEEP_TIME)

# Save the predicted ratings to a new CSV file
predicted_ratings_df = pd.DataFrame({
    'few_shot_predicted_rating': predicted_ratings,
    'actual_rating': actual_ratings
})
predicted_ratings_df.to_csv('../../data/amazon-beauty/large_predictions_few_shot.csv', index=False)

predicted_ratings_df.head(3)
# Out:
# Traceback (most recent call last):
#
#   File ~/opt/anaconda3/envs/test/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[10], line 1
#     get_ipython().run_cell_magic('time', '', '@retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(6))\ndef predict_rating_few_shot(product_title, rating_history, model=GPT_MODEL_NAME, temperature=TEMPERATURE):\n    """\n    Predict the rating of a product based on user\'s past rating history using the GPT model.\n    \n    Parameters:\n    - product_title (str): The title of the product for which rating needs to be predicted.\n    - rating_history (str): A string representation of user\'s past product ratings.\n    - model (str): The GPT model version to use.\n    - temperature (float): Sampling temperature for the model response. \n    \n    Returns:\n    - float: Predicted rating for the product or None if the response is not valid.\n    """\n    # Construct the prompt to ask the model\n    prompt = (f"Here is user rating history: {rating_history}; "\n              f"Based on the above rating history, please predict user\'s rating for the product: \'{product_title}\', "\n              "(1 being lowest and 5 being highest.). "\n              "Attention! Just give me back the exact whole number as a result, and you don\'t need a lot of text.")\n    \n    # Make the API call\n    response = openai.ChatCompletion.create(\n        model=model,\n        temperature=temperature,\n        messages=[\n            {"role": "system", "content": "You are a product critic."},\n            {"role": "user", "content": prompt}\n        ]\n    )\n    \n    rating_text = response.choices[0].message[\'content\'].strip()\n    try:\n        # Extract the first numerical value from the response\n        rating = float(re.search(r\'\\d+?\', rating_text).group())\n        if not (0.5 <= rating <= 5.0):\n            raise ValueError("Rating out of bounds")\n    except (ValueError, AttributeError):\n        print(f"Unexpected response for \'{product_title}\': {rating_text}")\n        rating = 0  # Set default value to 0 for unexpected responses\n\n    return rating\n\n# Parameters for pausing\nPAUSE_EVERY_N_USERS = 10\nSLEEP_TIME = 60  # Sleep for 10 seconds\npredicted_ratings = []\nactual_ratings = []\n\n# For each user in the dataset\nusers = data[\'reviewerID\'].unique()\nfor idx, reviewerID in enumerate(users):\n    user_data = data[data[\'reviewerID\'] == reviewerID]\n    for reviewerID in data[\'reviewerID\'].unique():\n    user_data = data[data[\'reviewerID\'] == reviewerID]\n    \n    # Check if the user has at least 5 ratings\n    if len(user_data) >= 5:\n        train_data = user_data.sample(4, random_state=RANDOM_STATE)\n        test_data = user_data.drop(train_data.index)\n\n        # For each product in the testing set, use the training data to predict a rating\n        for _, test_row in test_data.iterrows():\n            rating_history_str = \', \'.join([f"{row[\'title\']} ({row[\'rating\']} stars)" for _, row in train_data.iterrows()])\n            predicted_rating = predict_rating_few_shot(test_row[\'title\'], rating_history_str)\n            \n            predicted_ratings.append(predicted_rating)\n            actual_ratings.append(test_row[\'rating\'])\n    \n    # Introduce a pause after processing every PAUSE_EVERY_N_USERS\n    if (idx + 1) % PAUSE_EVERY_N_USERS == 0:\n        print(f"Processed {idx + 1} users. Pausing for {SLEEP_TIME} seconds...")\n        time.sleep(SLEEP_TIME)\n\n# Save the predicted ratings to a new CSV file\npredicted_ratings_df = pd.DataFrame({\n    \'few_shot_predicted_rating\': predicted_ratings,\n    \'actual_rating\': actual_ratings\n})\npredicted_ratings_df.to_csv(\'../../data/amazon-beauty/large_predictions_few_shot.csv\', index=False)\n\npredicted_ratings_df.head(3)\n')
#
#   File ~/opt/anaconda3/envs/test/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2478 in run_cell_magic
#     result = fn(*args, **kwargs)
#
#   File ~/opt/anaconda3/envs/test/lib/python3.11/site-packages/IPython/core/magics/execution.py:1281 in time
#     expr_ast = self.shell.compile.ast_parse(expr)
#
#   File ~/opt/anaconda3/envs/test/lib/python3.11/site-packages/IPython/core/compilerop.py:86 in ast_parse
#     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
#   File <unknown>:54
#     user_data = data[data['reviewerID'] == reviewerID]
#     ^
# IndentationError: expected an indented block after 'for' statement on line 53

# %%
predicted_ratings
# Out:
# [1.0, 1.0, 2.0, 2.0, 2.0, 5.0, 1.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, 4.0]

# %%
filtered_list = [(actual, predicted) for actual, predicted in zip(actual_ratings, predicted_ratings) if predicted is not None]

if not filtered_list:
    print("No valid predictions available for evaluation.")
else:
    actual_ratings_filtered, predicted_ratings_filtered = zip(*filtered_list)
    # Evaluate the model's performance
    rmse = np.sqrt(mean_squared_error(actual_ratings_filtered, predicted_ratings_filtered))
    print(f'Root Mean Squared Error (RMSE): {rmse}')

    mae = mean_absolute_error(actual_ratings_filtered, predicted_ratings_filtered)
    print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Root Mean Squared Error (RMSE): 1.9086270308410553
# Mean Absolute Error (MAE): 1.0714285714285714

# %%
# demonstrate the output of 4 random historical ratings
predicted_ratings = []
for title in data['title'].unique():
    # Randomly sample 4 rows from the entire dataset
    rating_history_samples = data.sample(4)
    rating_history_str = ', '.join([f"{row['title']} ({row['rating']} stars)" for _, row in rating_history_samples.iterrows()])

rating_history_str
# Out:
# 'Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz (5.0 stars), Citre Shine Moisture Burst Shampoo - 16 fl oz (2.0 stars), Oud Wood Oil. IMPRESSION of Tom Ford Oud Wood* Cologne for Men with SIMILAR Fragrance Accords, 10ml Amber Glass Roller, Black Cap; 100% Pure (Perfume Studio Oud Wood VERSION/TYPE; Not Original Brand) (2.0 stars), Astra Platinum Double Edge Safety Razor Blades ,100 Blades (20 x 5) (5.0 stars)'

# %% [markdown]
# # References
#
# + https://platform.openai.com/docs/api-reference/authentication
