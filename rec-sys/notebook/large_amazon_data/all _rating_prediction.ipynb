# %%
import numpy as np
import openai
import pandas as pd
import os
import sys
import time

# Add the path to the constants file to the system path
sys.path.append('../../')
from constants import *
from evaluation_utils import *
from path_utils import *
from ChatCompletion_OpenAI_API import *

# OpenAI API Key
openai.api_key = OPENAI_API_KEY
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# source code folder path
rec_sys_dir = get_rec_sys_directory()
print(f"Rec-sys directory: {rec_sys_dir}")

# data folder path
DATA_DIR = os.path.join(rec_sys_dir, 'data')
print(f"Data directory: {DATA_DIR}")

# data path
data_path = os.path.join(DATA_DIR, 'amazon-beauty/large_merged_data.csv')
print(f'Data path: {data_path}')

# zero shot save path
ZERO_SHOT_SAVE_PATH = os.path.join(DATA_DIR, 'amazon-beauty/all_large_predictions_zero_shot.csv')
print(f'Zero shot save path: {ZERO_SHOT_SAVE_PATH}')

# few shot save path
FEW_SHOT_1_OBS_SAVE_PATH = os.path.join(DATA_DIR, 'amazon-beauty/all_large_1_test_predictions_few_shot.csv')
print(f'Few shot save path: {FEW_SHOT_1_OBS_SAVE_PATH}')
# Out:
# Rec-sys directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys
# Data directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data
# Data path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/large_merged_data.csv
# Zero shot save path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/all_large_predictions_zero_shot.csv
# Few shot save path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/all_large_1_test_predictions_few_shot.csv

# %% [markdown]
# # Data Overview

# %%
# Read the data
data = pd.read_csv(data_path)

# get statistic and first few data of NUM_SAMPLES rows
data.info()
data.head(NUM_EXAMPLES)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9767 entries, 0 to 9766
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rating          9767 non-null   float64
#  1   verified        9767 non-null   bool
#  2   reviewTime      9767 non-null   object
#  3   reviewerID      9767 non-null   object
#  4   asin            9767 non-null   object
#  5   reviewerName    9767 non-null   object
#  6   reviewText      9759 non-null   object
#  7   summary         9759 non-null   object
#  8   unixReviewTime  9767 non-null   object
#  9   vote            1487 non-null   object
#  10  style           6768 non-null   object
#  11  category        9767 non-null   object
#  12  tech1           2 non-null      object
#  13  description     9767 non-null   object
#  14  fit             0 non-null      float64
#  15  title           9767 non-null   object
#  16  also_buy        9767 non-null   object
#  17  tech2           0 non-null      float64
#  18  brand           8749 non-null   object
#  19  feature         9767 non-null   object
#  20  rank            9703 non-null   float64
#  21  also_view       9767 non-null   object
#  22  details         9767 non-null   object
#  23  main_cat        9767 non-null   object
#  24  similar_item    62 non-null     object
#  25  date            2 non-null      object
#  26  price           3291 non-null   float64
# dtypes: bool(1), float64(5), object(21)
# memory usage: 1.9+ MB
#    rating  verified  reviewTime      reviewerID        asin  \
# 0     1.0     False  2015-08-25  A2RYSCZOPEXOCQ  9790787006
# 1     5.0     False  2001-06-08  A141OPVE376YFI  B000050B65
# 2     5.0     False  2001-06-08  A141OPVE376YFI  B000050B65
# 3     5.0      True  2008-07-25  A1TVTDKNMSQ7XU  B000050B6B
# 4     5.0      True  2008-07-25  A1TVTDKNMSQ7XU  B000050B6B
#
#         reviewerName                                         reviewText  \
# 0  The Cat Next Door  I use a lot of perfume, I go through a new bot...
# 1            Paul G.  First, a little background.  I've switched bet...
# 2            Paul G.  First, a little background.  I've switched bet...
# 3      Grandpa Pipes  I've had many Norelco razors in my 50 years of...
# 4      Grandpa Pipes  I've had many Norelco razors in my 50 years of...
#
#                                       summary unixReviewTime vote  ... tech2  \
# 0  This is not going to be my favorite scent.     2015-08-25  NaN  ...   NaN
# 1   Finally, a razor that lives up to the ads     2001-06-08   81  ...   NaN
# 2   Finally, a razor that lives up to the ads     2001-06-08   81  ...   NaN
# 3                          Just like new.....     2008-07-25  NaN  ...   NaN
# 4                          Just like new.....     2008-07-25  NaN  ...   NaN
#
#              brand feature   rank  \
# 0    Jenna Jameson      []  298.0
# 1          Norelco      []    2.0
# 2          Norelco      []    2.0
# 3  Philips Norelco      []  148.0
# 4  Philips Norelco      []  148.0
#
#                                            also_view  \
# 0         ['B00357FTX8', 'B01NBID7FJ', 'B0017JT658']
# 1  ['B01B1O9DOM', 'B00JITDVD2', 'B01KXV16DK', 'B0...
# 2  ['B01B1O9DOM', 'B00JITDVD2', 'B01KXV16DK', 'B0...
# 3  ['B001IA0PCY', 'B00196W5S4', 'B004URZADG', 'B0...
# 4  ['B001IA0PCY', 'B00196W5S4', 'B004URZADG', 'B0...
#
#                                              details    main_cat  \
# 0  {'Shipping Weight:': '12.8 ounces (', 'ASIN: '...  All Beauty
# 1                                                 {}  All Beauty
# 2                                                 {}  All Beauty
# 3  {'\n    Product Dimensions: \n    ': '5.1 x 0....  All Beauty
# 4  {'\n    Product Dimensions: \n    ': '5.1 x 0....  All Beauty
#
#    similar_item date  price
# 0           NaN  NaN  13.85
# 1           NaN  NaN    NaN
# 2           NaN  NaN    NaN
# 3           NaN  NaN  64.50
# 4           NaN  NaN  64.50
#
# [5 rows x 27 columns]

# %% [markdown]
# # Zero-shot (OpenAI API)

# %%
# %%time

predict_ratings_zero_shot_and_save(data,
                                       columns_for_prediction=ITEM_SIDE,
                                       pause_every_n_users=PAUSE_EVERY_N_USERS,
                                       sleep_time=SLEEP_TIME,
                                       save_path=ZERO_SHOT_SAVE_PATH)

# %%
# Evaluate Zero-shot Model
evaluate_model_predictions_rmse_mae(
    data_path=ZERO_SHOT_SAVE_PATH,
    num_examples=NUM_EXAMPLES,
    actual_ratings_column='rating',
    predicted_ratings_column='zero_shot_predicted_rating'
)

# %% [markdown]
# # Few-shot (OpenAI API)
#
#
# + For each user, we'll use 4 of their ratings as training data to predict ratings for an observation. Finally, we'll evaluate the predictions against the actual ratings to calculate the overall RMSE and MAE.

# %%
# %%time

predict_ratings_few_shot_and_save(data,
                                      columns_for_training=ITEM_SIDE + USER_SIDE + INTERACTION_SIDE,
                                       columns_for_prediction=ITEM_SIDE,
                                       obs_per_user=1,
                                       pause_every_n_users=PAUSE_EVERY_N_USERS,
                                       sleep_time=SLEEP_TIME,
                                       save_path=FEW_SHOT_1_OBS_SAVE_PATH)
# Out:
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this asin: B00AL4XD7M. title: Caboodles Heart Throb Long Tapered Tote, Black Diamond, 1.12 Pound. feature: []. description: ["This bag is definitely more than meets the eye. With so many interior pockets, it will hold all your must haves and more! In-fact, you'll have to go buy some more make-up to fill it up. Now that's a bag guaranteed to make your heart throb."]. price: 24.99. brand: Caboodles. category: []. tech1: nan. tech2: nan. also_buy: []. also_view: ['B00ZGK95FU', 'B00N57HV70', 'B001DKZFCY', 'B07BW9SL71', 'B07CQL67LV', 'B07BVH2P7R', 'B01FSF0786', 'B00367LZBM', 'B00WZX5B6I', 'B00EPU8ZVW', 'B009XHN0NU', 'B001EPAEFG', 'B07L5Y52N7', 'B07HPY2P17', 'B01FIRVGHK', 'B007GLDYW2', 'B079FQXJ3R', 'B07KLMJTB3', 'B00H346QVS', 'B07HQ189NJ', 'B07HPXY33M', 'B07F6FJT5T', 'B07KKMVK7T', 'B07DN4X7Z3', 'B07CJDNQCJ', 'B00OJSQITG', 'B01M013B86', 'B07BHBKZ24', 'B07C19GPHJ', 'B01NBY44E6', 'B07M8R7DX3', 'B077NYT4ZZ', 'B01KHFSBZ8', 'B07H381JQV', 'B01N55XY3M', 'B07L9FQBHZ', 'B00MAVO4FE', 'B07C25MWL3', 'B01FFGLUCK', 'B01LMNO270', 'B07HPY22ST', 'B07HPYCSKD', 'B079LC94VJ', 'B07DL8H2DL', 'B01J8OMLQY', 'B00I0GU8RG', 'B01BTQFAOO', 'B00DA4E0U4']. details: {'\n    Product Dimensions: \n    ': '11 x 7 x 7 inches ; 1.13 pounds', 'Shipping Weight:': '1.6 pounds (', 'Domestic Shipping: ': 'Currently, item can be shipped only within the U.S. and to APO/FPO addresses. For APO/FPO shipments, please check with the manufacturer regarding warranty and support issues.', 'International Shipping: ': 'This item can be shipped to select countries outside of the U.S.', 'ASIN: ': 'B017Y1147A', 'UPC:': '024099774826', 'Item model number:': '583238'}. main_cat: All Beauty. similar_item: nan. date: nan. rank: 100.0, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * asin: B0002564EE | title: Kordon Oasis (Novalek) Bell Bottle 8oz | feature: [] | description: ['UPC 0&#045;48054&#045;80408&#045;3 Item &#035; 80408 M&#045;08 AC Bell Bottle 8 oz&#046; Color Tinted Suitable for up to three rats, hamsters, gerbils, hedgehogs, sugar gliders and similar &quot;pocket&#045;pet&quot; type animals&#046; The 8 ounce Bell Bottle will serve several mice&#046;'] | price: 10.49 | brand: Kordon/Novalek/Oasis | category: [] | tech1: nan | tech2: nan | also_buy: ['B01H0YBT08', 'B016WM9IHK'] | also_view: [] | details: {'\n    Product Dimensions: \n    ': '3 x 2 x 10.5 inches ; 2.24 ounces', 'Shipping Weight:': '2.4 ounces (', 'ASIN: ': 'B0002564EE', 'UPC:': '048054804083'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 729.0 | reviewerID: A2RYSCZOPEXOCQ | reviewerName: The Cat Next Door | verified: True | reviewText: I have ordered two of those 8 oz bottles, one by one. I was so happy about the perfect water flow on the first bottle that I ordered an additional one of the same brand. Both of them came in red, which I am satisfied with, however I wish there was a color choice prior to ordering, I would choose teal. I also bought a smaller, 4 oz one from Supper Pet, which constantly clog, after the first lick (do not buy it). I then ordered a 4 oz one&nbsp;Kordon/Oasis (Novalek) SOA80404 Plastic No Chew Small Animal Bell Bottle, 4-Ounce, which is just as great as the 8 oz bottles. It came in my favorite teal color.
#
# These bottles are flowers patterned, full in one color with a metal pipe. They are the most pretty water bottles I have seen and also high quality ones. I totally recommend them. | rating: 5.0 | summary: The best water bottle for my Rats | unixReviewTime: 2014-05-08 | reviewTime: 2014-05-08 | vote: nan | style: nan - Rating: 5.0 stars
# * asin: 9790787006 | title: Jenna Jameson Heartbreaker Perfume for women 3.4 oz Eau De Parfum Spray | feature: [] | description: ['Jenna Jameson Heartbreaker Perfume for women 3.4 oz Eau De Parfum Spray Heartbreaker is young and sexy, with an attitude! The top note, is a fresh splash of sparkling raspberry Champaign garnished with lovely rose petals. After a taste of champagne, the middle note or the heart of the fragrance, takes us into the night of blooming jasmine and magnolia owers, to keep the mood casual but seductive. The base note, surprises us with the infusion of sophisticated sandalwood and tonka bean wrapped in an intoxicating morning of amber.', '', ''] | price: 13.85 | brand: Jenna Jameson | category: [] | tech1: nan | tech2: nan | also_buy: ['B004D8JQ4G', 'B0020MMD0G', 'B00ENL4HJW', 'B011YR4E4A', 'B001B0X05U', '0060539100', 'B008X9T0B0', 'B004IFOXFQ', 'B00AIZU9IU', 'B0017JT658', 'B0074OLDLK', 'B00BLEP5PE'] | also_view: ['B00357FTX8', 'B01NBID7FJ', 'B0017JT658'] | details: {'Shipping Weight:': '12.8 ounces (', 'ASIN: ': '9790787006', 'Item model number:': 'a03410', 'Discontinued by manufacturer:': 'Yes'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 298.0 | reviewerID: A2RYSCZOPEXOCQ | reviewerName: The Cat Next Door | verified: False | reviewText: I use a lot of perfume, I go through a new bottle every couple of weeks, and I never bought the same scent twice. I`m still looking for my favorite scent. This is not going to be it. I`m going to use it, but definitely not purchase again. Someone else may like it, it just does not lure my scents. Bottle is a very pretty, red glass, and it smells classier, than the name suggests.
#
# I got this for evaluation, 50% off, in order that I might provide this review.
#
# * I originally gave this 3 stars, but as I tried to use this further, I found the smell being just completely wrong. I asked three friends separately, what they think of it, and each one said, that this smells manly. And that was the exact word I was looking for. First two girls did not want to take this from me for free, the third one took it, but stated that really just a little at a time can be used. I downgraded this to 1 star, as it was in fact unusable and I wasted money on it. All four of us are in our early to late twenties and none of us liked this perfume. This is the only one 1 star review I ever wrote. | rating: 1.0 | summary: This is not going to be my favorite scent. | unixReviewTime: 2015-08-25 | reviewTime: 2015-08-25 | vote: nan | style: {'Size:': ' 1.7 Ounce'} - Rating: 1.0 stars
# * asin: B0002564EE | title: Kordon Oasis (Novalek) Bell
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "(4 stars, 80%)"
# Processing user 1/1608, item 2/5
# User A2RYSCZOPEXOCQ:
# Rating History for Prediction:
# * asin: B0002564EE | title: Kordon Oasis (Novalek) Bell Bottle 8oz | feature: [] | description: ['UPC 0&#045;48054&#045;80408&#045;3 Item &#035; 80408 M&#045;08 AC Bell Bottle 8 oz&#046; Color Tinted Suitable for up to three rats, hamsters, gerbils, hedgehogs, sugar gliders and similar &quot;pocket&#045;pet&quot; type animals&#046; The 8 ounce Bell Bottle will serve several mice&#046;'] | price: 10.49 | brand: Kordon/Novalek/Oasis | category: [] | tech1: nan | tech2: nan | also_buy: ['B01H0YBT08', 'B016WM9IHK'] | also_view: [] | details: {'\n    Product Dimensions: \n    ': '3 x 2 x 10.5 inches ; 2.24 ounces', 'Shipping Weight:': '2.4 ounces (', 'ASIN: ': 'B0002564EE', 'UPC:': '048054804083'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 729.0 | reviewerID: A2RYSCZOPEXOCQ | reviewerName: The Cat Next Door | verified: True | reviewText: I have ordered two of those 8 oz bottles, one by one. I was so happy about the perfect water flow on the first bottle that I ordered an additional one of the same brand. Both of them came in red, which I am satisfied with, however I wish there was a color choice prior to ordering, I would choose teal. I also bought a smaller, 4 oz one from Supper Pet, which constantly clog, after the first lick (do not buy it). I then ordered a 4 oz one&nbsp;Kordon/Oasis (Novalek) SOA80404 Plastic No Chew Small Animal Bell Bottle, 4-Ounce, which is just as great as the 8 oz bottles. It came in my favorite teal color.
#
# These bottles are flowers patterned, full in one color with a metal pipe. They are the most pretty water bottles I have seen and also high quality ones. I totally recommend them. | rating: 5.0 | summary: The best water bottle for my Rats | unixReviewTime: 2014-05-08 | reviewTime: 2014-05-08 | vote: nan | style: nan - Rating: 5.0 stars
# * asin: 9790787006 | title: Jenna Jameson Heartbreaker Perfume for women 3.4 oz Eau De Parfum Spray | feature: [] | description: ['Jenna Jameson Heartbreaker Perfume for women 3.4 oz Eau De Parfum Spray Heartbreaker is young and sexy, with an attitude! The top note, is a fresh splash of sparkling raspberry Champaign garnished with lovely rose petals. After a taste of champagne, the middle note or the heart of the fragrance, takes us into the night of blooming jasmine and magnolia owers, to keep the mood casual but seductive. The base note, surprises us with the infusion of sophisticated sandalwood and tonka bean wrapped in an intoxicating morning of amber.', '', ''] | price: 13.85 | brand: Jenna Jameson | category: [] | tech1: nan | tech2: nan | also_buy: ['B004D8JQ4G', 'B0020MMD0G', 'B00ENL4HJW', 'B011YR4E4A', 'B001B0X05U', '0060539100', 'B008X9T0B0', 'B004IFOXFQ', 'B00AIZU9IU', 'B0017JT658', 'B0074OLDLK', 'B00BLEP5PE'] | also_view: ['B00357FTX8', 'B01NBID7FJ', 'B0017JT658'] | details: {'Shipping Weight:': '12.8 ounces (', 'ASIN: ': '9790787006', 'Item model number:': 'a03410', 'Discontinued by manufacturer:': 'Yes'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 298.0 | reviewerID: A2RYSCZOPEXOCQ | reviewerName: The Cat Next Door | verified: False | reviewText: I use a lot of perfume, I go through a new bottle every couple of weeks, and I never bought the same scent twice. I`m still looking for my favorite scent. This is not going to be it. I`m going to use it, but definitely not purchase again. Someone else may like it, it just does not lure my scents. Bottle is a very pretty, red glass, and it smells classier, than the name suggests.
#
# I got this for evaluation, 50% off, in order that I might provide this review.
#
# * I originally gave this 3 stars, but as I tried to use this further, I found the smell being just completely wrong. I asked three friends separately, what they think of it, and each one said, that this smells manly. And that was the exact word I was looking for. First two girls did not want to take this from me for free, the third one took it, but stated that really just a little at a time can be used. I downgraded this to 1 star, as it was in fact unusable and I wasted money on it. All four of us are in our early to late twenties and none of us liked this perfume. This is the only one 1 star review I ever wrote. | rating: 1.0 | summary: This is not going to be my favorite scent. | unixReviewTime: 2015-08-25 | reviewTime: 2015-08-25 | vote: nan | style: {'Size:': ' 1.7 Ounce'} - Rating: 1.0 stars
# * asin: B0002564EE | title: Kordon Oasis (Novalek) Bell Bottle 8oz | feature: [] | description: ['UPC 0&#045;48054&#045;80408&#045;3 Item &#035; 80408 M&#045;08 AC Bell Bottle 8 oz&#046; Color Tinted Suitable for up to three rats, hamsters, gerbils, hedgehogs, sugar gliders and similar &quot;pocket&#045;pet&quot; type animals&#046; The 8 ounce Bell Bottle will serve several mice&#046;'] | price: 10.49 | brand: Kordon/Novalek/Oasis | category: [] | tech1: nan | tech2: nan | also_buy: ['B01H0YBT08', 'B016WM9IHK'] | also_view: [] | details: {'\n    Product Dimensions: \n    ': '3 x 2 x 10.5 inches ; 2.24 ounces', 'Shipping Weight:': '2.4 ounces (', 'ASIN: ': 'B0002564EE', 'UPC:': '048054804083'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 729.0 | reviewerID: A2RYSCZOPEXOCQ | reviewerName: The Cat Next Door | verified: True | reviewText: I have ordered two of those 8 oz bottles, one by one. I was so happy about the perfect water flow on the first bottle that I ordered an additional one of the same brand. Both of them came in red, which I am satisfied with, however I wish there was a color choice prior to ordering, I would choose teal. I also bought a smaller, 4 oz one from Supper Pet, which constantly clog, after the first lick (do not buy it). I then ordered a 4 oz one&nbsp;Kordon/Oasis (Novalek) SOA80404 Plastic No Chew Small Animal Bell Bottle, 4-Ounce, which is just as great as the 8 oz bottles. It came in my favorite teal color.
#
# These bottles are flowers patterned, full in one color with a metal pipe. They are the most pretty water bottles I have seen and also high quality ones. I totally recommend them. | rating: 5.0 | summary: The best water bottle for my Rats | unixReviewTime: 2014-05-08 | reviewTime: 2014-05-08 | vote: nan | style: nan - Rating: 5.0 stars
# * asin: B00NT0AR7E | title: OZNaturals Anti Aging Retinol Serum -The Most Effective Anti Wrinkle Serum Contains Professional Strength Retinol+ Astaxanthin+ Vitamin E - Get The Dramatic Youthful Results You&rsquo;ve Been Looking For | feature: [] | description: [] | price: 17.95 | brand: OZ Naturals | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: ['B06VSV4B7V', 'B06WGLJ4L9', 'B06X15QG43', 'B01N32LSUY', 'B06X8WKP95', 'B06WV7F27J', 'B06WGLJ55R', 'B06WCZLK3C', 'B06WGLHV6P', 'B06VSM8331', 'B078JXJSC9', 'B01NA0JIN4', 'B00TACV1FM', 'B00005K9CK', 'B07DD5VQGP', 'B07CQXWFKS', 'B072MRC7CL', 'B00Q301WXK', 'B00G2TQNZ4', 'B01LWSN8IS', 'B01EXNIGOQ', 'B01FB8DWB4', 'B00KB9Q8GU', 'B07HLTCZ1G', 'B075SPGZ7K', 'B01AF4L9A0', 'B0716FR6PL', 'B00QL67MY4', 'B01B5G45R6', 'B01KMSTCWG', 'B00OBWSBGS', 'B07GBDSLVN', 'B01M66VNNM', 'B00RSMM362', 'B00YT7D3S6', 'B01412ZUD4', 'B06W73PQJ5', 'B01BMN0TCM', 'B07FFDDKP5', 'B01BT02Q88', 'B01HXV90BS', 'B07C2CH5QL', 'B07D46FG9X', 'B07H8JL7MV', 'B07K26NGQB', 'B06XYFH2YR', 'B07G9VRFMZ', 'B078P41MZN', 'B07FQMNR42', 'B072N3ZLQW', 'B078NWRWQS', 'B013O70Z1Y', 'B01ES349CY', 'B07D45FSNT'] | details: {'\n    Product Dimensions: \n    ': '1.2 x 1.2 x 4 inches ; 0.96 ounces', 'Shipping Weight:': '4.8 ounces (', 'ASIN: ': 'B01NB1ZBA1', 'UPC:': '816457020108'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 9.0 | reviewerID: A2RYSCZOPEXOCQ | reviewerName: The Cat Next Door | verified: False | reviewText: I ordered this serum, because I had been recommended retinol for aging skin. I before had a Vitamin C serum from OZ Naturals, and I had good experience with this brand. You suppose to apply in this order:
# 1) Toner
# 2) Serum
# 3) Moisturizer
#
# This Retinol Serum comes in a 1 oz, brown, glass bottle with a pump. It is orange gel in consistence. I do see improvement in how my skin looks and feels, after using this serum.
#
# I received this for free. | rating: 4.0 | summary: Retinol Serum. | unixReviewTime: 2015-09-22 | reviewTime: 2015-09-22 | vote: nan | style: {'Size:': ' Original'} - Rating: 4.0 stars
# Predicted Item: Caboodles Heart Throb Long Tapered Tote, Black Diamond, 1.12 Pound (Code: B00AL4XD7M)
# Predicted Rating: 4.0 stars
#
# ----------------
#
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this asin: B000050FDY. title: Braun Clean &amp; Renew Refill Cartridges CCR - 2 Count (Packaging May Vary). feature: []. description: ['With Braun Clean & Renew refills, you can keep your shaver in like-new condition every day. Offered in multiple pack sizes, the Clean & Renew refills are used in Brauns patented Clean & Renew system base for when you are looking to clean, charge and lubricate your Braun shaver.']. price: 11.94. brand: Braun. category: []. tech1: nan. tech2: nan. also_buy: []. also_view: ['B000KND8IS', 'B07L9PW8R3', 'B071KCNQTR', 'B0786ZZQK6', 'B00454ZTEO', 'B01N2UCRSU', 'B00CX0N1LK', 'B01M29018Y', 'B017KXIZ92', 'B07L8WWYKY', 'B076FDW4FM', 'B008LQZP6E', 'B00J0NQZJ8', 'B001S2J5DW', 'B07J1D5Y1B', 'B00JHLIRIK', 'B00J73JOOO', 'B002EZZ5O0', 'B000PJA9XE', 'B07JVC4KC9', 'B018CKP7M0', 'B01N4UW0Y9', 'B07C7HHNNR', 'B00P4QQUV8', 'B009ROYJZM', 'B072HDRCXW', 'B07JPF8QPX', 'B01MYF2808', 'B009YCW878', 'B01MZG6QEM', 'B07F7NZ6ZC', 'B01N9YFOWA', 'B07KS94STJ', 'B07KS94SSN', 'B00QZX8RRO', 'B00UPYSXX2', 'B012DITQYM', 'B07H9R2J8H', 'B008LQZP7I', 'B07HFBKZNR', 'B00UCTDPS8', 'B000GBMYC0', 'B001B14N14', 'B07J6PJFVS', 'B00PRNKR3K', 'B0722GZMSZ', 'B0782Z6LKG', 'B01N5D9MVD', 'B00QXAZSDA', 'B00TXR3S1E', 'B071H76RH5', 'B01NB018BP', 'B077PV49W1', 'B00DU6ZV28', 'B004UQ6OG4', 'B01MCVM3RW']. details: {}. main_cat: All Beauty. similar_item: nan. date: nan. rank: 1.0, and
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * asin: B0002MQ9GK | title: Braun 8000 Activator Combi-Pack Foil and Cutterblock Replacement Parts for Braun's Activator Razor Models 8595 and 8585 | feature: [] | description: ['To bring back 100% shaving performance, replace your foil and cutterblock every 18 months. Change both parts at the same time for a closer shave with less skin irritation.'] | price: 34.99 | brand: Braun | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: ['B008LQZP7I', 'B000GBMYC0', 'B015RYPE6S', 'B076FDW4FM', 'B0041F9CKO', 'B00YTXCDYK', 'B07KS12JDB', 'B07KS94STJ', 'B019XFRT56', 'B000HI68VU', 'B01GR2YHEO', 'B07LFPB9JQ', 'B07L9PW8R3', 'B01GD7VUF2', 'B00N7P7URQ', 'B008LQZP6O', 'B008LQZP6E', 'B00EMWXBLW', 'B0017OM0QA', 'B000050FDX', 'B07H4MTJV8', 'B00009K3TO', 'B000KND8IS', 'B00N7S2RLW', 'B07L8WWYKY', 'B01M29018Y', 'B07JPF8QPX', 'B07KS94SSN', 'B00MXTSLAC', 'B00UCTF4TG', 'B07H5F5C39', 'B00CX0N1LK', 'B07GFZ3CQ3', 'B0786ZZQK6', 'B071KCNQTR', 'B002EZZ5O0', 'B07MDDFH5V', 'B008LQZP5K', 'B07J1D5Y1B', 'B00C92BLJG', 'B00HWMS222', 'B001VEK1LW', 'B012DITQYM', 'B06XBHYDVK', 'B001DNE3KQ', 'B07F7NZ6ZC', 'B077PV49W1', 'B00Y5A8W3I', 'B078YMZPH4', 'B00MW0L01O', 'B07L1P4JHS', 'B001DKMY9Q', 'B077XFPT4K', 'B077F5GR8C'] | details: {'\n    Item Weight: \n    ': '0.16 ounces', 'Shipping Weight:': '8 ounces (', 'Domestic Shipping: ': 'Item can be shipped within U.S.', 'International Shipping: ': 'This item is not eligible for international shipping.', 'ASIN: ': 'B0002MQ9GK', 'UPC:': '421020133781 787734001038 069055830796', 'Item model number:': 'Activator Combi Pack 8000FC', 'Discontinued by manufacturer:': 'Yes'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 98.0 | reviewerID: A141OPVE376YFI | reviewerName: Paul G. | verified: True | reviewText: I've had a Braun 8585 for years...got this to replace the cutter and foil.  I found the shave quality decreased and the blades started pulling whiskers.  Also I was nicked more often.
#
# I finally replaced the cutter and foil on my 8585 with this:&nbsp;Braun Series 3 Combi 30B Foil and Cutter Replacement Pack (Formerly 4700,7000).  It fits perfectly and gives me an excellent shave.  No more pulling, no nicks, and a closer shave.  Definitely the way to renew an 8000-series razor.
#
# Avoid this foil and cutterblock! | rating: 1.0 | summary: Don't get this! | unixReviewTime: 2010-11-29 | reviewTime: 2010-11-29 | vote: nan | style: nan - Rating: 1.0 stars
# * asin: B0002MQ9GK | title: Braun 8000 Activator Combi-Pack Foil and Cutterblock Replacement Parts for Braun's Activator Razor Models 8595 and 8585 | feature: [] | description: ['To bring back 100% shaving performance, replace your foil and cutterblock every 18 months. Change both parts at the same time for a closer shave with less skin irritation.'] | price: 34.99 | brand: Braun | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: ['B008LQZP7I', 'B000GBMYC0', 'B015RYPE6S', 'B076FDW4FM', 'B0041F9CKO', 'B00YTXCDYK', 'B07KS12JDB', 'B07KS94STJ', 'B019XFRT56', 'B000HI68VU', 'B01GR2YHEO', 'B07LFPB9JQ', 'B07L9PW8R3', 'B01GD7VUF2', 'B00N7P7URQ', 'B008LQZP6O', 'B008LQZP6E', 'B00EMWXBLW', 'B0017OM0QA', 'B000050FDX', 'B07H4MTJV8', 'B00009K3TO', 'B000KND8IS', 'B00N7S2RLW', 'B07L8WWYKY', 'B01M29018Y', 'B07JPF8QPX', 'B07KS94SSN', 'B00MXTSLAC', 'B00UCTF
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "(3 stars, 60%)"
# Processing user 2/1608, item 1/7
# User A141OPVE376YFI:
# Rating History for Prediction:
# * asin: B0002MQ9GK | title: Braun 8000 Activator Combi-Pack Foil and Cutterblock Replacement Parts for Braun's Activator Razor Models 8595 and 8585 | feature: [] | description: ['To bring back 100% shaving performance, replace your foil and cutterblock every 18 months. Change both parts at the same time for a closer shave with less skin irritation.'] | price: 34.99 | brand: Braun | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: ['B008LQZP7I', 'B000GBMYC0', 'B015RYPE6S', 'B076FDW4FM', 'B0041F9CKO', 'B00YTXCDYK', 'B07KS12JDB', 'B07KS94STJ', 'B019XFRT56', 'B000HI68VU', 'B01GR2YHEO', 'B07LFPB9JQ', 'B07L9PW8R3', 'B01GD7VUF2', 'B00N7P7URQ', 'B008LQZP6O', 'B008LQZP6E', 'B00EMWXBLW', 'B0017OM0QA', 'B000050FDX', 'B07H4MTJV8', 'B00009K3TO', 'B000KND8IS', 'B00N7S2RLW', 'B07L8WWYKY', 'B01M29018Y', 'B07JPF8QPX', 'B07KS94SSN', 'B00MXTSLAC', 'B00UCTF4TG', 'B07H5F5C39', 'B00CX0N1LK', 'B07GFZ3CQ3', 'B0786ZZQK6', 'B071KCNQTR', 'B002EZZ5O0', 'B07MDDFH5V', 'B008LQZP5K', 'B07J1D5Y1B', 'B00C92BLJG', 'B00HWMS222', 'B001VEK1LW', 'B012DITQYM', 'B06XBHYDVK', 'B001DNE3KQ', 'B07F7NZ6ZC', 'B077PV49W1', 'B00Y5A8W3I', 'B078YMZPH4', 'B00MW0L01O', 'B07L1P4JHS', 'B001DKMY9Q', 'B077XFPT4K', 'B077F5GR8C'] | details: {'\n    Item Weight: \n    ': '0.16 ounces', 'Shipping Weight:': '8 ounces (', 'Domestic Shipping: ': 'Item can be shipped within U.S.', 'International Shipping: ': 'This item is not eligible for international shipping.', 'ASIN: ': 'B0002MQ9GK', 'UPC:': '421020133781 787734001038 069055830796', 'Item model number:': 'Activator Combi Pack 8000FC', 'Discontinued by manufacturer:': 'Yes'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 98.0 | reviewerID: A141OPVE376YFI | reviewerName: Paul G. | verified: True | reviewText: I've had a Braun 8585 for years...got this to replace the cutter and foil.  I found the shave quality decreased and the blades started pulling whiskers.  Also I was nicked more often.
#
# I finally replaced the cutter and foil on my 8585 with this:&nbsp;Braun Series 3 Combi 30B Foil and Cutter Replacement Pack (Formerly 4700,7000).  It fits perfectly and gives me an excellent shave.  No more pulling, no nicks, and a closer shave.  Definitely the way to renew an 8000-series razor.
#
# Avoid this foil and cutterblock! | rating: 1.0 | summary: Don't get this! | unixReviewTime: 2010-11-29 | reviewTime: 2010-11-29 | vote: nan | style: nan - Rating: 1.0 stars
# * asin: B0002MQ9GK | title: Braun 8000 Activator Combi-Pack Foil and Cutterblock Replacement Parts for Braun's Activator Razor Models 8595 and 8585 | feature: [] | description: ['To bring back 100% shaving performance, replace your foil and cutterblock every 18 months. Change both parts at the same time for a closer shave with less skin irritation.'] | price: 34.99 | brand: Braun | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: ['B008LQZP7I', 'B000GBMYC0', 'B015RYPE6S', 'B076FDW4FM', 'B0041F9CKO', 'B00YTXCDYK', 'B07KS12JDB', 'B07KS94STJ', 'B019XFRT56', 'B000HI68VU', 'B01GR2YHEO', 'B07LFPB9JQ', 'B07L9PW8R3', 'B01GD7VUF2', 'B00N7P7URQ', 'B008LQZP6O', 'B008LQZP6E', 'B00EMWXBLW', 'B0017OM0QA', 'B000050FDX', 'B07H4MTJV8', 'B00009K3TO', 'B000KND8IS', 'B00N7S2RLW', 'B07L8WWYKY', 'B01M29018Y', 'B07JPF8QPX', 'B07KS94SSN', 'B00MXTSLAC', 'B00UCTF4TG', 'B07H5F5C39', 'B00CX0N1LK', 'B07GFZ3CQ3', 'B0786ZZQK6', 'B071KCNQTR', 'B002EZZ5O0', 'B07MDDFH5V', 'B008LQZP5K', 'B07J1D5Y1B', 'B00C92BLJG', 'B00HWMS222', 'B001VEK1LW', 'B012DITQYM', 'B06XBHYDVK', 'B001DNE3KQ', 'B07F7NZ6ZC', 'B077PV49W1', 'B00Y5A8W3I', 'B078YMZPH4', 'B00MW0L01O', 'B07L1P4JHS', 'B001DKMY9Q', 'B077XFPT4K', 'B077F5GR8C'] | details: {'\n    Item Weight: \n    ': '0.16 ounces', 'Shipping Weight:': '8 ounces (', 'Domestic Shipping: ': 'Item can be shipped within U.S.', 'International Shipping: ': 'This item is not eligible for international shipping.', 'ASIN: ': 'B0002MQ9GK', 'UPC:': '421020133781 787734001038 069055830796', 'Item model number:': 'Activator Combi Pack 8000FC', 'Discontinued by manufacturer:': 'Yes'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 98.0 | reviewerID: A141OPVE376YFI | reviewerName: Paul G. | verified: True | reviewText: I've had a Braun 8585 for years...got this to replace the cutter and foil.  I found the shave quality decreased and the blades started pulling whiskers.  Also I was nicked more often.
#
# I finally replaced the cutter and foil on my 8585 with this:&nbsp;Braun Series 3 Combi 30B Foil and Cutter Replacement Pack (Formerly 4700,7000).  It fits perfectly and gives me an excellent shave.  No more pulling, no nicks, and a closer shave.  Definitely the way to renew an 8000-series razor.
#
# Avoid this foil and cutterblock! | rating: 1.0 | summary: Don't get this! | unixReviewTime: 2010-11-29 | reviewTime: 2010-11-29 | vote: nan | style: nan - Rating: 1.0 stars
# * asin: B000EG8HLE | title: Philips Norelco BG2020 BodyGroom | feature: [] | description: ['Norelco Bodygroom is the all-in-one grooming solution, exclusively for men, that safely trims and shaves all body zones. For below the neck use only.', 'The Philips Norelco BG2020 Bodygroom Shaver is the All-in-One grooming solution, exclusively for men that safely trims and shaves all body zones. With the Bodygroom, men can trim and shave hair from their chest & abs, underarms, groin area, legs, back and shoulders. Bodygroom features the very latest technology and ergonomic design to offer a convenient, easy and pain-free way to remove and trim body hair. Bodygroom&#146;s advanced design allows for it to be used wet or dry and even in the shower. Its hypoallergenic foil protects even the most sensitive skin against nicks, cuts or irritation, and its stainless-steel blades ensure long-lasting performance. The Bodygroom comes with many extras including a cleaning brush and convenient charging stand.<BR><BR> We all know that men&#146;s body hair is different, it can be coarse and grow in multiple directions, and that is why Bodygroom is truly a revolution in grooming. Men finally have a product designed specifically to meet their unique grooming needs.<BR><BR> <P> <TABLE cellPadding=5 width=150 align=left> <TBODY> <TR> <TD><IMG src="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/BG2020_watt_100x100.jpg" align=top border=0 img><BR></TD></TR></TBODY></TABLE><BR><BR><BR><B>Trim & Shave: </B>Bodygroom&#146;s dual function shave-and-trim system allows you total control over how much hair you want to remove. Bodygroom comes with three length attachment combs to trim and tidy hair with out completely removing it. To remove hair completely use the Bodygroom without any attachments for a close, smooth shave.<BR><BR><BR> <P> <TABLE cellPadding=5 width=150 align=left> <TBODY> <TR> <TD><IMG src="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/BG2020_wetDry_100x100.jpg" align=top border=0 img><BR></TD></TR></TBODY></TABLE><BR><BR><BR><B>Use Wet & Dry: </B>Because Bodygroom is water-resistant it is fast and easy to clean and ideal for use in the shower. It even comes with its own hanging cord so you can keep it close by while bathing. Since Bodygroom can also be used dry, you&#146;ll be able to shave and trim anytime and anywhere you like.<BR><BR><BR> <P> <TABLE cellPadding=5 width=150 align=left> <TBODY> <TR> <TD><IMG src="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/less_irritation_100x100.jpg" align=top border=0 img><BR></TD></TR></TBODY></TABLE><BR><BR><BR><B>Safe with Less Irritation: </B>&#150;Bodygroom&#146;s hypoallergenic shaving foil means a comfortable shave with less irritation, even on the most sensitive skin and in the most sensitive body zones. Bodygroom allows you to groom your body without worrying about painful nicks and cuts.<BR><BR><BR> <P> <TABLE cellPadding=5 width=150 align=left> <TBODY> <TR> <TD><IMG src="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/ultra_close_100x100.jpg" align=top border=0 img><BR></TD></TR></TBODY></TABLE><BR><BR><BR><B>Ultra Close Results: </B>Bodygroom&#146;s Chromium Stainless Steel blades deliver ultra close results. The blades ensure long-lasting performance of your Bodygroom and are maintenance-free.<BR><BR><BR><BR> <TABLE cellSpacing=0 cellPadding=0 border=0> <TBODY> <TR> <TD vAlign=top align=left><B>Other standard features include:</B><BR> <UL> <LI class=bullet>Ergonomic design. <LI class=bullet>Safe for use on all body zones: chest & abs, underarms, groin area, legs, back and shoulders <LI class=bullet>Water-resistant for use in the shower <LI class=bullet>Rechargeable: charging time is 8 hours for up to 50 minutes of cordless use <LI class=bullet>Cleaning Brush <LI class=bullet>Charge stand and hanging cord for optimum convenience </LI></UL></TD></TR></TBODY></TABLE> Every Philips Norelco Grooming product comes w ...
#
# I'm not too upset by the death of my Bodygroom - while I had hoped it would last longer it wasn't very expensive to start with so I'll order another one.  Why?  Because it gets the job done.
#
# Yes, the guard clogs with hair quickly.  That's why I use it in the shower...makes cleanup much easier!  If I trim too quickly the guard comes off but fortunately I haven't shaved a bare swath across my chest...yet.
#
# As for the more sensitive areas, well, it works well there too without pain - if you're careful.  It's easy to get the wrong angle and have the trimmer blade (that cuts with the guard) contact skin.  Work slowly to ensure only the center touches skin.
#
# It's not perfect but it works great for taming unruly chest hair, and if you prefer a smoother look elsewhere, well, it can take care of that too. | rating: 4.0 | summary: Worked for 2 1/2 years | unixReviewTime: 2011-01-06 | reviewTime: 2011-01-06 | vote: nan | style: nan - Rating: 4.0 stars
# * asin: B000050B65 | title: Norelco 6885XL Deluxe Quadra Action Cord/Cordless Rechargeable Men's Shaver | feature: [] | description: ['This high-tech shaver comes with an LCD indicator that shows the number of shaving minutes remaining on your battery. The Norelco Quadra features a quick charge for a 3-minute shave, or a full charge for longer shaves. Quadra Action System adjusts the floating razor heads to hug the contours of your face. Indicator lights up when it is time to clean and razor rinses clean with tap water. Cord and cordless operation. Worldwide voltage. Includes deluxe pouch, protective razor head cap, coil cord and cleaning brush. No. 6885XL. Imported.', "This 7-watt electric razor puts three individually floating shaving heads to work clearing away stubble. The stainless-steel heads adjust automatically in multiple directions to fit facial contours, while the blades shave in two stages, with slots for long hairs and holes for short hairs. Operating either with the cord or cordless, the razor provides a pop-up trimmer for mustaches and sideburns and rinses clean after use. It's perfect for the traveling man because it works worldwide on systems from 110 to 240 volts, recharges fully in one hour for 45 minutes of shaving time or charges in six minutes for a three-minute shave, and fits into a soft, molded plastic travel case. For those on the go, this shaver can be recharged from any 12-volt car or boat battery (special adapter cable is not included). An LCD light signals when recharging and/or cleaning is needed. There's also a plastic stand to store the razor upright. Norelco provides a 60-day, full-refund satisfaction guarantee after three weeks of use and a two-year warranty against defects. <I>--Fred Brack</I>"] | price: nan | brand: Norelco | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: ['B01B1O9DOM', 'B00JITDVD2', 'B01KXV16DK', 'B00AEINQ9K', 'B07CKYCNXM', 'B01H6YAJXA', 'B076M7J7T1', 'B079QHML21'] | details: {} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 2.0 | reviewerID: A141OPVE376YFI | reviewerName: Paul G. | verified: False | reviewText: First, a little background.  I've switched between Norelco electric razors and blades over the years, never quite satisfied with the shave I was getting.  Norelco has always said "shaves as close as a blade or your money back".  I've never found this to be true, but the razors were good enough that I didn't return them.  Most recently I used the Gilette Mach 3 razor which does a very good job.
# Now here's why I give the 6885XL (6886XL is apparently the same model, sold at Costco and other warehouse stores) 5 stars:
# - Closest shave yet.  This is the first electric razor I've used that shaves as close as a blade (including the Mach 3).  In fact, it shaves closer than a blade under my jaw and around my adam's apple.  I can't shave against the grain with a blade in those areas or my skin breaks out (and that's the only way to get the closest shave.)  With the 6885XL I don't have this problem and I get a really close shave.
# - It's quiet.  Previous electric razors were so noisy I had to shave in another bathroom so I wouldn't wake my wife.  Not so with this one.
# - Easy to clean.  Open the top and run hot water through it.  No more brushes (except for periodic maintenance).  An indicator will tell you when it's time to clean.
# Other features:
# - Charge remaining (in minutes) display.  This isn't particularly useful to me, but it seems reasonable accurate.
# - It comes with a stand that holds the razor upright on the counter or basin.  Much neater than the razor just laying around or stuffed in a cabinet.
# - Hard carrying case, for travel.
# - Automatically adjusts to different voltages.
# My wife about had a heart attack when I bought it.  However, it gives me the best shave ever (electric or blades). | rating: 5.0 | summary: Finally, a razor that lives up to the ads | unixReviewTime: 2001-06-08 | reviewTime: 2001-06-08 | vote: 81 | style: nan - Rating: 5.0 stars
# Predicted Item: Braun Clean &amp; Renew Refill Cartridges CCR - 2 Count (Packaging May Vary) (Code: B000050FDY)
# Predicted Rating: 3.0 stars
#
# ----------------
#
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this asin: B001AJD0UM. title: Philips Norelco 7810XL Men's Cutting System. feature: []. description: ['The new 7810 features the Precision Cutting System with slots to cut long hairs and holes to shave the shortest stubble. Also, the 7810 features an ergonomically-designed handle for comfort. Cleaning is simple with the 7810 as it is completely washable. The Patented Reflex Action System automatically adjusts to every curve on your face for flexible, smoother shaving. Super Lift and Cut technology features a dual blade system that lifts hairs to cut comfortably below skin level. Model number 7810 and 7810XL are one and the same.', '<style type="text/css">  .caption { font-family: Verdana, Helvetica neue, Arial, serif; font-size: 10px; font-weight: bold; font-style: italic; }  ul.indent { list-style: inside disc; text-indent: 20px; } </style>  The fully washable Philips Norelco 7810XL Men\'s Shaving System showcases the unique Philips Norelco Precision Cutting System, which combines slots to cut long hairs and holes to trim even the shortest stubble, resulting in a clean, uniform shave. The Patented Reflex Action System combines with Individually Floating Heads to easily navigate the curves of your face and neck, while Super Lift &amp; Cut Technology allows this shaver to achieve a below-the-skin cut. An ergonomically designed grip provides the 7810XL with exceptional handling, while the shaver\'s one-hour full charge offers up to 17 days of cordless shaving. When you\'re on the go, a three-minute quick charge provides one cordless shave.<P>', '<table align=right width=175 cellpadding=20> <tr> <td> <a href="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/B001AJD0UM-1-lg.jpg" onclick="window.open(this.href,null,\'width=511,height=810\'); return false;"><img src="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/B001AJD0UM-1-sm.jpg" border=0></a><br><br><span class="caption">The Philips Norelco 7810XL Men\'s Shaving System features a stylish, easy to use design. <a href="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/B001AJD0UM-1-lg.jpg" onclick="window.open(this.href,null,\'width=511,height=810\'); return false;">View larger</a>.</span> </td> </tr> </table>  <table border="0" cellpadding=10>  <tr><td><img src="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/B001AJ8YGC-2-sm.jpg" border=0></td> <td><b>Precision Cutting System</b><br> Ultra thin heads featuring slots to shave longer hairs and holes to shave the shortest stubble provide a clean, uniform shave. </td></tr>  <tr><td><img src="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/B001AJ6YS2-2-sm.jpg" border=0></td> <td><b>Patented Reflex Action System</b><br> The patented reflex action system adjusts automatically to every curve on your face and neck for an uncommonly smooth shave. </td></tr>  <tr><td><img src="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/B001AJ6YS2-3-sm.jpg" border=0></td> <td><b>Individually Floating Heads </b><br> Three individually floating heads follow the contours of your face and neck, aligning the razor-sharp blades next to your skin for exceptional closeness.', '</td></tr>  <tr><td><img src="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/B001AJ6YS2-4-sm.jpg" border=0></td> <td><b>Super Lift &amp; Cut Technology </b><br> Super lift &amp; cut technology is a unique two blade system. The first blade lifts and the second blade cuts. This below skin cut results in a more comfortable shave. </td></tr>  <tr><td><img src="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/B001AJ6YS2-6-sm.jpg" border=0></td> <td><b>Fully Washable</b><br> It\'s simple to rinse this water-resistant shaver under the tap. This saves time, eliminates messes, and keeps your shaver in tip-top condition. </td></tr> </table>  <b>Standard Features</b><br> A spring release, pop-up trimmer is a standard feature  ...
# product_category: Beauty? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * asin: B000068PBO | title: Norelco 5810XL Reflex Action Shaving System | feature: [] | description: ["Norelco's Reflex Shaving system provides unexpected closeness and convenience without the nicks and cuts of blades.", "The three floating heads on this cord/cordless shaver adjust in  multiple directions to fit facial contours while Norelco's Lift & Cut  below-skin shaving technology produces a close, smooth shave. A  full-width trimmer pops up for neat work on sideburns and mustaches.  Perfect for the traveling man because it works worldwide on 110-volt to  240-volt systems, the razor recharges fully in one hour for 30 minutes  of cordless shaving time or quick-charges in six minutes for a  three-minute shave. An LED meter shows when the shaver is charging and  blinks when it's fully charged. The shaver fits the hand comfortably  and comes in a soft, molded-plastic travel case. It carries a 60-day,  full-satisfaction, money-back guarantee and a two-year warranty against  defects. <I>--Fred Brack</I>"] | price: nan | brand: Norelco | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: ['B001IA0PCY', 'B004URZADG', 'B00JITDVD2', 'B01DDKS2JO', 'B000068PBT', 'B075G1RM7R'] | details: {'Shipping Weight:': '14.4 ounces', 'ASIN: ': 'B000068PBO'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 2.0 | reviewerID: A1TVTDKNMSQ7XU | reviewerName: Grandpa Pipes | verified: True | reviewText: I bought this shaver to replace an older corded Norelco. After using it for two weeks I find it to be an ideal shaving tool with
# all the needed bells and whistles and no more. Norelco put ALL of the required features for a good shave in this model. Simple and to the point. A sleeper in the Norelco shaver model lineup if there is one. | rating: 5.0 | summary: A simple shaver that could. | unixReviewTime: 2003-06-28 | reviewTime: 2003-06-28 | vote: 6 | style: nan - Rating: 5.0 stars
# * asin: B000050B6B | title: Philips Norelco HQ5 Shaving Heads | feature: [] | description: ['Replacement razor heads for Reflex Action razor models only. (Does not fit Reflex Plus.)', 'These three stainless-steel heads fit Norelco Reflex Action razors only. Installing them is simple, and the package provides illustrated instructions. Combined, the three heads provide 45 hair lifters and 45 rotating blades to shave below the skin. They adjust to individual facial contours for a smooth, effortless shave. <I>--Fred Brack</I>'] | price: 64.5 | brand: Philips Norelco | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: ['B001IA0PCY', 'B00196W5S4', 'B004URZADG', 'B07B4WQHQY', 'B01DDKS2JO', 'B00JWKF50E', 'B07K37JBGT', 'B000068PBT', 'B06Y5PP751', 'B00126ZXPI', 'B00JITDVD2', 'B00R5PT0H2', '7293000154', 'B0042AE50U', 'B07K35QSKD', 'B00CQFLNEE', 'B01KXV16DK', 'B075G1RM7R', 'B00LSQTSSU', 'B07CKYCNXM', 'B0736CDYH3', 'B01859QG3W', 'B07DRMJCFB', 'B00DK9Y6D0', 'B073ZMYBVL', 'B00009RB1C'] | details: {'\n    Product Dimensions: \n    ': '5.1 x 0.3 x 6.3 inches', 'Shipping Weight:': '0.8 ounces (', 'ASIN: ': 'B000050B6B', 'UPC:': '075020000699 075020202055', 'Item model number:': 'HQ5', 'Discontinued by manufacturer:': 'Yes'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 148.0 | reviewerID: A1TVTDKNMSQ7XU | reviewerName: Grandpa Pipes | verified: True | reviewText: I've had many Norelco razors in my 50 years of shaving with all being renewed
# with a fresh set of heads after a few years. Every Norelco I owned always failed
# the switch so be mindful of that if you want new heads.
#
# Switch OK? Then buy new heads and keep on shavin' | rating: 5.0 | summary: Just like new..... | unixReviewTime: 2008-07-25 | reviewTime: 2008-07-25 | vote: nan | style: nan - Rating: 5.0 stars
# * asin: B000068PBO | title: Norelco 5810XL Reflex Action Shaving System | feature: [] | description: ["Norelco's Reflex Shaving system provides unexpected closeness and convenience without the nicks and cuts of blades.", "The three floating heads on this cord/cordless shaver adjust in  multiple directions to fit facial contours while Norelco's Lift & Cut  below-skin shaving technology produces a close, smooth shave. A  full-width trimmer pops up for neat work on sideburns and mustaches.  Perfect for the traveling man because it works worldwide on 110-volt to
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "(5.0 stars, 100%)"
# Processing user 3/1608, item 2/5
# User A1TVTDKNMSQ7XU:
# Rating History for Prediction:
# * asin: B000068PBO | title: Norelco 5810XL Reflex Action Shaving System | feature: [] | description: ["Norelco's Reflex Shaving system provides unexpected closeness and convenience without the nicks and cuts of blades.", "The three floating heads on this cord/cordless shaver adjust in  multiple directions to fit facial contours while Norelco's Lift & Cut  below-skin shaving technology produces a close, smooth shave. A  full-width trimmer pops up for neat work on sideburns and mustaches.  Perfect for the traveling man because it works worldwide on 110-volt to  240-volt systems, the razor recharges fully in one hour for 30 minutes  of cordless shaving time or quick-charges in six minutes for a  three-minute shave. An LED meter shows when the shaver is charging and  blinks when it's fully charged. The shaver fits the hand comfortably  and comes in a soft, molded-plastic travel case. It carries a 60-day,  full-satisfaction, money-back guarantee and a two-year warranty against  defects. <I>--Fred Brack</I>"] | price: nan | brand: Norelco | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: ['B001IA0PCY', 'B004URZADG', 'B00JITDVD2', 'B01DDKS2JO', 'B000068PBT', 'B075G1RM7R'] | details: {'Shipping Weight:': '14.4 ounces', 'ASIN: ': 'B000068PBO'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 2.0 | reviewerID: A1TVTDKNMSQ7XU | reviewerName: Grandpa Pipes | verified: True | reviewText: I bought this shaver to replace an older corded Norelco. After using it for two weeks I find it to be an ideal shaving tool with
# all the needed bells and whistles and no more. Norelco put ALL of the required features for a good shave in this model. Simple and to the point. A sleeper in the Norelco shaver model lineup if there is one. | rating: 5.0 | summary: A simple shaver that could. | unixReviewTime: 2003-06-28 | reviewTime: 2003-06-28 | vote: 6 | style: nan - Rating: 5.0 stars
# * asin: B000050B6B | title: Philips Norelco HQ5 Shaving Heads | feature: [] | description: ['Replacement razor heads for Reflex Action razor models only. (Does not fit Reflex Plus.)', 'These three stainless-steel heads fit Norelco Reflex Action razors only. Installing them is simple, and the package provides illustrated instructions. Combined, the three heads provide 45 hair lifters and 45 rotating blades to shave below the skin. They adjust to individual facial contours for a smooth, effortless shave. <I>--Fred Brack</I>'] | price: 64.5 | brand: Philips Norelco | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: ['B001IA0PCY', 'B00196W5S4', 'B004URZADG', 'B07B4WQHQY', 'B01DDKS2JO', 'B00JWKF50E', 'B07K37JBGT', 'B000068PBT', 'B06Y5PP751', 'B00126ZXPI', 'B00JITDVD2', 'B00R5PT0H2', '7293000154', 'B0042AE50U', 'B07K35QSKD', 'B00CQFLNEE', 'B01KXV16DK', 'B075G1RM7R', 'B00LSQTSSU', 'B07CKYCNXM', 'B0736CDYH3', 'B01859QG3W', 'B07DRMJCFB', 'B00DK9Y6D0', 'B073ZMYBVL', 'B00009RB1C'] | details: {'\n    Product Dimensions: \n    ': '5.1 x 0.3 x 6.3 inches', 'Shipping Weight:': '0.8 ounces (', 'ASIN: ': 'B000050B6B', 'UPC:': '075020000699 075020202055', 'Item model number:': 'HQ5', 'Discontinued by manufacturer:': 'Yes'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 148.0 | reviewerID: A1TVTDKNMSQ7XU | reviewerName: Grandpa Pipes | verified: True | reviewText: I've had many Norelco razors in my 50 years of shaving with all being renewed
# with a fresh set of heads after a few years. Every Norelco I owned always failed
# the switch so be mindful of that if you want new heads.
#
# Switch OK? Then buy new heads and keep on shavin' | rating: 5.0 | summary: Just like new..... | unixReviewTime: 2008-07-25 | reviewTime: 2008-07-25 | vote: nan | style: nan - Rating: 5.0 stars
# ...
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "3 stars, 60%"
# Processing user 50/1608, item 1/5
# User A2PSC7LUNIDEAH:
# Rating History for Prediction:
# * asin: B001VEK1GW | title: Braun bodyCruzer Men's Body Groomer, Titanium | feature: [] | description: ['Introducing a revolutionary body grooming experience, new Braun bodyCruzer. Equipped with a precision power trimmer to effectively to trim body hair and a Gillette Fusion blade for an incredible level of closeness and comfort, the new Braun bodyCruzer helps you get the groomed body look you want.', 'Introducing a revolutionary body grooming experience: the new Braun bodyCruZer. Equipped with a precision power trimmer to effectively to trim body hair and a Gillette Fusion blade for an incredible level of closeness and comfort, the new Braun bodyCruZer helps you get the groomed body look you want. Recommended for all body areas. Braun bodyCruZer is the only body groomer in the world that combines a Braun electric precision trimmer to shorten hairs and a Gillette blade for a clean and comfortable shave anywhere on the body. You can use the trimmer alone, the blade alone, or use both in combination. An attachable comb also lets you trim hair to a preferred length. The Worlds only body groomer with a powered trimmer and a Gillette Fusion blade, all in one! 100% waterproof / in and out of the shower. <style type="text/css"> #section-head { width: auto; margin: 0px 0px 10px 0px; padding-top: 5px; padding-bottom: 5px; padding-left: 5px; background: #212A59; color: #FFFFFF; font-size: 16px; font-weight: bold; border-bottom: 2px solid #ABD0E1; border-top: 2px solid #ABD0E1; } #section-break { margin-top: 40px; clear: both; } th.reviewclassspan { color: #FFFFFF; font-size: 13px; font-weight: bold; margin-bottom: 2px; padding: 5px; background: #212A59; } th.reviewclass { font-size: 16px; font-weight: bold; color: #212A59; border-bottom: 2px solid #ABD0E1; padding-bottom: 5px; background-color: #FFFFFF; } td.reviewclass { font-size: 13px; color: #212A59; background-color: #CCCCCC; border-bottom: 1px dotted #000000; padding: 5px } #feature-box { position: relative; margin-left: 0px; margin-right: 15px; margin-top: 5px; margin-bottom: 5px; width: 340px; float: left; display: inline; } #feature-box-header { width: auto; padding-top: 3px; padding-bottom: 3px; padding-left: 5px; margin-bottom: 2px; background: #212A59; color: #FFFFFF; font-size: 13px; font-weight: bold; } #feature-box-image { float: left; } #feature-box-container { float: right; width: 213px; height: 124px; background: #CCCCCC; color: #212A59; } #feature-box-content { padding: 5px; font-size: 13px; margin-left: 2px; }</style> <div id="section-break"> </div> <div id="section-head">Product Detail Feature Chart</div> <div> <table width=100% id="table6"> <tr> <th class="reviewclass"> <img src="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/B55_Braunlogo.jpg" width="141" height="99" alt="Bodycruzer logo"/></th> <th class="reviewclass"> <a href="http://www.amazon.com/Braun-BodyCruZer-Mens-Groomer-Titanium/dp/B001VEK1GW"> <img src="https://images-na.ssl-images-amazon.com/images/G/01/hpc/detail-page/B55_shaver_standing_sm.jpg" border="0" width="69" height="100"></a><a href="http://www.amazon.com/Braun-BodyCruZer-Mens-Groomer-Titanium/dp/B001VEK1GW"><br> B-55</a></th> </tr> <tr> <th class="reviewclassspan" colspan="2"> <p align="left"> <b>Shave System</b></th> </tr> <tr> <td class="reviewclass" align="center">Long Hair Trimmer</td> <td class="reviewclass" align=center>Yes</td> </tr> <tr> <td class="reviewclass" align="center">Blade Cartridge on device</td> <td class="reviewclass" align="center">Fusion</td> </tr> <tr> <td class="reviewclass" align="center">Sensitive Comb</td> <td class="reviewclass" align=center>Yes</td> </tr> <tr> <td class="reviewclass" align="center">Comb 1 (3mm)</td> <td class="reviewclass" align=center>Yes</td> </tr> <tr> <td class="reviewclass" align="center">Comb 2 (8mm)</td> <td class="reviewclass" align=center>Yes</td> </tr> <tr> <th class="reviewclassspan" colspan="2"> <p align="left"> <b>Color</b></th> </tr> <tr> <td class="reviewclass" ...
#
# *Decent dry shaver/trimmer that will trim the hair all the way to the stub.
# *Adjustable heads for trimming to the desired hair lenght.
# *Waterproof
# *Durable design
#
# The Bad:
#
# *The blade defeats the purpose of the trimmer in many cases.
#
# The Bottom Line:
#
# This is a decent body groomer from Braun considering other choices out there(Norelco.)  This is one example however when a brand tries too hard to beat out their competition.  The dry trimmer is what you can expect from your body trimmer:  Shaves hair close, but not completely off.  So of course you say to yourself "Well, that's what the Gillette blade is for, right?"  If you think about it, the  number one reason people buy a body groomer like this is because they get irritation while using a blade and here it is, sitting on top of a trimmer.  Therefore, if you are already comfortable using a blade, then there is no reason for you to get this.  For most, if you are getting irritation from a blade, then you will get irritation from using this blade as well.  However, if you rarely get irritations from blades and prefer to use shave/blade combo in the shower/bath, then this could be a good choice for you.  Other things to consider:  One full charge should last you for about 50 minutes.  Overall a decent choice, but certainly not for everyone. | rating: 4.0 | summary: Good idea, but not for everyone(Beware of the blade bite!) | unixReviewTime: 2009-05-22 | reviewTime: 2009-05-22 | vote: nan | style: nan - Rating: 4.0 stars
# * asin: B00005U8U8 | title: Norelco 6756X Deluxe Advantage Wet/Dry Cordless Men's Razor | feature: [] | description: ['Norelco 6756X .. The Norelco Advantage is the only electric shaver that dispenses Nivea for Men shaving lotion or gel for a close, refreshing shave with less irritation. Contour Control automatically adjusts to every curve on your face. Lift and Cut Technology lifts hair to cut below skin level fro a comfortable, close shave. Water Resistant for use in or out of the shower. Includes 10 Nivea for Men alcohol-free cartridges and a handy steam-free shower mirror. Advantage provides the best of both worlds, the convenience of an electric shaver and the wet shave experience of a blade.', 'This 6-watt electric razor has it all. It\'s cordless, shaves a  wet or dry face while dispensing shaving lotion with the push of a  button, automatically adjusts to facial contours with three  stainless-steel shaving heads, provides 45 hair lifters and 45 rotating  blades to shave "below" the skin, and comes with a full-width, snap-on  trimmer for mustache and sideburns. It\'s perfect for the traveling man  because it charges fully worldwide on 110- to 240-volt systems in one  hour to provide 40 minutes shaving time. Including a cord for hanging  the razor in the shower, everything fits in a soft, washable travel  bag. Shaving-lotion cartridges snap in easily, and pump buttons on both  sides of the head dispense the lotion. (Five Nivea lotion and five  Nivea gel cartridges are included--only Nivea may be used with Norelco\'s wet/dry razors.) The head rinses clean after use.  Norelco provides a 60-day, full-refund satisfaction-guarantee after two  weeks of use and a two-year warranty against defects. <i>--Fred  Brack</i>', '', ''] | price: nan | brand: Norelco | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: [] | details: {} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 3.0 | reviewerID: A2PSC7LUNIDEAH | reviewerName: Dmitry Kristal | verified: False | reviewText: If you're a woman and have no idea what to get your guy, get this!!  I got this shaver yestarday and couldn't wait to write a review.  The whole WET SHAVING is great because you can use it in the shower to get a closer shave because you are constantly rinsing your face which will always lubricate your face.  The "goo" cartridge is great also because it is built in.
# Also, there's an adjustable trimmer head for facial hair.
# The only negative is that accessories might get pricey.  Maintenance and assessories might go for about $$$$$ per year. | rating: 4.0 | summary: A perfect gift for a guy.  However, it may get pricey later. | unixReviewTime: 2003-01-01 | reviewTime: 2003-01-01 | vote: 10 | style: nan - Rating: 4.0 stars
# * asin: B000H723LU | title: SK-II Facial Treatment Essence | feature: [] | description: ["SK-II's signature product, the much-loved and most awarded bestseller, Facial Treatment Essence has over 90% pitera, the miracle ingredient discovered over 30 years ago that remains essentially unchanged till today. Its irreplaceable formula gently exfoliates the face and helps moderate the skin surface renewal cycle. SK-II Facial Treatment Essence helps to improve the appearance of 5 dimensions of beautiful, crystal clear skin: spots are less visible, appearance of wrinkles is reduced, skin texture is more refined, firmness is improved, and radiance is beautifully elevated. Skin becomes breathtakingly crystal clear."] | price: 115.21 | brand: nan | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: ['B0739LQ1Z6', 'B00DW909OS', 'B075XFD9VP', 'B0716YHHNH', 'B07BWYK1W4', 'B07CNF2LQC', 'B01HGFW2NY', 'B01N6Z6R5T', 'B07D7GXRHT', 'B0006FL8TG', 'B00SISLLV8', 'B07BZSKJXR', 'B077WHWKSJ', 'B01LY59ZMW', 'B01M1DQ131', 'B0716JS4KX', 'B01MECULV1', 'B0158XU5PI', 'B00IUL532Q', 'B0167C6UOE', 'B012DSVG18', 'B01296JRMO', 'B00BRPBWMW', 'B00QKSWW0C', 'B07C422Z86', 'B07DCP6FSF', 'B077T9XS9D', 'B01M2VINAC', 'B075T2YTD8', 'B00EEA8O8C', 'B01IMA7HXM', 'B01I2ZP7QQ', 'B0721QQLND', 'B07HH815D3', 'B005Z5Q2PC', 'B076D34QPS', 'B00ILN3RGM', 'B07CQWVPLH', 'B07CWF1N7N', 'B07C84JW6N', 'B004R9GWW0', 'B07BYZHMZ9', 'B00Q2QDWGK', 'B072J8Z1RQ', 'B00JN0M5WO', 'B009VXTTRW', 'B00DSRK3WW', 'B01276ZKW2', 'B00P6W0IMM', 'B003MBVNIM', 'B01KOTOH3W'] | details: {'\n    Product Dimensions: \n    ': '1.6 x 5.5 x 0.1 inches ; 1.6 ounces', 'Shipping Weight:': '7.2 ounces (', 'Domestic Shipping: ': 'Item can be shipped within U.S.', 'International Shipping: ': 'This item is not eligible for international shipping.', 'ASIN:': 'B000H723LU', 'Item model number:': 'U-SC-3249'} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 396.0 | reviewerID: A2PSC7LUNIDEAH | reviewerName: Dmitry Kristal | verified: False | reviewText: With the high price tag and time it takes to see some result, make sure you have some patience with this product.  I am surprised that the only instruction for this treatment is the video that you see on top of the Amazon page.  Another issue is the dispensing of the product: You have to carefully pour it from a plastic hole without allow any drops on the floor.
#
# While you should see some results within a week such as tightening of the pores, the question is whether or not it is cost-effective to keep buying more bottles after the initial one?  Tread carefully! | rating: 4.0 | summary: Great product, but at what cost? | unixReviewTime: 2015-02-22 | reviewTime: 2015-02-22 | vote: nan | style: {'Size:': ' 2.5 fl. oz.'} - Rating: 4.0 stars
# * asin: B00005U8U8 | title: Norelco 6756X Deluxe Advantage Wet/Dry Cordless Men's Razor | feature: [] | description: ['Norelco 6756X .. The Norelco Advantage is the only electric shaver that dispenses Nivea for Men shaving lotion or gel for a close, refreshing shave with less irritation. Contour Control automatically adjusts to every curve on your face. Lift and Cut Technology lifts hair to cut below skin level fro a comfortable, close shave. Water Resistant for use in or out of the shower. Includes 10 Nivea for Men alcohol-free cartridges and a handy steam-free shower mirror. Advantage provides the best of both worlds, the convenience of an electric shaver and the wet shave experience of a blade.', 'This 6-watt electric razor has it all. It\'s cordless, shaves a  wet or dry face while dispensing shaving lotion with the push of a  button, automatically adjusts to facial contours with three  stainless-steel shaving heads, provides 45 hair lifters and 45 rotating  blades to shave "below" the skin, and comes with a full-width, snap-on  trimmer for mustache and sideburns. It\'s perfect for the traveling man  because it charges fully worldwide on 110- to 240-volt systems in one  hour to provide 40 minutes shaving time. Including a cord for hanging  the razor in the shower, everything fits in a soft, washable travel  bag. Shaving-lotion cartridges snap in easily, and pump buttons on both  sides of the head dispense the lotion. (Five Nivea lotion and five  Nivea gel cartridges are included--only Nivea may be used with Norelco\'s wet/dry razors.) The head rinses clean after use.  Norelco provides a 60-day, full-refund satisfaction-guarantee after two  weeks of use and a two-year warranty against defects. <i>--Fred  Brack</i>', '', ''] | price: nan | brand: Norelco | category: [] | tech1: nan | tech2: nan | also_buy: [] | also_view: [] | details: {} | main_cat: All Beauty | similar_item: nan | date: nan | rank: 3.0 | reviewerID: A2PSC7LUNIDEAH | reviewerName: Dmitry Kristal | verified: False | reviewText: If you're a woman and have no idea what to get your guy, get this!!  I got this shaver yestarday and couldn't wait to write a review.  The whole WET SHAVING is great because you can use it in the shower to get a closer shave because you are constantly rinsing your face which will always lubricate your face.  The "goo" cartridge is great also because it is built in.
# Also, there's an adjustable trimmer head for facial hair.
# The only negative is that accessories might get pricey.  Maintenance and assessories might go for about $$$$$ per year. | rating: 4.0 | summary: A perfect gift for a guy.  However, it may get pricey later. | unixReviewTime: 2003-01-01 | reviewTime: 2003-01-01 | vote: 10 | style: nan - Rating: 4.0 stars
# Predicted Item: Gillette Bodywash, Dry Skin Hydrator &amp; Body Wash, 12-Ounce Bottle (Pack of 6) (Code: B0019ZD61A)
# Predicted Rating: 3.0 stars
#
# ----------------
#
# Processed 50 users. Pausing for 60 seconds...

# %%
# Evaluate Few-shot Model
evaluate_model_predictions_rmse_mae(
    data_path=FEW_SHOT_1_OBS_SAVE_PATH,
    num_examples=NUM_EXAMPLES,
    actual_ratings_column='actual_rating',
    predicted_ratings_column='few_shot_predicted_rating'
)

# %% [markdown]
# # Limitations:
#
# The model might not fully understand the nuanced relationships between products based on titles alone. Additional context or features might be needed for more accurate predictions.
# This approach might be computationally expensive and slower than traditional matrix factorization or deep learning-based recommendation models, especially for a large number of users.
#
# # References
#
# + https://platform.openai.com/docs/api-reference/authentication
