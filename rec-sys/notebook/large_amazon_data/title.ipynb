# %%
import numpy as np
import openai
import pandas as pd
import os
import sys
import time

# Add the path to the constants file to the system path
sys.path.append('../../')
from constants import *
from evaluation_utils import *
from path_utils import *
from ChatCompletion_OpenAI_API import *

# OpenAI API Key
openai.api_key = OPENAI_API_KEY
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# source code folder path
rec_sys_dir = get_rec_sys_directory()
print(f"Rec-sys directory: {rec_sys_dir}")

# data folder path
DATA_DIR = os.path.join(rec_sys_dir, 'data')
print(f"Data directory: {DATA_DIR}")

# data path
data_path = os.path.join(DATA_DIR, 'amazon-beauty/large_merged_data.csv')
print(f'Data path: {data_path}')

# zero shot save path
ZERO_SHOT_SAVE_PATH = os.path.join(DATA_DIR, 'amazon-beauty/output/title_large_predictions_zero_shot.csv')
print(f'Zero shot save path: {ZERO_SHOT_SAVE_PATH}')

# few shot save path
FEW_SHOT_1_OBS_SAVE_PATH = os.path.join(DATA_DIR, 'amazon-beauty/output/title_large_1_test_predictions_few_shot.csv')
print(f'Few shot save path: {FEW_SHOT_1_OBS_SAVE_PATH}')
# Out:
# Rec-sys directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys
# Data directory: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data
# Data path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/large_merged_data.csv
# Zero shot save path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/output/title_large_predictions_zero_shot.csv
# Few shot save path: /Users/tnathu-ai/VSCode/recommender-system/recommender-system-openAI/rec-sys/data/amazon-beauty/output/title_large_1_test_predictions_few_shot.csv

# %% [markdown]
# # Data Overview

# %%
# Read the data
data = pd.read_csv(data_path)

# get statistic and first few data of NUM_SAMPLES rows
data.info()
data.head(NUM_EXAMPLES)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9767 entries, 0 to 9766
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rating          9767 non-null   float64
#  1   verified        9767 non-null   bool
#  2   reviewTime      9767 non-null   object
#  3   reviewerID      9767 non-null   object
#  4   asin            9767 non-null   object
#  5   reviewerName    9767 non-null   object
#  6   reviewText      9759 non-null   object
#  7   summary         9759 non-null   object
#  8   unixReviewTime  9767 non-null   object
#  9   vote            1487 non-null   object
#  10  style           6768 non-null   object
#  11  category        9767 non-null   object
#  12  tech1           2 non-null      object
#  13  description     9767 non-null   object
#  14  fit             0 non-null      float64
#  15  title           9767 non-null   object
#  16  also_buy        9767 non-null   object
#  17  tech2           0 non-null      float64
#  18  brand           8749 non-null   object
#  19  feature         9767 non-null   object
#  20  rank            9703 non-null   float64
#  21  also_view       9767 non-null   object
#  22  details         9767 non-null   object
#  23  main_cat        9767 non-null   object
#  24  similar_item    62 non-null     object
#  25  date            2 non-null      object
#  26  price           3291 non-null   float64
# dtypes: bool(1), float64(5), object(21)
# memory usage: 1.9+ MB
#    rating  verified  reviewTime      reviewerID        asin  \
# 0     1.0     False  2015-08-25  A2RYSCZOPEXOCQ  9790787006
# 1     5.0     False  2001-06-08  A141OPVE376YFI  B000050B65
# 2     5.0     False  2001-06-08  A141OPVE376YFI  B000050B65
# 3     5.0      True  2008-07-25  A1TVTDKNMSQ7XU  B000050B6B
# 4     5.0      True  2008-07-25  A1TVTDKNMSQ7XU  B000050B6B
#
#         reviewerName                                         reviewText  \
# 0  The Cat Next Door  I use a lot of perfume, I go through a new bot...
# 1            Paul G.  First, a little background.  I've switched bet...
# 2            Paul G.  First, a little background.  I've switched bet...
# 3      Grandpa Pipes  I've had many Norelco razors in my 50 years of...
# 4      Grandpa Pipes  I've had many Norelco razors in my 50 years of...
#
#                                       summary unixReviewTime vote  ... tech2  \
# 0  This is not going to be my favorite scent.     2015-08-25  NaN  ...   NaN
# 1   Finally, a razor that lives up to the ads     2001-06-08   81  ...   NaN
# 2   Finally, a razor that lives up to the ads     2001-06-08   81  ...   NaN
# 3                          Just like new.....     2008-07-25  NaN  ...   NaN
# 4                          Just like new.....     2008-07-25  NaN  ...   NaN
#
#              brand feature   rank  \
# 0    Jenna Jameson      []  298.0
# 1          Norelco      []    2.0
# 2          Norelco      []    2.0
# 3  Philips Norelco      []  148.0
# 4  Philips Norelco      []  148.0
#
#                                            also_view  \
# 0         ['B00357FTX8', 'B01NBID7FJ', 'B0017JT658']
# 1  ['B01B1O9DOM', 'B00JITDVD2', 'B01KXV16DK', 'B0...
# 2  ['B01B1O9DOM', 'B00JITDVD2', 'B01KXV16DK', 'B0...
# 3  ['B001IA0PCY', 'B00196W5S4', 'B004URZADG', 'B0...
# 4  ['B001IA0PCY', 'B00196W5S4', 'B004URZADG', 'B0...
#
#                                              details    main_cat  \
# 0  {'Shipping Weight:': '12.8 ounces (', 'ASIN: '...  All Beauty
# 1                                                 {}  All Beauty
# 2                                                 {}  All Beauty
# 3  {'\n    Product Dimensions: \n    ': '5.1 x 0....  All Beauty
# 4  {'\n    Product Dimensions: \n    ': '5.1 x 0....  All Beauty
#
#    similar_item date  price
# 0           NaN  NaN  13.85
# 1           NaN  NaN    NaN
# 2           NaN  NaN    NaN
# 3           NaN  NaN  64.50
# 4           NaN  NaN  64.50
#
# [5 rows x 27 columns]

# %% [markdown]
# # Zero-shot (OpenAI API)

# %%
# %%time

predict_ratings_zero_shot_and_save(data,
                                       columns_for_prediction=['title'],
                                       pause_every_n_users=PAUSE_EVERY_N_USERS,
                                       sleep_time=SLEEP_TIME,
                                       save_path=ZERO_SHOT_SAVE_PATH)

# %%
import pandas as pd

# Read the data
data = pd.read_csv(ZERO_SHOT_SAVE_PATH)

# Display the original data types
# print("Original Data Types:")
# print(data.dtypes)
# print("\n")

# Attempt to convert ratings to float and add a flag for conversion failure
data['is_rating_float'] = pd.to_numeric(data['zero_shot_predicted_rating'], errors='coerce').notna()

# Filter rows where ratings are not float
non_float_ratings = data[data['is_rating_float'] == False]

# total number of rows with non-float ratings
print(f"Total number of rows with non-float ratings: {len(non_float_ratings)}")

# Display rows with non-float ratings
print("Rows with non-float ratings:")
non_float_ratings.head(3)

# %%
# %%time


# # Re-run zero-shot predictions for failed cases
# zero_shot_data = pd.read_csv(ZERO_SHOT_SAVE_PATH)
# # Attempt to convert ratings to float and add a flag for conversion failure
# zero_shot_data['is_rating_float'] = pd.to_numeric(zero_shot_data['zero_shot_predicted_rating'], errors='coerce').notna()
# failed_zero_shot_indices = zero_shot_data[zero_shot_data['is_rating_float'] == False].index
# zero_shot_data = rerun_failed_predictions(
#     zero_shot_data, 
#     failed_zero_shot_indices, 
#     predict_ratings_zero_shot_and_save, 
#     ZERO_SHOT_SAVE_PATH,
#     columns_for_prediction=['title'],
#     user_column_name='reviewerID',
#     pause_every_n_users=PAUSE_EVERY_N_USERS,
#     sleep_time=SLEEP_TIME
# )

# %%
evaluate_model_predictions_rmse_mae(
    data_path=ZERO_SHOT_SAVE_PATH,
    num_examples=NUM_EXAMPLES,
    actual_ratings_column='rating',
    predicted_ratings_column='zero_shot_predicted_rating'
)

# %% [markdown]
# # Few-shot (OpenAI API)
#
#
# + For each user, we'll use 4 of their ratings as training data to predict ratings for the rest of their products. Finally, we'll evaluate the predictions against the actual ratings to calculate the overall RMSE and MAE.
#
# + The rating_history_str now includes both the title and the review text for each of the training data rows

# %% [markdown]
# # 1 observation per reviewer - Few-shot OpenAI

# %%
# %%time

predict_ratings_few_shot_and_save(data,
                                      columns_for_training=['title'],
                                       columns_for_prediction=['title'],
                                       obs_per_user=1,
                                       pause_every_n_users=PAUSE_EVERY_N_USERS,
                                       sleep_time=SLEEP_TIME,
                                       save_path=FEW_SHOT_1_OBS_SAVE_PATH)
# Out:
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Caboodles Heart Throb Long Tapered Tote, Black Diamond, 1.12 Pound? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Kordon Oasis (Novalek) Bell Bottle 8oz - Rating: 5.0 stars
# * title: Jenna Jameson Heartbreaker Perfume for women 3.4 oz Eau De Parfum Spray - Rating: 1.0 stars
# * title: Kordon Oasis (Novalek) Bell Bottle 8oz - Rating: 5.0 stars
# * title: OZNaturals Anti Aging Retinol Serum -The Most Effective Anti Wrinkle Serum Contains Professional Strength Retinol+ Astaxanthin+ Vitamin E - Get The Dramatic Youthful Results You&rsquo;ve Been Looking For - Rating: 4.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "3 stars, 60%"
# Extracted rating: 3.0
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Braun Clean &amp; Renew Refill Cartridges CCR - 2 Count (Packaging May Vary)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Braun 8000 Activator Combi-Pack Foil and Cutterblock Replacement Parts for Braun's Activator Razor Models 8595 and 8585 - Rating: 1.0 stars
# * title: Braun 8000 Activator Combi-Pack Foil and Cutterblock Replacement Parts for Braun's Activator Razor Models 8595 and 8585 - Rating: 1.0 stars
# * title: Philips Norelco BG2020 BodyGroom - Rating: 4.0 stars
# * title: Norelco 6885XL Deluxe Quadra Action Cord/Cordless Rechargeable Men's Shaver - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "(4 stars, 80%)"
# Extracted rating: 4.0
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Philips Norelco 7810XL Men's Cutting System? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Norelco 5810XL Reflex Action Shaving System - Rating: 5.0 stars
# * title: Philips Norelco HQ5 Shaving Heads - Rating: 5.0 stars
# * title: Norelco 5810XL Reflex Action Shaving System - Rating: 5.0 stars
# * title: Philips Norelco HQ5 Shaving Heads - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "5 stars, 100%"
# Extracted rating: 5.0
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Pump for 33.8 oz American Crew Bottles? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: AXE Shower Tool, Detailer 1 ea, Pack of 4 - Rating: 5.0 stars
# * title: Braun Clean &amp; Renew Refill Cartridges CCR - 2 Count (Packaging May Vary) - Rating:
Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "5 stars"
# Extracted rating: 5.0
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: Groganics Dht Deep Freeze Shampoo 8oz (3 Pack) - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "5 stars, 100%"
# Extracted rating: 5.0
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: Peter Lamas Wheatgrass Purifying Shampoo and Conditioner Set, 12 Fluid Ounce Each - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "5 stars"
# Extracted rating: 5.0
# Processed 150 users. Pausing for 60 seconds...
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "5 stars"
# Extracted rating: 5.0
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 4.0 stars
# * title: Sexy Straight Smooth and Seal Hair Spray 8.1 Ounce (Pack of 3) - Rating: 4.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 4.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 4.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "3 stars, 60%"
# Extracted rating: 3.0
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: Classics Jovan Musk Womens 4 Piece Gift Set - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 80%"
# Extracted rating: 4.0
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: Dolce &amp; Gabbana Compact Parfum, 0.05 Ounce - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "5 stars"
# Extracted rating: 5.0
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: Theorie Argan Oil Ultimate Reform Shampoo &amp; Conditioner 27 Fl Oz Each - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "5 stars, 100%"
# Extracted rating: 5.0
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: Bumble and Bumble Texture Hair Un Dressing Creme 5 oz - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4.5 stars, 90%"
# Extracted rating: 4.5
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4 stars, 80%"
# Extracted rating: 4.0
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: (Pack of 3) L.A. Colors Mineral Pressed Powder #Mp303 &quot;Creamy Natural&quot; - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "4.5 stars, 90%"
# Extracted rating: 4.5
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Khadi Natural Ayurvedic Herbal 18 Herbs Hair Oil for Strong Smooth Hair (210 ml)? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz - Rating: 5.0 stars
# * title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz - Rating: 5.0 stars
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: Dolce &amp; Gabbana Compact Parfum, 0.05 Ounce - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "5 stars, 100%"
# Extracted rating: 5.0
# Constructed Prompt for few-shot approach:
#
# The prompt:
# **********
# How will user rate this title: Bath &amp; Body Works Ile De Tahiti Moana Coconut Vanille Moana Body Wash with Tamanoi 8.5 oz? (1 being lowest and 5 being highest) Attention! Just give me back the exact number as a result, and you don't need a lot of text.
#
# Here is user rating history:
# * title: Avalon Grapefruit and Geranium Smoothing Shampoo, 11 Ounce - Rating: 5.0 stars
# * title: Axe Daily Clean Shampoo, Black Chill Cool Metal, 12 Ounce (Pack of 6) - Rating: 5.0 stars
# * title: Citre Shine Moisture Burst Shampoo - 16 fl oz - Rating: 5.0 stars
# * title: Bonne Bell Smackers Bath and Body Starburst Collection - Rating: 5.0 stars
#
# Based on the above information, please predict user's rating for the product: (1 being lowest and 5 being highest, The output should be like: (x stars, xx%), do not explain the reason.)
# **********
#
#
#
# System Fingerprint: fp_eeff13170a
#
# API call response: "5 stars, 100%"
# Extracted rating: 5.0
# Processed 160 users. Pausing for 60 seconds...

# %%
import pandas as pd

# Read the data
data = pd.read_csv(FEW_SHOT_1_OBS_SAVE_PATH)

# Display the original data types
# print("Original Data Types:")
# print(data.dtypes)
# print("\n")

# Attempt to convert ratings to float and add a flag for conversion failure
data['is_rating_float'] = pd.to_numeric(data['few_shot_predicted_rating'], errors='coerce').notna()

# Filter rows where ratings are not float
non_float_ratings = data[data['is_rating_float'] == False]

# total number of rows with non-float ratings
print(f"Total number of rows with non-float ratings: {len(non_float_ratings)}")

# Display rows with non-float ratings
print("Rows with non-float ratings:")
non_float_ratings.head(3)

# %%
# # Re-run few-shot predictions for failed cases
# few_shot_data = pd.read_csv(FEW_SHOT_1_OBS_SAVE_PATH)
# # Add code to detect failed few-shot predictions similar to zero-shot
# few_shot_data['is_rating_float_few_shot'] = pd.to_numeric(few_shot_data['few_shot_predicted_rating'], errors='coerce').notna()

# # Assuming 'is_rating_float_few_shot' is the flag column for few-shot predictions
# failed_few_shot_indices = few_shot_data[few_shot_data['is_rating_float_few_shot'] == False].index
# few_shot_data = rerun_failed_predictions(
#     few_shot_data, 
#     failed_few_shot_indices, 
#     predict_ratings_few_shot_and_save, 
#     FEW_SHOT_1_OBS_SAVE_PATH,
#     columns_for_training=['title'],
#     columns_for_prediction=['title'],
#     obs_per_user=1,
#     pause_every_n_users=PAUSE_EVERY_N_USERS,
#     sleep_time=SLEEP_TIME
# )

# %%
evaluate_model_predictions_rmse_mae(
    data_path=FEW_SHOT_1_OBS_SAVE_PATH,
    num_examples=NUM_EXAMPLES,
    actual_ratings_column='actual_rating',
    predicted_ratings_column='few_shot_predicted_rating'
)

# %% [markdown]
# # Limitations:
#
# The model might not fully understand the nuanced relationships between products based on titles alone. Additional context or features might be needed for more accurate predictions.
# This approach might be computationally expensive and slower than traditional matrix factorization or deep learning-based recommendation models, especially for a large number of users.
#
# # References
#
# + https://platform.openai.com/docs/api-reference/authentication
